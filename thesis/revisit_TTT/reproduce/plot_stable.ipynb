# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    })

colors = [(0.2298057,0.298717966,0.753683153),
          (0.3634607953411765,0.4847836818509804,0.9010188868941177),
          (0.5108243242509803,0.6493966148235294,0.9850787763764707),
          (0.6672529243333334,0.7791764569999999,0.992959213),
          (0.8049647588235295,0.8516661605568627,0.9261650744313725),
          (0.9193759889058823,0.8312727235294118,0.7828736304470588),
          (0.968203399,0.7208441,0.6122929913333334),
          (0.9440545734235294,0.5531534787490197,0.4355484903137255),
          (0.8523781350078431,0.34649194649411763,0.2803464686980392),
          (0.705673158,0.01555616,0.150232812)]
colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 30

# %%
filename1 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_rss_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1.csv"
df1 = pd.read_csv(filename1)
filename2 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_rss_joint(l1_1e-5)Q_T300_300epoch-tag-Training normalized L1.csv"
df2 = pd.read_csv(filename2)

plt.figure(figsize=(6,5),dpi=400)
# alpha: transparency 
plt.plot(range(1, 301), df1['Value'], color=colors[0], label='Train on P')
plt.plot(range(1, 301), df2['Value'], color=colors[1], label='Train on Q')
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs: train on P',fontsize=FONTSIZE/2)
plt.ylabel('Joint training loss',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %% [markdown]
# Train on P

# %%
filename1 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_rss_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1.csv"
df1 = pd.read_csv(filename1)
filename2 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_sensmap_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1.csv"
df2 = pd.read_csv(filename2)

plt.figure(figsize=(6,5),dpi=400)
# alpha: transparency 
plt.plot(range(1, 301), df1['Value'], color=colors[0], label='Root-sum-of-squares (RSS)')
plt.plot(range(1, 301), df2['Value'], color=colors[1], label='Sensitivity encoding (SENSE)')
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs: train on P',fontsize=FONTSIZE/2)
plt.ylabel('Joint training loss',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
filename1 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_rss_joint(l1_1e-5)Q_T300_300epoch-tag-Training normalized L1.csv"
df1 = pd.read_csv(filename1)
filename2 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_sensmap_joint(l1_1e-5)Q_T300_300epoch-tag-Training normalized L1.csv"
df2 = pd.read_csv(filename2)

plt.figure(figsize=(6,5),dpi=400)
# alpha: transparency 
plt.plot(range(1, 301), df1['Value'], color=colors[0], label='Root-sum-of-squares (RSS)')
plt.plot(range(1, 301), df2['Value'], color=colors[1], label='Sensitivity encoding (SENSE)')
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs: train on Q',fontsize=FONTSIZE/2)
plt.ylabel('Joint training loss',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %% [markdown]
# Train on P

# %%
filename1 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_rss_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1.csv"
df1 = pd.read_csv(filename1)
filename2 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_sensmap_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1.csv"
df2 = pd.read_csv(filename2)

plt.figure(figsize=(6,5),dpi=400)
# alpha: transparency 
plt.plot(range(1, 301), df1['Value'], color=colors[0], label='Root-sum-of-squares (RSS)')
plt.plot(range(1, 301), df2['Value'], color=colors[1], label='Sensitivity encoding (SENSE)')
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs: train on P',fontsize=FONTSIZE/2)
plt.ylabel('Joint training loss',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
filename1 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_rss_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1 - sup loss.csv"
df1 = pd.read_csv(filename1)
filename2 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_rss_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1 - self loss.csv"
df2 = pd.read_csv(filename2)

plt.figure(figsize=(6,5),dpi=400)
# alpha: transparency 
plt.plot(range(1, 301), df1['Value'], color=colors[7], label='Supervised loss')
plt.plot(range(1, 301), df2['Value'], color=colors[8], label='Self-supervised loss')
plt.ylim(0, 1.4)
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Training loss',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = 15)
plt.grid(True)
plt.show()

# %%
filename1 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_sensmap_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1 - sup loss.csv"
df1 = pd.read_csv(filename1)
filename2 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_sensmap_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1 - self loss.csv"
df2 = pd.read_csv(filename2)

plt.figure(figsize=(6,5),dpi=400)
# alpha: transparency 
plt.plot(range(1, 301), df1['Value'], color=colors[7], label='Supervised loss')
plt.plot(range(1, 301), df2['Value'], color=colors[8], label='Self-supervised loss')
plt.ylim(0, 1.4)
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Training loss',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = 15) # 20
plt.grid(True)
plt.show()

# %%
filename1 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_sensmapcombine_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1 - sup loss.csv"
df1 = pd.read_csv(filename1)
filename2 = f"/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/log/run-metaMRI_save_E_tttpaper_sensmapcombine_joint(l1_1e-5)P_T300_300epoch-tag-Training normalized L1 - self loss.csv"
df2 = pd.read_csv(filename2)

plt.figure(figsize=(6,5),dpi=400)
# alpha: transparency 
plt.plot(range(1, 301), df1['Value'], color=colors[7], label='Supervised loss')
plt.plot(range(1, 301), df2['Value'], color=colors[8], label='Self-supervised loss')
plt.ylim(0, 1.4)
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Training loss',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = 15)
plt.grid(True)
plt.show()
