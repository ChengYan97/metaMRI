# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    })

colors = [(0.2298057,0.298717966,0.753683153),
          (0.3634607953411765,0.4847836818509804,0.9010188868941177),
          (0.5108243242509803,0.6493966148235294,0.9850787763764707),
          (0.6672529243333334,0.7791764569999999,0.992959213),
          (0.8049647588235295,0.8516661605568627,0.9261650744313725),
          (0.9193759889058823,0.8312727235294118,0.7828736304470588),
          (0.968203399,0.7208441,0.6122929913333334),
          (0.9440545734235294,0.5531534787490197,0.4355484903137255),
          (0.8523781350078431,0.34649194649411763,0.2803464686980392),
          (0.705673158,0.01555616,0.150232812)]
colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 30

# %% [markdown]
# ### stanford data

# %%
standard = [0.01698, 0.0153, 0.01461,0.01392 ,0.01322, 0.01286, 0.01245]
maml = [0.01653, 0.01503, 0.01435, 0.01381, 0.01313, 0.01279, 0.01244]
x = [1, 5, 10, 20, 50, 100, 200]
variance_standard = [0.00032, 0.00011, 0.00005, 0, 0, 0]
variance_maml = [0.00018, 0.00014, 0.00005, 0, 0, 0]

plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(x, maml, color=colors[0], marker='o',markersize=4, label='Initialized by MAML train on P')
plt.errorbar(x[0], maml[0], yerr=variance_maml[0], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[1], maml[1], yerr=variance_maml[1], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[2], maml[2], yerr=variance_maml[2], fmt=colors[0], capsize=3, capthick=1)

plt.plot(x, standard, color=colors[1], marker='o',markersize=4, label='Initialized by standard train on P')
plt.errorbar(x[0], standard[0], yerr=variance_standard[0], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[1], standard[1], yerr=variance_standard[1], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[2], standard[2], yerr=variance_standard[2], fmt=colors[1], capsize=3, capthick=1)

plt.xscale('log')  # Set x-axis to log scale
plt.xticks(x,x)
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Data scale for adaptation',fontsize=FONTSIZE/2)
plt.ylabel('Best NMSE on target domain',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
standard = [0.83552, 0.84447, 0.84844, 0.8522,0.8567, 0.8585, 0.8606]
maml = [0.83784, 0.84621, 0.84997, 0.8527 ,0.8571, 0.8585, 0.8608]
x = [1, 5, 10, 20, 50, 100, 200]
variance_standard = [0.0022, 0.00072, 0.00042, 0, 0, 0]
variance_maml = [0.00144, 0.00078, 0.00041, 0, 0, 0]

plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(x, maml, color=colors[0], marker='o',markersize=4, label='Initialized by MAML train on P')
plt.errorbar(x[0], maml[0], yerr=variance_maml[0], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[1], maml[1], yerr=variance_maml[1], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[2], maml[2], yerr=variance_maml[2], fmt=colors[0], capsize=3, capthick=1)

plt.plot(x, standard, color=colors[1], marker='o',markersize=4, label='Initialized by standard train on P')
plt.errorbar(x[0], standard[0], yerr=variance_standard[0], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[1], standard[1], yerr=variance_standard[1], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[2], standard[2], yerr=variance_standard[2], fmt=colors[1], capsize=3, capthick=1)

plt.xscale('log')  # Set x-axis to log scale
plt.xticks(x,x)
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Data scale for adaptation',fontsize=FONTSIZE/2)
plt.ylabel('Best SSIM on target domain',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %% [markdown]
# ### fastMRI data

# %%
standard = [0.01168, 0.01105, 0.01058 ,0.009818, 0.009409, 0.008789]
maml = [0.01151, 0.01094, 0.01048, 0.009689, 0.009252, 0.008755]
variance_standard = [0.0001, 0.0001, 8e-05, 0, 0]
variance_maml = [0.00015, 0.00016, 8e-05, 0, 0]
x = [5, 10, 20, 50, 100, 200]


plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(x, maml, color=colors[0], marker='o',markersize=4, label='Initialized by MAML train on P')
plt.errorbar(x[0], maml[0], yerr=variance_maml[0], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[1], maml[1], yerr=variance_maml[1], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[2], maml[2], yerr=variance_maml[2], fmt=colors[0], capsize=3, capthick=1)

plt.plot(x, standard, color=colors[1], marker='o',markersize=4, label='Initialized by standard train on P')
plt.errorbar(x[0], standard[0], yerr=variance_standard[0], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[1], standard[1], yerr=variance_standard[1], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[2], standard[2], yerr=variance_standard[2], fmt=colors[1], capsize=3, capthick=1)

plt.xscale('log')  # Set x-axis to log scale
plt.xticks(x,x)
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Data scale for adaptation',fontsize=FONTSIZE/2)
plt.ylabel('Best NMSE on target domain',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
Standard max SSIM:  0.90054
Standard stand diviation:  0.00015
Standard epoch:  6
MAML max SSIM:  0.90182
MAML stand diviation:  0.00062
MAML epoch:  13

# %%
standard = [0.89419, 0.89696, 0.90054 ,0.9053, 0.909, 0.9125]
maml = [00.8958, 0.89859, 0.90182, 0.9067, 0.9099, 0.9126]
variance_standard = [00.00088, 0.00105, 0.00015, 0, 0]
variance_maml = [0.00079, 0.001, 0.00062, 0, 0]
x = [5, 10, 20, 50, 100, 200]

# standard = [0.83311, 0.89419, 0.89696, 0.9006 ,0.9053, 0.909, 0.9125]
# maml = [0.83633, 0.8958, 0.89859, 0.9020, 0.9067, 0.9099, 0.9126]
# variance_standard = [0.0021, 0.00088, 0.00105, 0, 0, 0]
# variance_maml = [0.00096, 0.00079, 0.001, 0, 0, 0]
# x = [1, 5, 10, 20, 50, 100, 200]


plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(x, maml, color=colors[0], marker='o',markersize=4, label='Initialized by MAML train on P')
plt.errorbar(x[0], maml[0], yerr=variance_maml[0], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[1], maml[1], yerr=variance_maml[1], fmt=colors[0], capsize=3, capthick=1)
plt.errorbar(x[2], maml[2], yerr=variance_maml[2], fmt=colors[0], capsize=3, capthick=1)

plt.plot(x, standard, color=colors[1], marker='o',markersize=4, label='Initialized by standard train on P')
plt.errorbar(x[0], standard[0], yerr=variance_standard[0], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[1], standard[1], yerr=variance_standard[1], fmt=colors[1], capsize=3, capthick=1)
plt.errorbar(x[2], standard[2], yerr=variance_standard[2], fmt=colors[1], capsize=3, capthick=1)

plt.xscale('log')  # Set x-axis to log scale
plt.xticks(x,x)
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Data scale for adaptation',fontsize=FONTSIZE/2)
plt.ylabel('Best SSIM on target domain',fontsize=FONTSIZE/2)
#plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data1 = []
data2 = []

for i in range(1,6):
    # read csv
    filename1 = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/data_scale/log/run-metaMRI_thesis_metaMRI_setup_8knee_data_scale_E_sup_maml_20few-adapt_lrCA0.001_Q1_seed{i}-tag-Testing SSIM.csv"
    df1 = pd.read_csv(filename1)
    # extract value
    values1 = df1['Value'].values
    data1.append(values1)
    # read csv
    filename2 = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/data_scale/log/run-metaMRI_thesis_metaMRI_setup_8knee_data_scale_E_sup_standard_20few-adapt_lrCA0.001_Q1_seed{i}-tag-Testing SSIM.csv"
    df2 = pd.read_csv(filename2)
    # extract value
    values2 = df2['Value'].values
    data2.append(values2)


data1 = [sublist[:30] for sublist in data1]
data2 = [sublist[:30] for sublist in data2]

# mean and std
mean_values1 = np.mean(data1, axis=0)
std_values1 = np.std(data1, axis=0)
mean_values2 = np.mean(data2, axis=0)
std_values2 = np.std(data2, axis=0)

# %%
min_index2 = np.argmin(mean_values2)
print('Standard min NMSE: ',  round(mean_values2[min_index2], 5))
print('Standard stand diviation: ', round(std_values2[min_index2], 5))
print('Standard epoch: ', min_index2)

min_index1 = np.argmin(mean_values1)
print('MAML min NMSE: ',  round(mean_values1[min_index1], 5))
print('MAML stand diviation: ', round(std_values1[min_index1], 5))
print('MAML epoch: ', min_index1)
# Out:
# Standard min NMSE:  0.01058
# Standard stand diviation:  8e-05
# Standard epoch:  4
# MAML min NMSE:  0.01048
# MAML stand diviation:  8e-05
# MAML epoch:  8

# %%
max_index2 = np.argmax(mean_values2)
print('Standard max SSIM: ',  round(mean_values2[max_index2], 5))
print('Standard stand diviation: ', round(std_values2[max_index2], 5))
print('Standard epoch: ', max_index2)

max_index1 = np.argmax(mean_values1)
print('MAML max SSIM: ',  round(mean_values1[max_index1], 5))
print('MAML stand diviation: ', round(std_values1[max_index1], 5))
print('MAML epoch: ', max_index1)
# Out:
# Standard max SSIM:  0.90054
# Standard stand diviation:  0.00015
# Standard epoch:  6
# MAML max SSIM:  0.90182
# MAML stand diviation:  0.00062
# MAML epoch:  13
