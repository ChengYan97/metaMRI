# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    })

colors = [(0.2298057,0.298717966,0.753683153),
          (0.3634607953411765,0.4847836818509804,0.9010188868941177),
          (0.5108243242509803,0.6493966148235294,0.9850787763764707),
          (0.6672529243333334,0.7791764569999999,0.992959213),
          (0.8049647588235295,0.8516661605568627,0.9261650744313725),
          (0.9193759889058823,0.8312727235294118,0.7828736304470588),
          (0.968203399,0.7208441,0.6122929913333334),
          (0.9440545734235294,0.5531534787490197,0.4355484903137255),
          (0.8523781350078431,0.34649194649411763,0.2803464686980392),
          (0.705673158,0.01555616,0.150232812)]
colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 30

# %% [markdown]
# bach size

# %%
val_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/innerloopsettings/run-metaMRI_save_E6_E6.3_E6.3_maml(NMSE)_T8x200_1inner_200epoch-tag-Validation NMSE.csv')
values_val_0 = val_0['Value'].values

val_1 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/innerloopsettings/run-metaMRI_save_E6_E6.3_E6.3_maml(NMSE)_T8x200_2inner_200epoch-tag-Validation NMSE.csv')
values_val_1 = val_1['Value'].values

# %%
plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(values_val_0, label='Task batch size = 1', color=colors[0])
plt.plot(values_val_1, label='Task batch size = 2', color=colors[1])

#plt.plot(adapt_loss3, label='8knee 9 adapt lr = 1e-3', color=colors[5])
# 0 - 200
plt.xlim(0, 200)


plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Validation NMSE',fontsize=FONTSIZE/2)
# plt.title('Inner loop loss optimization improvement')
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %% [markdown]
# learning rate

# %%
val_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/innerloopsettings/run-metaMRI_save_E6_E6.3_E6.3_maml(NMSE)_T8x200_1inner_200epoch-tag-Validation NMSE.csv')
values_val_0 = val_0['Value'].values

val_1 = pd.read_csv("/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/innerloopsettings/run-metaMRI_save_E6_E6'_E6'_maml(NMSE-lre-3)_T8x200_200epoch-tag-Validation NMSE.csv")
values_val_1 = val_1['Value'].values

val_2 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/innerloopsettings/run-metaMRI_save_E6_E6.4_E6.4_maml(NMSE-lre-3)_T8x200_200epoch-tag-Validation NMSE.csv')
values_val_2 = val_2['Value'].values

# %%
plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(values_val_0, label='Inner lr = 1e-4, outer lr = 1e-4', color=colors[0])
plt.plot(values_val_2, label='Inner lr = 1e-4, outer lr = 1e-3', color=colors[4])
plt.plot(values_val_1, label='Inner lr = 1e-3, outer lr = 1e-3', color=colors[3])

#plt.plot(adapt_loss3, label='8knee 9 adapt lr = 1e-3', color=colors[5])
# 0 - 200
plt.xlim(0, 200)


plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Validation NMSE',fontsize=FONTSIZE/2)
# plt.title('Inner loop loss optimization improvement')
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()
