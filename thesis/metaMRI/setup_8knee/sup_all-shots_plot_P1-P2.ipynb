# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    })

colors = [(0.2298057,0.298717966,0.753683153),
          (0.3634607953411765,0.4847836818509804,0.9010188868941177),
          (0.5108243242509803,0.6493966148235294,0.9850787763764707),
          (0.6672529243333334,0.7791764569999999,0.992959213),
          (0.8049647588235295,0.8516661605568627,0.9261650744313725),
          (0.9193759889058823,0.8312727235294118,0.7828736304470588),
          (0.968203399,0.7208441,0.6122929913333334),
          (0.9440545734235294,0.5531534787490197,0.4355484903137255),
          (0.8523781350078431,0.34649194649411763,0.2803464686980392),
          (0.705673158,0.01555616,0.150232812)]
colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 30

# %% [markdown]
# Testing NMSE

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define your data filenames
filename1_P = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_maml_200few-adapt_lr0.0001_P1_train_seed1-tag-Testing NMSE.csv"
filename2_P = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_standard_200few-adapt_lr0.0001_P1_train_seed1-tag-Testing NMSE.csv"
filename1_Q = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_maml_200few-adapt_lr0.0001_P1_train_seed1-tag-Testing SSIM.csv"
filename2_Q = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_standard_200few-adapt_lr0.0001_P1_train_seed1-tag-Testing SSIM.csv"

# Read data into dataframes
df1_P = pd.read_csv(filename1_P)
df2_P = pd.read_csv(filename2_P)
df1_Q = pd.read_csv(filename1_Q)
df2_Q = pd.read_csv(filename2_Q)

# Create a figure with subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5), dpi=400)

# Plot the first set of data (train on P)
axs[0].plot(range(0, 11), df1_P['Value'], color=colors[0], label='MAML trained on P')
axs[0].plot(range(0, 11), df2_P['Value'], color=colors[1], label='Standard trained on P')
axs[0].tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
axs[0].tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
axs[0].set_xlabel('Epochs', fontsize=20)
axs[0].set_ylabel('Test NMSE', fontsize=20)
axs[0].legend(fontsize = 24)
axs[0].grid(True)

# Plot the second set of data (train on Q)
axs[1].plot(range(0, 11), df1_Q['Value'], color=colors[0], label='MAML trained on P')
axs[1].plot(range(0, 11), df2_Q['Value'], color=colors[1], label='Standard trained on P')
axs[1].tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
axs[1].tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
axs[1].set_xlabel('Epochs', fontsize=20)
axs[1].set_ylabel('Test SSIM', fontsize=20)
axs[1].legend(fontsize = 24)
axs[1].grid(True)

# Adjust spacing between subplots
plt.tight_layout()

# Save or display the figure
plt.show()  # Display the figure

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define your data filenames
filename1_P = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_maml_200few-adapt_lr0.0001_P2_train_seed1-tag-Testing NMSE.csv"
filename2_P = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_standard_200few-adapt_lr0.0001_P2_train_seed1-tag-Testing NMSE.csv"
filename1_Q = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_maml_200few-adapt_lr0.0001_P2_train_seed1-tag-Testing SSIM.csv"
filename2_Q = f"/cheng/metaMRI/metaMRI/thesis/metaMRI/setup_8knee/in_log/run-metaMRI_thesis_metaMRI_setup_8knee_in_log_E_sup_standard_200few-adapt_lr0.0001_P2_train_seed1-tag-Testing SSIM.csv"

# Read data into dataframes
df1_P = pd.read_csv(filename1_P)
df2_P = pd.read_csv(filename2_P)
df1_Q = pd.read_csv(filename1_Q)
df2_Q = pd.read_csv(filename2_Q)

# Create a figure with subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5), dpi=400)

# Plot the first set of data (train on P)
axs[0].plot(range(0, 11), df1_P['Value'], color=colors[0], label='MAML trained on P')
axs[0].plot(range(0, 11), df2_P['Value'], color=colors[1], label='Standard trained on P')
axs[0].tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
axs[0].tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
axs[0].set_xlabel('Epochs', fontsize=20)
axs[0].set_ylabel('Test NMSE', fontsize=20)
axs[0].legend(fontsize = 24)
axs[0].grid(True)

# Plot the second set of data (train on Q)
axs[1].plot(range(0, 11), df1_Q['Value'], color=colors[0], label='MAML trained on P')
axs[1].plot(range(0, 11), df2_Q['Value'], color=colors[1], label='Standard trained on P')
axs[1].tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
axs[1].tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
axs[1].set_xlabel('Epochs', fontsize=20)
axs[1].set_ylabel('Test SSIM', fontsize=20)
axs[1].legend(fontsize = 24)
axs[1].grid(True)

# Adjust spacing between subplots
plt.tight_layout()

# Save or display the figure
plt.show()  # Display the figure
