# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    })

colors = [(0.2298057,0.298717966,0.753683153),
          (0.3634607953411765,0.4847836818509804,0.9010188868941177),
          (0.5108243242509803,0.6493966148235294,0.9850787763764707),
          (0.6672529243333334,0.7791764569999999,0.992959213),
          (0.8049647588235295,0.8516661605568627,0.9261650744313725),
          (0.9193759889058823,0.8312727235294118,0.7828736304470588),
          (0.968203399,0.7208441,0.6122929913333334),
          (0.9440545734235294,0.5531534787490197,0.4355484903137255),
          (0.8523781350078431,0.34649194649411763,0.2803464686980392),
          (0.705673158,0.01555616,0.150232812)]
colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 30

# %% [markdown]
# overlap

# %% [markdown]
# P

# %%
adapt_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/overlap/run-metaMRI_save_E14.2_maml_out_k-sup(l1_out-5_in-5)P_T300_300epoch-tag-Meta 0-step Adaptation Loss (MAML).csv')
values_adapt_0 = adapt_0['Value'].values

adapt_last = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/overlap/run-metaMRI_save_E14.2_maml_out_k-sup(l1_out-5_in-5)P_T300_300epoch-tag-Meta 4-step Adaptation Loss (MAML).csv')
values_adapt_last = adapt_last['Value'].values

adapt_loss1 = values_adapt_0 - values_adapt_last

# %% [markdown]
# Q

# %%
adapt_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/overlap/run-metaMRI_save_E14.2_maml_out_k-sup(l1_out-5_in-5)Q_T300_300epoch-tag-Meta 0-step Adaptation Loss (MAML).csv')
values_adapt_0 = adapt_0['Value'].values

adapt_last = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/overlap/run-metaMRI_save_E14.2_maml_out_k-sup(l1_out-5_in-5)Q_T300_300epoch-tag-Meta 4-step Adaptation Loss (MAML).csv')
values_adapt_last = adapt_last['Value'].values

adapt_loss2 = values_adapt_0 - values_adapt_last

# %%
plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(adapt_loss1, label='MAML train on P', color=colors[4])
plt.plot(adapt_loss2, label='MAML train on Q', color=colors[5])
#plt.plot(adapt_loss3, label='8knee 9 adapt lr = 1e-3', color=colors[5])
# 0 - 200
plt.xlim(0, 300)
plt.ylim(0, 0.002)

plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Meta-learner improved loss',fontsize=FONTSIZE/2)
# plt.title('Inner loop loss optimization improvement')
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %% [markdown]
# FOMAML 20 step

# %%
adapt_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/fomaml/run-metaMRI_save_E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)P_T300_300epoch-tag-Meta 0-step Adaptation Loss (MAML).csv')
values_adapt_0 = adapt_0['Value'].values

adapt_last = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/fomaml/run-metaMRI_save_E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)P_T300_300epoch-tag-Meta 19-step Adaptation Loss (MAML).csv')
values_adapt_last = adapt_last['Value'].values

adapt_loss1 = values_adapt_0 - values_adapt_last

# %%
adapt_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/fomaml/run-metaMRI_save_E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)Q_T300_300epoch-tag-Meta 0-step Adaptation Loss (MAML).csv')
values_adapt_0 = adapt_0['Value'].values

adapt_last = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/fomaml/run-metaMRI_save_E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)Q_T300_300epoch-tag-Meta 19-step Adaptation Loss (MAML).csv')
values_adapt_last = adapt_last['Value'].values

adapt_loss2 = values_adapt_0 - values_adapt_last

# %%
plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(adapt_loss1, label='MAML train on P', color=colors[4])
plt.plot(adapt_loss2, label='MAML train on Q', color=colors[5])
#plt.plot(adapt_loss3, label='8knee 9 adapt lr = 1e-3', color=colors[5])
# 0 - 200
plt.xlim(0, 300)
plt.ylim(0, 0.002)

plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Meta-learner improved loss',fontsize=FONTSIZE/2)
# plt.title('Inner loop loss optimization improvement')
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %% [markdown]
# disjoint

# %% [markdown]
# P

# %%
adapt_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/disjoint/run-metaMRI_save_E14.4_maml_in1-4_out_k3-4(l1_out-5_in-5)P_T300_300epoch-tag-Meta 0-step Adaptation Loss (MAML).csv')
values_adapt_0 = adapt_0['Value'].values

adapt_last = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/disjoint/run-metaMRI_save_E14.4_maml_in1-4_out_k3-4(l1_out-5_in-5)P_T300_300epoch-tag-Meta 4-step Adaptation Loss (MAML).csv')
values_adapt_last = adapt_last['Value'].values

adapt_loss1 = values_adapt_0 - values_adapt_last

# %% [markdown]
# Q

# %%
adapt_0 = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/disjoint/run-metaMRI_save_E14.4_maml_in1-4_out_k3-4(l1_out-5_in-5)Q_T300_300epoch-tag-Meta 0-step Adaptation Loss (MAML).csv')
values_adapt_0 = adapt_0['Value'].values

adapt_last = pd.read_csv('/cheng/metaMRI/metaMRI/thesis/metaTTT/adapt_loss_analysis/disjoint/run-metaMRI_save_E14.4_maml_in1-4_out_k3-4(l1_out-5_in-5)Q_T300_300epoch-tag-Meta 4-step Adaptation Loss (MAML).csv')
values_adapt_last = adapt_last['Value'].values

adapt_loss2 = values_adapt_0 - values_adapt_last

# %%
plt.figure(figsize=(6,5),dpi=400)

# alpha: transparency 
plt.plot(adapt_loss1, label='MAML train on P', color=colors[4])
plt.plot(adapt_loss2, label='MAML train on Q', color=colors[5])
#plt.plot(adapt_loss3, label='8knee 9 adapt lr = 1e-3', color=colors[5])
# 0 - 200
plt.xlim(0, 300)
plt.ylim(0, 0.002)

plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Meta-learner improved loss',fontsize=FONTSIZE/2)
# plt.title('Inner loop loss optimization improvement')
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()
