# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)P_T300_300epoch/E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9486750364303589
# The best SSIM epoch:  127
# Testing sample:  2
# The best SSIM through training process: 0.917702317237854
# The best SSIM epoch:  157
# Testing sample:  3
# The best SSIM through training process: 0.9420949816703796
# The best SSIM epoch:  101
# Testing sample:  4
# The best SSIM through training process: 0.9452779293060303
# The best SSIM epoch:  156
# Testing sample:  5
# The best SSIM through training process: 0.9445791244506836
# The best SSIM epoch:  186
# Testing sample:  6
# The best SSIM through training process: 0.9382783770561218
# The best SSIM epoch:  124
# Testing sample:  7
# The best SSIM through training process: 0.9385243058204651
# The best SSIM epoch:  161
# Testing sample:  8
# The best SSIM through training process: 0.9255616664886475
# The best SSIM epoch:  79
# Testing sample:  9
# The best SSIM through training process: 0.9399140477180481
# The best SSIM epoch:  201
# Testing sample:  10
# The best SSIM through training process: 0.9405885338783264
# The best SSIM epoch:  112
# Testing sample:  11
# The best SSIM through training process: 0.9409695863723755
# The best SSIM epoch:  122
# Testing sample:  12
# The best SSIM through training process: 0.9419825077056885
# The best SSIM epoch:  140
# Testing sample:  13
# The best SSIM through training process: 0.9537437558174133
# The best SSIM epoch:  187
# Testing sample:  14
# The best SSIM through training process: 0.9537416100502014
# The best SSIM epoch:  200
# Testing sample:  15
# The best SSIM through training process: 0.9335339069366455
# The best SSIM epoch:  195
# Testing sample:  16
# The best SSIM through training process: 0.9498715996742249
# The best SSIM epoch:  138
# Testing sample:  17
# The best SSIM through training process: 0.9478331804275513
# The best SSIM epoch:  134
# Testing sample:  18
# The best SSIM through training process: 0.9340064525604248
# The best SSIM epoch:  146
# Testing sample:  19
# The best SSIM through training process: 0.9473260045051575
# The best SSIM epoch:  182
# Testing sample:  20
# The best SSIM through training process: 0.9585172533988953
# The best SSIM epoch:  236
# Testing sample:  21
# The best SSIM through training process: 0.9530120491981506
# The best SSIM epoch:  237
# Testing sample:  22
# The best SSIM through training process: 0.9440646767616272
# The best SSIM epoch:  119
# Testing sample:  23
# The best SSIM through training process: 0.9530789852142334
# The best SSIM epoch:  175
# Testing sample:  24
# The best SSIM through training process: 0.9481619000434875
# The best SSIM epoch:  112
# Testing sample:  25
# The best SSIM through training process: 0.9455071687698364
# The best SSIM epoch:  178
# Testing sample:  26
# The best SSIM through training process: 0.944492757320404
# The best SSIM epoch:  131
# Testing sample:  27
# The best SSIM through training process: 0.9343080520629883
# The best SSIM epoch:  140
# Testing sample:  28
# The best SSIM through training process: 0.935840368270874
# The best SSIM epoch:  115
# Testing sample:  29
# The best SSIM through training process: 0.9498630166053772
# The best SSIM epoch:  147
# Testing sample:  30
# The best SSIM through training process: 0.9272675514221191
# The best SSIM epoch:  177
# Testing sample:  31
# The best SSIM through training process: 0.9249034523963928
# The best SSIM epoch:  113
# Testing sample:  32
# The best SSIM through training process: 0.9359258413314819
# The best SSIM epoch:  214
# Testing sample:  33
# The best SSIM through training process: 0.944007158279419
# The best SSIM epoch:  222
# Testing sample:  34
# The best SSIM through training process: 0.948564887046814
# The best SSIM epoch:  207
# Testing sample:  35
# The best SSIM through training process: 0.9498975872993469
# The best SSIM epoch:  107
# Testing sample:  36
# The best SSIM through training process: 0.9377042651176453
# The best SSIM epoch:  132
# Testing sample:  37
# The best SSIM through training process: 0.9424454569816589
# The best SSIM epoch:  81
# Testing sample:  38
# The best SSIM through training process: 0.9368630051612854
# The best SSIM epoch:  128
# Testing sample:  39
# The best SSIM through training process: 0.9522311687469482
# The best SSIM epoch:  183
# Testing sample:  40
# The best SSIM through training process: 0.9451409578323364
# The best SSIM epoch:  144
# Testing sample:  41
# The best SSIM through training process: 0.9385538101196289
# The best SSIM epoch:  115
# Testing sample:  42
# The best SSIM through training process: 0.9410890340805054
# The best SSIM epoch:  175
# Testing sample:  43
# The best SSIM through training process: 0.9387063384056091
# The best SSIM epoch:  110
# Testing sample:  44
# The best SSIM through training process: 0.9482760429382324
# The best SSIM epoch:  104
# Testing sample:  45
# The best SSIM through training process: 0.9510577321052551
# The best SSIM epoch:  258
# Testing sample:  46
# The best SSIM through training process: 0.9251540899276733
# The best SSIM epoch:  131
# Testing sample:  47
# The best SSIM through training process: 0.9555573463439941
# The best SSIM epoch:  202
# Testing sample:  48
# The best SSIM through training process: 0.9306998252868652
# The best SSIM epoch:  135
# Testing sample:  49
# The best SSIM through training process: 0.8917083740234375
# The best SSIM epoch:  107
# Testing sample:  50
# The best SSIM through training process: 0.9382525086402893
# The best SSIM epoch:  86
# Testing sample:  51
# The best SSIM through training process: 0.9396221041679382
# The best SSIM epoch:  193
# Testing sample:  52
# The best SSIM through training process: 0.9414334893226624
# The best SSIM epoch:  162
# Testing sample:  53
# The best SSIM through training process: 0.9427251219749451
# The best SSIM epoch:  144
# Testing sample:  54
# The best SSIM through training process: 0.9654616713523865
# The best SSIM epoch:  140
# Testing sample:  55
# The best SSIM through training process: 0.9474636316299438
# The best SSIM epoch:  167
# Testing sample:  56
# The best SSIM through training process: 0.9473453164100647
# The best SSIM epoch:  228
# Testing sample:  57
# The best SSIM through training process: 0.9557632803916931
# The best SSIM epoch:  211
# Testing sample:  58
# The best SSIM through training process: 0.9408919215202332
# The best SSIM epoch:  155
# Testing sample:  59
# The best SSIM through training process: 0.9559630155563354
# The best SSIM epoch:  117
# Testing sample:  60
# The best SSIM through training process: 0.9284951686859131
# The best SSIM epoch:  94
# Testing sample:  61
# The best SSIM through training process: 0.9485526084899902
# The best SSIM epoch:  147
# Testing sample:  62
# The best SSIM through training process: 0.9346538186073303
# The best SSIM epoch:  126
# Testing sample:  63
# The best SSIM through training process: 0.9361552000045776
# The best SSIM epoch:  139
# Testing sample:  64
# The best SSIM through training process: 0.9485802054405212
# The best SSIM epoch:  267
# Testing sample:  65
# The best SSIM through training process: 0.9494521617889404
# The best SSIM epoch:  114
# Testing sample:  66
# The best SSIM through training process: 0.9580938220024109
# The best SSIM epoch:  192
# Testing sample:  67
# The best SSIM through training process: 0.9367254376411438
# The best SSIM epoch:  114
# Testing sample:  68
# The best SSIM through training process: 0.9425345659255981
# The best SSIM epoch:  129
# Testing sample:  69
# The best SSIM through training process: 0.9396035075187683
# The best SSIM epoch:  219
# Testing sample:  70
# The best SSIM through training process: 0.9431224465370178
# The best SSIM epoch:  133
# Testing sample:  71
# The best SSIM through training process: 0.928748369216919
# The best SSIM epoch:  116
# Testing sample:  72
# The best SSIM through training process: 0.9446300268173218
# The best SSIM epoch:  186
# Testing sample:  73
# The best SSIM through training process: 0.9320108294487
# The best SSIM epoch:  132
# Testing sample:  74
# The best SSIM through training process: 0.9312791228294373
# The best SSIM epoch:  121
# Testing sample:  75
# The best SSIM through training process: 0.9395884871482849
# The best SSIM epoch:  98
# Testing sample:  76
# The best SSIM through training process: 0.9390483498573303
# The best SSIM epoch:  149
# Testing sample:  77
# The best SSIM through training process: 0.9537683129310608
# The best SSIM epoch:  205
# Testing sample:  78
# The best SSIM through training process: 0.9605110883712769
# The best SSIM epoch:  257
# Testing sample:  79
# The best SSIM through training process: 0.9449173212051392
# The best SSIM epoch:  92
# Testing sample:  80
# The best SSIM through training process: 0.9309463500976562
# The best SSIM epoch:  196
# Testing sample:  81
# The best SSIM through training process: 0.9422124624252319
# The best SSIM epoch:  232
# Testing sample:  82
# The best SSIM through training process: 0.936693012714386
# The best SSIM epoch:  149
# Testing sample:  83
# The best SSIM through training process: 0.94285649061203
# The best SSIM epoch:  171
# Testing sample:  84
# The best SSIM through training process: 0.946803092956543
# The best SSIM epoch:  84
# Testing sample:  85
# The best SSIM through training process: 0.9545888304710388
# The best SSIM epoch:  114
# Testing sample:  86
# The best SSIM through training process: 0.8979007601737976
# The best SSIM epoch:  91
# Testing sample:  87
# The best SSIM through training process: 0.928799569606781
# The best SSIM epoch:  105
# Testing sample:  88
# The best SSIM through training process: 0.9406034350395203
# The best SSIM epoch:  112
# Testing sample:  89
# The best SSIM through training process: 0.9437389373779297
# The best SSIM epoch:  165
# Testing sample:  90
# The best SSIM through training process: 0.9528905749320984
# The best SSIM epoch:  216
# Testing sample:  91
# The best SSIM through training process: 0.9324011206626892
# The best SSIM epoch:  150
# Testing sample:  92
# The best SSIM through training process: 0.9408780336380005
# The best SSIM epoch:  117
# Testing sample:  93
# The best SSIM through training process: 0.9220213294029236
# The best SSIM epoch:  82
# Testing sample:  94
# The best SSIM through training process: 0.934533417224884
# The best SSIM epoch:  117
# Testing sample:  95
# The best SSIM through training process: 0.9278078079223633
# The best SSIM epoch:  124
# Testing sample:  96
# The best SSIM through training process: 0.9452773928642273
# The best SSIM epoch:  140
# Testing sample:  97
# The best SSIM through training process: 0.9381393194198608
# The best SSIM epoch:  130
# Testing sample:  98
# The best SSIM through training process: 0.9399147629737854
# The best SSIM epoch:  164
# Testing sample:  99
# The best SSIM through training process: 0.9599199891090393
# The best SSIM epoch:  244
# Testing sample:  100
# The best SSIM through training process: 0.9442556500434875
# The best SSIM epoch:  124
# Testing average SSIM loss:  0.9413538032770157
# Testing average SSIM loss epoch:  151.43
