# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttkspace_sensmap_joint(l1_1e-5)Q_T300_300epoch/E_tttkspace_sensmap_joint(l1_1e-5)Q_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9660852551460266
# The best SSIM epoch:  87
# Testing sample:  2
# The best SSIM through training process: 0.9268278479576111
# The best SSIM epoch:  53
# Testing sample:  3
# The best SSIM through training process: 0.9600467681884766
# The best SSIM epoch:  67
# Testing sample:  4
# The best SSIM through training process: 0.9635442495346069
# The best SSIM epoch:  102
# Testing sample:  5
# The best SSIM through training process: 0.9555541276931763
# The best SSIM epoch:  77
# Testing sample:  6
# The best SSIM through training process: 0.9561095237731934
# The best SSIM epoch:  88
# Testing sample:  7
# The best SSIM through training process: 0.9496753811836243
# The best SSIM epoch:  76
# Testing sample:  8
# The best SSIM through training process: 0.9379971027374268
# The best SSIM epoch:  42
# Testing sample:  9
# The best SSIM through training process: 0.9545904397964478
# The best SSIM epoch:  77
# Testing sample:  10
# The best SSIM through training process: 0.9586578607559204
# The best SSIM epoch:  51
# Testing sample:  11
# The best SSIM through training process: 0.9580426216125488
# The best SSIM epoch:  78
# Testing sample:  12
# The best SSIM through training process: 0.9603243470191956
# The best SSIM epoch:  88
# Testing sample:  13
# The best SSIM through training process: 0.966004490852356
# The best SSIM epoch:  85
# Testing sample:  14
# The best SSIM through training process: 0.9660031795501709
# The best SSIM epoch:  111
# Testing sample:  15
# The best SSIM through training process: 0.9497970342636108
# The best SSIM epoch:  69
# Testing sample:  16
# The best SSIM through training process: 0.9626083970069885
# The best SSIM epoch:  114
# Testing sample:  17
# The best SSIM through training process: 0.9605786204338074
# The best SSIM epoch:  56
# Testing sample:  18
# The best SSIM through training process: 0.9494134187698364
# The best SSIM epoch:  49
# Testing sample:  19
# The best SSIM through training process: 0.9557361006736755
# The best SSIM epoch:  85
# Testing sample:  20
# The best SSIM through training process: 0.9705513715744019
# The best SSIM epoch:  101
# Testing sample:  21
# The best SSIM through training process: 0.9671180844306946
# The best SSIM epoch:  87
# Testing sample:  22
# The best SSIM through training process: 0.958929181098938
# The best SSIM epoch:  42
# Testing sample:  23
# The best SSIM through training process: 0.9623603224754333
# The best SSIM epoch:  117
# Testing sample:  24
# The best SSIM through training process: 0.9660735130310059
# The best SSIM epoch:  88
# Testing sample:  25
# The best SSIM through training process: 0.9599508047103882
# The best SSIM epoch:  65
# Testing sample:  26
# The best SSIM through training process: 0.9605931639671326
# The best SSIM epoch:  71
# Testing sample:  27
# The best SSIM through training process: 0.9542707800865173
# The best SSIM epoch:  75
# Testing sample:  28
# The best SSIM through training process: 0.9529958963394165
# The best SSIM epoch:  69
# Testing sample:  29
# The best SSIM through training process: 0.9640505313873291
# The best SSIM epoch:  86
# Testing sample:  30
# The best SSIM through training process: 0.9404710531234741
# The best SSIM epoch:  50
# Testing sample:  31
# The best SSIM through training process: 0.9457392692565918
# The best SSIM epoch:  74
# Testing sample:  32
# The best SSIM through training process: 0.9515935778617859
# The best SSIM epoch:  65
# Testing sample:  33
# The best SSIM through training process: 0.959534764289856
# The best SSIM epoch:  101
# Testing sample:  34
# The best SSIM through training process: 0.9578328728675842
# The best SSIM epoch:  106
# Testing sample:  35
# The best SSIM through training process: 0.9566934108734131
# The best SSIM epoch:  85
# Testing sample:  36
# The best SSIM through training process: 0.9588460922241211
# The best SSIM epoch:  44
# Testing sample:  37
# The best SSIM through training process: 0.9531413316726685
# The best SSIM epoch:  45
# Testing sample:  38
# The best SSIM through training process: 0.9539380073547363
# The best SSIM epoch:  90
# Testing sample:  39
# The best SSIM through training process: 0.965951681137085
# The best SSIM epoch:  143
# Testing sample:  40
# The best SSIM through training process: 0.9636667370796204
# The best SSIM epoch:  94
# Testing sample:  41
# The best SSIM through training process: 0.9565590620040894
# The best SSIM epoch:  69
# Testing sample:  42
# The best SSIM through training process: 0.9550321698188782
# The best SSIM epoch:  73
# Testing sample:  43
# The best SSIM through training process: 0.9547159075737
# The best SSIM epoch:  50
# Testing sample:  44
# The best SSIM through training process: 0.9607829451560974
# The best SSIM epoch:  68
# Testing sample:  45
# The best SSIM through training process: 0.9661918878555298
# The best SSIM epoch:  97
# Testing sample:  46
# The best SSIM through training process: 0.9326151609420776
# The best SSIM epoch:  65
# Testing sample:  47
# The best SSIM through training process: 0.9676083326339722
# The best SSIM epoch:  116
# Testing sample:  48
# The best SSIM through training process: 0.9426535964012146
# The best SSIM epoch:  43
# Testing sample:  49
# The best SSIM through training process: 0.8955309391021729
# The best SSIM epoch:  19
# Testing sample:  50
# The best SSIM through training process: 0.9518970251083374
# The best SSIM epoch:  49
# Testing sample:  51
# The best SSIM through training process: 0.9559782147407532
# The best SSIM epoch:  110
# Testing sample:  52
# The best SSIM through training process: 0.95176100730896
# The best SSIM epoch:  90
# Testing sample:  53
# The best SSIM through training process: 0.9585206508636475
# The best SSIM epoch:  85
# Testing sample:  54
# The best SSIM through training process: 0.9756110310554504
# The best SSIM epoch:  125
# Testing sample:  55
# The best SSIM through training process: 0.9640509486198425
# The best SSIM epoch:  67
# Testing sample:  56
# The best SSIM through training process: 0.9601282477378845
# The best SSIM epoch:  104
# Testing sample:  57
# The best SSIM through training process: 0.9682042598724365
# The best SSIM epoch:  83
# Testing sample:  58
# The best SSIM through training process: 0.9527052640914917
# The best SSIM epoch:  82
# Testing sample:  59
# The best SSIM through training process: 0.9705144166946411
# The best SSIM epoch:  87
# Testing sample:  60
# The best SSIM through training process: 0.9377264380455017
# The best SSIM epoch:  44
# Testing sample:  61
# The best SSIM through training process: 0.9655331969261169
# The best SSIM epoch:  83
# Testing sample:  62
# The best SSIM through training process: 0.9485766291618347
# The best SSIM epoch:  95
# Testing sample:  63
# The best SSIM through training process: 0.9493811130523682
# The best SSIM epoch:  50
# Testing sample:  64
# The best SSIM through training process: 0.9651634693145752
# The best SSIM epoch:  105
# Testing sample:  65
# The best SSIM through training process: 0.9626573920249939
# The best SSIM epoch:  60
# Testing sample:  66
# The best SSIM through training process: 0.9736613631248474
# The best SSIM epoch:  111
# Testing sample:  67
# The best SSIM through training process: 0.9468443989753723
# The best SSIM epoch:  64
# Testing sample:  68
# The best SSIM through training process: 0.953900933265686
# The best SSIM epoch:  91
# Testing sample:  69
# The best SSIM through training process: 0.9607500433921814
# The best SSIM epoch:  97
# Testing sample:  70
# The best SSIM through training process: 0.9625073075294495
# The best SSIM epoch:  81
# Testing sample:  71
# The best SSIM through training process: 0.9455223083496094
# The best SSIM epoch:  42
# Testing sample:  72
# The best SSIM through training process: 0.9626781344413757
# The best SSIM epoch:  74
# Testing sample:  73
# The best SSIM through training process: 0.9415956139564514
# The best SSIM epoch:  65
# Testing sample:  74
# The best SSIM through training process: 0.9492852687835693
# The best SSIM epoch:  65
# Testing sample:  75
# The best SSIM through training process: 0.9502148032188416
# The best SSIM epoch:  37
# Testing sample:  76
# The best SSIM through training process: 0.9576704502105713
# The best SSIM epoch:  90
# Testing sample:  77
# The best SSIM through training process: 0.9646773338317871
# The best SSIM epoch:  81
# Testing sample:  78
# The best SSIM through training process: 0.9730448722839355
# The best SSIM epoch:  84
# Testing sample:  79
# The best SSIM through training process: 0.958799421787262
# The best SSIM epoch:  57
# Testing sample:  80
# The best SSIM through training process: 0.9432644248008728
# The best SSIM epoch:  99
# Testing sample:  81
# The best SSIM through training process: 0.9575528502464294
# The best SSIM epoch:  109
# Testing sample:  82
# The best SSIM through training process: 0.9544405937194824
# The best SSIM epoch:  92
# Testing sample:  83
# The best SSIM through training process: 0.9565991163253784
# The best SSIM epoch:  77
# Testing sample:  84
# The best SSIM through training process: 0.9616888761520386
# The best SSIM epoch:  48
# Testing sample:  85
# The best SSIM through training process: 0.9644525051116943
# The best SSIM epoch:  51
# Testing sample:  86
# The best SSIM through training process: 0.9008312225341797
# The best SSIM epoch:  54
# Testing sample:  87
# The best SSIM through training process: 0.9430662393569946
# The best SSIM epoch:  62
# Testing sample:  88
# The best SSIM through training process: 0.9549520611763
# The best SSIM epoch:  59
# Testing sample:  89
# The best SSIM through training process: 0.9633115530014038
# The best SSIM epoch:  64
# Testing sample:  90
# The best SSIM through training process: 0.9652310609817505
# The best SSIM epoch:  80
# Testing sample:  91
# The best SSIM through training process: 0.9480944275856018
# The best SSIM epoch:  109
# Testing sample:  92
# The best SSIM through training process: 0.9600727558135986
# The best SSIM epoch:  76
# Testing sample:  93
# The best SSIM through training process: 0.9375394582748413
# The best SSIM epoch:  48
# Testing sample:  94
# The best SSIM through training process: 0.9466667771339417
# The best SSIM epoch:  45
# Testing sample:  95
# The best SSIM through training process: 0.9438253045082092
# The best SSIM epoch:  80
# Testing sample:  96
# The best SSIM through training process: 0.9600717425346375
# The best SSIM epoch:  69
# Testing sample:  97
# The best SSIM through training process: 0.9491358995437622
# The best SSIM epoch:  77
# Testing sample:  98
# The best SSIM through training process: 0.9540626406669617
# The best SSIM epoch:  81
# Testing sample:  99
# The best SSIM through training process: 0.9746331572532654
# The best SSIM epoch:  110
# Testing sample:  100
# The best SSIM through training process: 0.9581617116928101
# The best SSIM epoch:  83
# Testing average SSIM loss:  0.9555080515146256
# Testing average SSIM loss epoch:  76.84

# %%
fig, axes = plt.subplots(1, 2, dpi= 400)

axes[0].imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[0].axis('off')

axes[1].imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[1].set_title('Ground Truth')
axes[1].axis('off')

plt.subplots_adjust(wspace=0.1)
plt.show()

# %% [markdown]
# without TTT

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 100it [02:20,  1.40s/it]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.9088788759708405
