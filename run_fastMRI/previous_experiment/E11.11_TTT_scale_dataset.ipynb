# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_rss, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E11.11_sup(l1_1e-5)P_T300_300epoch/E11.11_sup(l1_1e-5)P_T300_300epoch_E150_best.pth'
# '/cheng/metaMRI/metaMRI/save/E11.11_joint(l1_1e-5)P_T300_300epoch/E11.11_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E11.11_sup(l1_1e-5)P_T300_300epoch/E11.11_sup(l1_1e-5)P_T300_300epoch_E300_best.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### without TTT

# %%
# loss_l1_history_=[]
loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_rss(input_kspace, model)

    # gt image no normalization: x
    target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    
    # A†y
    train_inputs = rss_torch(ifft2c(scale_factor * input_kspace))      # [coils,height,width,2] -> [height,width,2]
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )   # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0))
    train_outputs = train_outputs.squeeze(0) # [2, height, width]
    
    # supervised loss [x, fθ(A†y)]
    output_image_1c = complex_abs(torch.moveaxis(train_outputs, 0, -1 )).unsqueeze(0)    # [2, height, width] -> [1, height, width]
    # # normalization
    # output_image_1c = (output_image_1c - output_image_1c.mean()) / output_image_1c.std()
    # output_image_1c *= target_image_1c.std()
    # output_image_1c += target_image_1c.mean()
    # # L1
    # loss_l1 = (l1_loss(output_image_1c, target_image_1c) / torch.sum(torch.abs(target_image_1c))).item()
    
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image_1c = center_crop( target_image_1c, crop_size )
    crop_output_image_1c = center_crop( output_image_1c, crop_size )
    # normalization
    crop_output_image_1c = (crop_output_image_1c - crop_output_image_1c.mean()) / crop_output_image_1c.std()
    crop_output_image_1c *= crop_target_image_1c.std()
    crop_output_image_1c += crop_target_image_1c.mean()
    # SSIM = 1 - loss
    loss_ssim = 1 - ssim_fct(crop_output_image_1c, crop_target_image_1c, data_range = crop_target_image_1c.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 100it [00:41,  2.43it/s]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.8618986350297928

# %% [markdown]
# ### Test-time training

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 50
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_rss(input_kspace, model)
    scale_input_kspace = scale_factor * input_kspace
    
    # gt image by normalized kspace: x
    target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    
    # A†y
    train_inputs = rss_torch(ifft2c(scale_input_kspace))      # [coils,height,width,2] -> [height,width,2]
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )   # [2, height, width]
    
    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))
        model_output = model_output.squeeze(0)      # [2, height, width]       
        # S fθ(A†y) [coils, height, width, channel]
        output_sens_image = complex_mul(torch.moveaxis(model_output.unsqueeze(0), 1, -1 ), sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))
    
        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(torch.moveaxis(model_output, 0, -1 )).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        # # normalization
        # output_image_1c = (output_image_1c - output_image_1c.mean()) / output_image_1c.std()
        # output_image_1c *= target_image_1c.std()
        # output_image_1c += target_image_1c.mean()
        # # L1
        # loss_l1 = (l1_loss(output_image_1c, target_image_1c) / torch.sum(torch.abs(target_image_1c))).item()

        # center crop for SSIM
        crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
        crop_target_image_1c = center_crop( target_image_1c, crop_size )
        crop_output_image_1c = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image_1c = (crop_output_image_1c - crop_output_image_1c.mean()) / crop_output_image_1c.std()
        crop_output_image_1c *= crop_target_image_1c.std()
        crop_output_image_1c += crop_target_image_1c.mean()
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image_1c, crop_target_image_1c, data_range = crop_target_image_1c.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.8797459006309509
# The best SSIM epoch:  1
# Testing sample:  2
# The best SSIM through training process: 0.856252908706665
# The best SSIM epoch:  0
# Testing sample:  3
# The best SSIM through training process: 0.8848729729652405
# The best SSIM epoch:  20
# Testing sample:  4
# The best SSIM through training process: 0.8746867775917053
# The best SSIM epoch:  14
# Testing sample:  5
# The best SSIM through training process: 0.8531181216239929
# The best SSIM epoch:  0
# Testing sample:  6
# The best SSIM through training process: 0.8730610013008118
# The best SSIM epoch:  1
# Testing sample:  7
# The best SSIM through training process: 0.8397634029388428
# The best SSIM epoch:  0
# Testing sample:  8
# The best SSIM through training process: 0.8768767714500427
# The best SSIM epoch:  17
# Testing sample:  9
# The best SSIM through training process: 0.850934624671936
# The best SSIM epoch:  0
# Testing sample:  10
# The best SSIM through training process: 0.8650960922241211
# The best SSIM epoch:  1
# Testing sample:  11
# The best SSIM through training process: 0.859185516834259
# The best SSIM epoch:  18
# Testing sample:  12
# The best SSIM through training process: 0.8808467388153076
# The best SSIM epoch:  7
# Testing sample:  13
# The best SSIM through training process: 0.8528004884719849
# The best SSIM epoch:  0
# Testing sample:  14
# The best SSIM through training process: 0.8598424792289734
# The best SSIM epoch:  0
# Testing sample:  15
# The best SSIM through training process: 0.843776524066925
# The best SSIM epoch:  1
# Testing sample:  16
# The best SSIM through training process: 0.8603318333625793
# The best SSIM epoch:  0
# Testing sample:  17
# The best SSIM through training process: 0.8729864358901978
# The best SSIM epoch:  0
# Testing sample:  18
# The best SSIM through training process: 0.8634142875671387
# The best SSIM epoch:  1
# Testing sample:  19
# The best SSIM through training process: 0.8794549703598022
# The best SSIM epoch:  0
# Testing sample:  20
# The best SSIM through training process: 0.8565891981124878
# The best SSIM epoch:  0
# Testing sample:  21
# The best SSIM through training process: 0.8759868144989014
# The best SSIM epoch:  0
# Testing sample:  22
# The best SSIM through training process: 0.8653918504714966
# The best SSIM epoch:  0
# Testing sample:  23
# The best SSIM through training process: 0.8677302598953247
# The best SSIM epoch:  0
# Testing sample:  24
# The best SSIM through training process: 0.8944045305252075
# The best SSIM epoch:  8
# Testing sample:  25
# The best SSIM through training process: 0.8606417775154114
# The best SSIM epoch:  0
# Testing sample:  26
# The best SSIM through training process: 0.866651177406311
# The best SSIM epoch:  1
# Testing sample:  27
# The best SSIM through training process: 0.8530851006507874
# The best SSIM epoch:  9
# Testing sample:  28
# The best SSIM through training process: 0.8690553307533264
# The best SSIM epoch:  6
# Testing sample:  29
# The best SSIM through training process: 0.859886646270752
# The best SSIM epoch:  0
# Testing sample:  30
# The best SSIM through training process: 0.8540335297584534
# The best SSIM epoch:  0
# Testing sample:  31
# The best SSIM through training process: 0.8597807884216309
# The best SSIM epoch:  49
# Testing sample:  32
# The best SSIM through training process: 0.8622967004776001
# The best SSIM epoch:  0
# Testing sample:  33
# The best SSIM through training process: 0.8533258438110352
# The best SSIM epoch:  0
# Testing sample:  34
# The best SSIM through training process: 0.8518128395080566
# The best SSIM epoch:  0
# Testing sample:  35
# The best SSIM through training process: 0.8959411382675171
# The best SSIM epoch:  2
# Testing sample:  36
# The best SSIM through training process: 0.8612872958183289
# The best SSIM epoch:  0
# Testing sample:  37
# The best SSIM through training process: 0.8729442358016968
# The best SSIM epoch:  1
# Testing sample:  38
# The best SSIM through training process: 0.8727626800537109
# The best SSIM epoch:  3
# Testing sample:  39
# The best SSIM through training process: 0.9050277471542358
# The best SSIM epoch:  8
# Testing sample:  40
# The best SSIM through training process: 0.8900405168533325
# The best SSIM epoch:  5
# Testing sample:  41
# The best SSIM through training process: 0.8645383715629578
# The best SSIM epoch:  47
# Testing sample:  42
# The best SSIM through training process: 0.863996684551239
# The best SSIM epoch:  0
# Testing sample:  43
# The best SSIM through training process: 0.8559839725494385
# The best SSIM epoch:  1
# Testing sample:  44
# The best SSIM through training process: 0.8829851150512695
# The best SSIM epoch:  7
# Testing sample:  45
# The best SSIM through training process: 0.8659183382987976
# The best SSIM epoch:  0
# Testing sample:  46
# The best SSIM through training process: 0.8653115034103394
# The best SSIM epoch:  0
# Testing sample:  47
# The best SSIM through training process: 0.8487071394920349
# The best SSIM epoch:  0
# Testing sample:  48
# The best SSIM through training process: 0.877104640007019
# The best SSIM epoch:  2
# Testing sample:  49
# The best SSIM through training process: 0.8425460457801819
# The best SSIM epoch:  0
# Testing sample:  50
# The best SSIM through training process: 0.8853833079338074
# The best SSIM epoch:  3
# Testing sample:  51
# The best SSIM through training process: 0.8599731922149658
# The best SSIM epoch:  0
# Testing sample:  52
# The best SSIM through training process: 0.8709640502929688
# The best SSIM epoch:  0
# Testing sample:  53
# The best SSIM through training process: 0.8781271576881409
# The best SSIM epoch:  5
# Testing sample:  54
# The best SSIM through training process: 0.8929243087768555
# The best SSIM epoch:  0
# Testing sample:  55
# The best SSIM through training process: 0.8584914207458496
# The best SSIM epoch:  0
# Testing sample:  56
# The best SSIM through training process: 0.8511752486228943
# The best SSIM epoch:  0
# Testing sample:  57
# The best SSIM through training process: 0.8729168176651001
# The best SSIM epoch:  0
# Testing sample:  58
# The best SSIM through training process: 0.8635832071304321
# The best SSIM epoch:  0
# Testing sample:  59
# The best SSIM through training process: 0.8758537769317627
# The best SSIM epoch:  2
# Testing sample:  60
# The best SSIM through training process: 0.8646852374076843
# The best SSIM epoch:  5
# Testing sample:  61
# The best SSIM through training process: 0.8621387481689453
# The best SSIM epoch:  0
# Testing sample:  62
# The best SSIM through training process: 0.8483966588973999
# The best SSIM epoch:  6
# Testing sample:  63
# The best SSIM through training process: 0.8678945899009705
# The best SSIM epoch:  1
# Testing sample:  64
# The best SSIM through training process: 0.8663491606712341
# The best SSIM epoch:  0
# Testing sample:  65
# The best SSIM through training process: 0.8764227032661438
# The best SSIM epoch:  2
# Testing sample:  66
# The best SSIM through training process: 0.8381404876708984
# The best SSIM epoch:  0
# Testing sample:  67
# The best SSIM through training process: 0.8783506155014038
# The best SSIM epoch:  3
# Testing sample:  68
# The best SSIM through training process: 0.8834262490272522
# The best SSIM epoch:  2
# Testing sample:  69
# The best SSIM through training process: 0.8578200340270996
# The best SSIM epoch:  0
# Testing sample:  70
# The best SSIM through training process: 0.8632351756095886
# The best SSIM epoch:  49
# Testing sample:  71
# The best SSIM through training process: 0.8540163636207581
# The best SSIM epoch:  1
# Testing sample:  72
# The best SSIM through training process: 0.8649916052818298
# The best SSIM epoch:  0
# Testing sample:  73
# The best SSIM through training process: 0.8398175835609436
# The best SSIM epoch:  0
# Testing sample:  74
# The best SSIM through training process: 0.8540021777153015
# The best SSIM epoch:  1
# Testing sample:  75
# The best SSIM through training process: 0.8662834167480469
# The best SSIM epoch:  49
# Testing sample:  76
# The best SSIM through training process: 0.8548973202705383
# The best SSIM epoch:  1
# Testing sample:  77
# The best SSIM through training process: 0.8638332486152649
# The best SSIM epoch:  0
# Testing sample:  78
# The best SSIM through training process: 0.8962085247039795
# The best SSIM epoch:  0
# Testing sample:  79
# The best SSIM through training process: 0.8920126557350159
# The best SSIM epoch:  14
# Testing sample:  80
# The best SSIM through training process: 0.8367953300476074
# The best SSIM epoch:  0
# Testing sample:  81
# The best SSIM through training process: 0.8561127781867981
# The best SSIM epoch:  0
# Testing sample:  82
# The best SSIM through training process: 0.8669387102127075
# The best SSIM epoch:  1
# Testing sample:  83
# The best SSIM through training process: 0.8880204558372498
# The best SSIM epoch:  0
# Testing sample:  84
# The best SSIM through training process: 0.8841511011123657
# The best SSIM epoch:  16
# Testing sample:  85
# The best SSIM through training process: 0.8794873952865601
# The best SSIM epoch:  1
# Testing sample:  86
# The best SSIM through training process: 0.8308525681495667
# The best SSIM epoch:  1
# Testing sample:  87
# The best SSIM through training process: 0.8795014023780823
# The best SSIM epoch:  5
# Testing sample:  88
# The best SSIM through training process: 0.8759825229644775
# The best SSIM epoch:  49
# Testing sample:  89
# The best SSIM through training process: 0.8592441082000732
# The best SSIM epoch:  0
# Testing sample:  90
# The best SSIM through training process: 0.8828901052474976
# The best SSIM epoch:  0
# Testing sample:  91
# The best SSIM through training process: 0.8667780756950378
# The best SSIM epoch:  3
# Testing sample:  92
# The best SSIM through training process: 0.8719763159751892
# The best SSIM epoch:  49
# Testing sample:  93
# The best SSIM through training process: 0.8649653792381287
# The best SSIM epoch:  15
# Testing sample:  94
# The best SSIM through training process: 0.8559380173683167
# The best SSIM epoch:  1
# Testing sample:  95
# The best SSIM through training process: 0.8604480028152466
# The best SSIM epoch:  1
# Testing sample:  96
# The best SSIM through training process: 0.8659151196479797
# The best SSIM epoch:  0
# Testing sample:  97
# The best SSIM through training process: 0.8483808636665344
# The best SSIM epoch:  0
# Testing sample:  98
# The best SSIM through training process: 0.8504469394683838
# The best SSIM epoch:  0
# Testing sample:  99
# The best SSIM through training process: 0.8723955750465393
# The best SSIM epoch:  0
# Testing sample:  100
# The best SSIM through training process: 0.8735376596450806
# The best SSIM epoch:  2
# Testing average SSIM loss:  0.8661588913202286
# Testing average SSIM loss epoch:  5.18
