# %% [markdown]
# Plot from tensorboard

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    })

colors = [(0.2298057,0.298717966,0.753683153),
          (0.3634607953411765,0.4847836818509804,0.9010188868941177),
          (0.5108243242509803,0.6493966148235294,0.9850787763764707),
          (0.6672529243333334,0.7791764569999999,0.992959213),
          (0.8049647588235295,0.8516661605568627,0.9261650744313725),
          (0.9193759889058823,0.8312727235294118,0.7828736304470588),
          (0.968203399,0.7208441,0.6122929913333334),
          (0.9440545734235294,0.5531534787490197,0.4355484903137255),
          (0.8523781350078431,0.34649194649411763,0.2803464686980392),
          (0.705673158,0.01555616,0.150232812)]
colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

# %%
plt.figure(dpi=300) #figsize=(6,5)
plt.plot(range(1, 31), train_loss_history, color=colors[0], label='Training on target few-shots')
plt.plot(range(0, 31), test_loss_history_NMSE, color=colors[1], label='Testing on target domain')
plt.scatter(suggest_epoch, test_loss_history_NMSE[suggest_epoch], color=colors[1], s=FONTSIZE, label = 'Early-stopping')
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.title('Few-shots Adaptation', fontsize = FONTSIZE/2)
#plt.yticks(np.arange(0, 0.5, 0.1))
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epoch',fontsize=FONTSIZE/2)
plt.ylabel('NMSE',fontsize=FONTSIZE/2)
plt.grid(True)
# plt.savefig('/cheng/metaMRI/metaMRI/save/plots/'+ experiment_name, format='png', bbox_inches='tight')

# %%
pretrain = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E7.1_standard_200shots_adapt_Q2_seed3-tag-Testing SSIM.csv')
pretrain_appro = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E7.1_standard_200shots_appro_adapt_Q2_seed3-tag-Testing SSIM.csv')
pretrain_few = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E6.4_standard_adapt_Q2_seed3-tag-Testing SSIM.csv')
pretrain_appro_few = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E7.1_standard_appro_adapt_Q2_seed3-tag-Testing SSIM.csv')

plt.figure(figsize=(6,5))
plt.plot(pretrain['Step'], pretrain['Value'], label='Standard 200-shots', color=colors[0])
plt.plot(pretrain_appro['Step'], pretrain_appro['Value'], label='Standard 200-approximate-shots', color=colors[1])
plt.plot(pretrain_few['Step'], pretrain_few['Value'], label='Standard 10-shots', color=colors[2])
plt.plot(pretrain_appro_few['Step'], pretrain_appro_few['Value'], label='Standard 10-approximate-shots', color=colors[3])
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.title('Few-shot and many-shot learning adaptation', fontsize = FONTSIZE/2)
#plt.yticks(np.arange(0, 0.5, 0.1))
plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epoch',fontsize=FONTSIZE/2)
plt.ylabel('SSIM',fontsize=FONTSIZE/2)
plt.grid(True)
# plt.savefig('save/plots/fasterrcnn_v2.png', format='png', bbox_inches='tight')

# %%
maml = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E7.1_maml(1inner)_adapt_Q2_seed1-tag-Testing SSIM.csv')
maml_appro = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E7.1_maml(1inner)_appro_adapt_Q2_seed1-tag-Testing SSIM.csv')
pretrain = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E6.4_standard_adapt_Q2_seed1-tag-Testing SSIM.csv')
pretrain_appro = pd.read_csv('/cheng/metaMRI/metaMRI/save/E7.1/E7.1_standard_appro_adapt_Q2_seed1-tag-Testing SSIM.csv')

plt.figure(figsize=(6,5))
plt.plot(maml['Step'], maml['Value'], label='MAML(E6.3) 10-shots', linewidth=2)
plt.plot(maml_appro['Step'], maml_appro['Value'], label='MAML(E6.3) 10-approximate-shots', linewidth=2)
plt.plot(pretrain['Step'], pretrain['Value'], label='Standard 10-shots', linewidth=2)
plt.plot(pretrain_appro['Step'], pretrain_appro['Value'], label='Standard 10-approximate-shots', linewidth=2)
# plt.rcParams['font.size'] = 12
plt.legend()
#plt.yticks(np.arange(0, 0.5, 0.1))
plt.xlabel('Epoch',fontsize=15)
plt.ylabel('SSIM',fontsize=15)
plt.title('Few-shots Adaptation')
# plt.savefig('save/plots/fasterrcnn_v2.png', format='png', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Few-shots Adaptation')

# %%
maml1 = pd.read_csv('/cheng/metaMRI/metaMRI/save/E6.1/E6.1_adapt_SSIM_mete_Q3-tag-Validation SSIM.csv')
maml2 = pd.read_csv('/cheng/metaMRI/metaMRI/save/E6.1/E6.1_adapt_SSIM_mete_Q3-tag-Validation SSIM1.csv')
maml3 = pd.read_csv('/cheng/metaMRI/metaMRI/save/E6.1/E6.1_adapt_SSIM_meta_Q3-tag-Validation SSIM2.csv')
pretrain1 = pd.read_csv('/cheng/metaMRI/metaMRI/save/E6.1/E6.1_adapt_SSIM_standard_Q3-tag-Validation SSIM.csv')

plt.figure(figsize=(6,5))
plt.plot(maml1['Step'], maml1['Value'], label='MAML 10-shots Adaptation (seed 0)', linewidth=2)
plt.plot(maml2['Step'], maml2['Value'], label='MAML 10-shots Adaptation (seed 1)', linewidth=2)
plt.plot(maml3['Step'], maml3['Value'], label='MAML 10-shots Adaptation (seed 2)', linewidth=2)
plt.plot(pretrain1['Step'], pretrain1['Value'], label='Standard 10-shots Adaptation', linewidth=2)
# plt.rcParams['font.size'] = 12
plt.legend()
#plt.yticks(np.arange(0, 0.5, 0.1))
plt.xlabel('Epoch',fontsize=15)
plt.ylabel('Loss NMSE',fontsize=15)
# plt.savefig('save/plots/fasterrcnn_v2.png', format='png', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Loss NMSE')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = []
data2 = []

for i in range(1,4):
    # read csv
    filename1 = f"/cheng/metaMRI/metaMRI/save/E7.1/E6.4_standard_adapt_Q2_seed{i}-tag-Testing SSIM.csv"
    df1 = pd.read_csv(filename1)
    # extract value
    values1 = df1['Value'].values
    data1.append(values1)
    # read csv
    filename2 = f"/cheng/metaMRI/metaMRI/save/E7.1/E7.1_standard_appro_adapt_Q2_seed{i}-tag-Testing SSIM.csv"
    df2 = pd.read_csv(filename2)
    # extract value
    values2 = df2['Value'].values
    data2.append(values2)

# mean and std
mean_values1 = np.mean(data1, axis=0)
std_values1 = np.std(data1, axis=0)
mean_values2 = np.mean(data2, axis=0)
std_values2 = np.std(data2, axis=0)

# alpha: transparency 
plt.plot(range(0, 31), mean_values1, color='red', label='Standard 10-shots')
plt.fill_between(range(0, 31), mean_values1 - std_values1, mean_values1 + std_values1, color='red', alpha=0.15, edgecolor=None)
plt.plot(range(0, 31), mean_values2, color='blue', label='Standard  10-approximate-shots')
plt.fill_between(range(0, 31), mean_values2 - std_values2, mean_values2 + std_values2, color='blue', alpha=0.15, edgecolor=None)

plt.xlabel('Epochs')
plt.ylabel('SSIM')
plt.title('Few-shots Adaptation')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = []
data2 = []
data3 = []
data4 = []
for i in range(1,4):
    # read csv
    filename1 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.3_maml_adapt_Q1_seed{i}-tag-Testing NMSE.csv"
    df1 = pd.read_csv(filename1)
    # extract value
    values1 = df1['Value'].values
    data1.append(values1)
    # read csv
    filename2 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.4_E6.4_maml_adapt_Q1_seed{i}-tag-Testing NMSE.csv"
    df2 = pd.read_csv(filename2)
    # extract value
    values2 = df2['Value'].values
    data2.append(values2)
    # read csv
    filename3 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.5_E6.5_maml_adapt_Q1_seed{i}-tag-Testing NMSE.csv"
    df3 = pd.read_csv(filename3)
    # extract value
    values3 = df3['Value'].values
    data3.append(values3)
    # read csv
    filename4 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.6_maml_adapt_Q1_seed{i}-tag-Testing NMSE.csv"
    df4 = pd.read_csv(filename4)
    # extract value
    values4 = df4['Value'].values
    data4.append(values4)
    
# mean and std
mean_values1 = np.mean(data1, axis=0)
std_values1 = np.std(data1, axis=0)
mean_values2 = np.mean(data2, axis=0)
std_values2 = np.std(data2, axis=0)
mean_values3 = np.mean(data3, axis=0)
std_values3 = np.std(data3, axis=0)
mean_values4 = np.mean(data4, axis=0)
std_values4 = np.std(data4, axis=0)

# alpha: transparency 
plt.plot(range(0, 31), mean_values1, color='red', label='MAML E6.3')
plt.fill_between(range(0, 31), mean_values1 - std_values1, mean_values1 + std_values1, color='red', alpha=0.15, edgecolor=None)
plt.plot(range(0, 31), mean_values2, color='blue', label='MAML E6.4')
plt.fill_between(range(0, 31), mean_values2 - std_values2, mean_values2 + std_values2, color='blue', alpha=0.15, edgecolor=None)
plt.plot(range(0, 31), mean_values3, color='green', label='MAML E6.5')
plt.fill_between(range(0, 31), mean_values3 - std_values3, mean_values3 + std_values3, color='green', alpha=0.15, edgecolor=None)
plt.plot(range(0, 31), mean_values4, color='orange', label='MAML E6.6')
plt.fill_between(range(0, 31), mean_values4 - std_values4, mean_values4 + std_values4, color='orange', alpha=0.15, edgecolor=None)

plt.xlabel('Epochs')
plt.ylabel('Testing NMSE')
plt.title('Out-of-distribution Q1 Adaptation')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = []
data2 = []

for i in range(1,4):
    # read csv
    filename1 = f"/cheng/metaMRI/metaMRI/save/E6*/run-metaMRI_save_E6__maml_adapt_Q3_seed{i}-tag-Adapt NMSE.csv"
    df1 = pd.read_csv(filename1)
    # extract value
    values1 = df1['Value'].values
    data1.append(values1)
    # read csv
    filename2 = f"/cheng/metaMRI/metaMRI/save/E6*/run-metaMRI_save_E6__standard_adapt_Q3_seed{i}-tag-Adapt NMSE.csv"
    df2 = pd.read_csv(filename2)
    # extract value
    values2 = df2['Value'].values
    data2.append(values2)

    
# mean and std
mean_values1 = np.mean(data1, axis=0)
std_values1 = np.std(data1, axis=0)
mean_values2 = np.mean(data2, axis=0)
std_values2 = np.std(data2, axis=0)

plt.figure(figsize=(6,5))

# alpha: transparency 
plt.plot(range(1, 31), mean_values1, color=colors[0], label='Initialization by MAML (Meta-training)')
plt.fill_between(range(1, 31), mean_values1 - std_values1, mean_values1 + std_values1, color=colors[0], alpha=0.15, edgecolor=None)
plt.plot(range(1, 31), mean_values2, color=colors[1], label='Initialization by standard training')
plt.fill_between(range(1, 31), mean_values2 - std_values2, mean_values2 + std_values2, color=colors[1], alpha=0.15, edgecolor=None)

plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Adaptation NMSE',fontsize=FONTSIZE/2)
plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = []
data2 = []

for i in range(1,4):
    # read csv
    filename1 = f"/cheng/metaMRI/metaMRI/save/E6*/run-metaMRI_save_E6__maml_adapt_Q3_seed{i}-tag-Testing NMSE.csv"
    df1 = pd.read_csv(filename1)
    # extract value
    values1 = df1['Value'].values
    data1.append(values1)
    # read csv
    filename2 = f"/cheng/metaMRI/metaMRI/save/E6*/run-metaMRI_save_E6__standard_adapt_Q3_seed{i}-tag-Testing NMSE.csv"
    df2 = pd.read_csv(filename2)
    # extract value
    values2 = df2['Value'].values
    data2.append(values2)

    
# mean and std
mean_values1 = np.mean(data1, axis=0)
std_values1 = np.std(data1, axis=0)
mean_values2 = np.mean(data2, axis=0)
std_values2 = np.std(data2, axis=0)


plt.figure(figsize=(6,5))

# alpha: transparency 
plt.plot(range(0, 31), mean_values1, color=colors[0], label='Initialization by MAML (Meta-training)')
plt.fill_between(range(0, 31), mean_values1 - std_values1, mean_values1 + std_values1, color=colors[0], alpha=0.15, edgecolor=None)
plt.plot(range(0, 31), mean_values2, color=colors[1], label='Initialization by standard training')
plt.fill_between(range(0, 31), mean_values2 - std_values2, mean_values2 + std_values2, color=colors[1], alpha=0.15, edgecolor=None)

plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Testing NMSE',fontsize=FONTSIZE/2)
plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = []
data2 = []

for i in range(1,4):
    # read csv
    filename1 = f"/cheng/metaMRI/metaMRI/save/E6*/run-metaMRI_save_E6__maml_adapt_Q3_seed{i}-tag-Testing SSIM.csv"
    df1 = pd.read_csv(filename1)
    # extract value
    values1 = df1['Value'].values
    data1.append(values1)
    # read csv
    filename2 = f"/cheng/metaMRI/metaMRI/save/E6*/run-metaMRI_save_E6__standard_adapt_Q3_seed{i}-tag-Testing SSIM.csv"
    df2 = pd.read_csv(filename2)
    # extract value
    values2 = df2['Value'].values
    data2.append(values2)

    
# mean and std
mean_values1 = np.mean(data1, axis=0)
std_values1 = np.std(data1, axis=0)
mean_values2 = np.mean(data2, axis=0)
std_values2 = np.std(data2, axis=0)


plt.figure(figsize=(6,5))

# alpha: transparency 
plt.plot(range(0, 31), mean_values1, color=colors[0], label='Initialization by MAML (Meta-training)')
plt.fill_between(range(0, 31), mean_values1 - std_values1, mean_values1 + std_values1, color=colors[0], alpha=0.15, edgecolor=None)
plt.plot(range(0, 31), mean_values2, color=colors[1], label='Initialization by standard training')
plt.fill_between(range(0, 31), mean_values2 - std_values2, mean_values2 + std_values2, color=colors[1], alpha=0.15, edgecolor=None)

plt.tick_params(axis='both', which='major', labelsize=FONTSIZE/2)
plt.tick_params(axis='both', which='minor', labelsize=(FONTSIZE-2)/2)
plt.xlabel('Epochs',fontsize=FONTSIZE/2)
plt.ylabel('Testing SSIM',fontsize=FONTSIZE/2)
plt.title('Out-of-distribution Q3 Adaptation', fontsize = FONTSIZE/2)
plt.legend(fontsize = (FONTSIZE-3)/2)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = []
data2 = []
data3 = []
data4 = []
for i in range(1,4):
    # read csv
    filename1 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.3_maml_adapt_Q1_seed{i}-tag-Adapt NMSE.csv"
    df1 = pd.read_csv(filename1)
    # extract value
    values1 = df1['Value'].values
    data1.append(values1)
    # read csv
    filename2 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.4_E6.4_maml_adapt_Q1_seed{i}-tag-Adapt NMSE.csv"
    df2 = pd.read_csv(filename2)
    # extract value
    values2 = df2['Value'].values
    data2.append(values2)
    # read csv
    filename3 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.5_E6.5_maml_adapt_Q1_seed{i}-tag-Adapt NMSE.csv"
    df3 = pd.read_csv(filename3)
    # extract value
    values3 = df3['Value'].values
    data3.append(values3)
    # read csv
    filename4 = f"/cheng/metaMRI/metaMRI/save/E6.6/run-metaMRI_save_E6.6_maml_adapt_Q1_seed{i}-tag-Adapt NMSE.csv"
    df4 = pd.read_csv(filename4)
    # extract value
    values4 = df4['Value'].values
    data4.append(values4)
    
# mean and std
mean_values1 = np.mean(data1, axis=0)
std_values1 = np.std(data1, axis=0)
mean_values2 = np.mean(data2, axis=0)
std_values2 = np.std(data2, axis=0)
mean_values3 = np.mean(data3, axis=0)
std_values3 = np.std(data3, axis=0)
mean_values4 = np.mean(data4, axis=0)
std_values4 = np.std(data4, axis=0)

# alpha: transparency 
plt.plot(range(0, 30), mean_values1, color='red', label='MAML E6.3')
plt.fill_between(range(0, 30), mean_values1 - std_values1, mean_values1 + std_values1, color='red', alpha=0.15, edgecolor=None)
plt.plot(range(0, 30), mean_values2, color='blue', label='MAML E6.4')
plt.fill_between(range(0, 30), mean_values2 - std_values2, mean_values2 + std_values2, color='blue', alpha=0.15, edgecolor=None)
plt.plot(range(0, 30), mean_values3, color='green', label='MAML E6.5')
plt.fill_between(range(0, 30), mean_values3 - std_values3, mean_values3 + std_values3, color='green', alpha=0.15, edgecolor=None)
plt.plot(range(0, 30), mean_values4, color='orange', label='MAML E6.6')
plt.fill_between(range(0, 30), mean_values4 - std_values4, mean_values4 + std_values4, color='orange', alpha=0.15, edgecolor=None)

plt.xlabel('Epochs')
plt.ylabel('Adapt NMSE')
plt.title('Out-of-distribution Q1 Adaptation')
plt.legend()
plt.show()

# %%
len(mean_values1)
# Out:
# 31

# %%
import math
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
import torchvision.models as models


model = models.resnet18(pretrained=False)

optimizer = optim.SGD(model.parameters(), lr=0.001)

total_iterations = 200
initial_lr = 0.001

scheduler = CosineAnnealingLR(optimizer, total_iterations/1, eta_min=0.0001, last_epoch=-1)

lr = []
for iteration in range(total_iterations):
    
    scheduler.step()
    
    current_lr = optimizer.param_groups[0]['lr']
    lr.append(current_lr)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# ...

# %%
#plt.figure(figsize=(6,5))
plt.figure(figsize=(6,5))
plt.plot(list(range(1, len(lr)+1)), lr, label='cosine annealing lr', linewidth=2)
plt.legend()
plt.yticks([i * 0.0001 for i in range(11)])
plt.xlabel('Epoch',fontsize=15)
plt.ylabel('Learning rate',fontsize=15)
# plt.savefig('save/plots/fasterrcnn_v2.png', format='png', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Learning rate')
