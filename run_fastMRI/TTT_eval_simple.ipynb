# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/testinggggggggggggggggg/testinggggggggggggggggg_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = False
eval_with_binary_mask = False

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )
    train_inputs, mean, std = normalize_separate_over_ch(train_inputs, eps=1e-11)
    
    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = model_output.squeeze(0) * std + mean
        model_output = model_output.unsqueeze(0)
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]

        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, input_kspace) / torch.sum(torch.abs(input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9440407752990723
# The best SSIM epoch:  104
# Testing sample:  2
# The best SSIM through training process: 0.9015007615089417
# The best SSIM epoch:  63
# Testing sample:  3
# The best SSIM through training process: 0.9383485913276672
# The best SSIM epoch:  91
# Testing sample:  4
# The best SSIM through training process: 0.9355271458625793
# The best SSIM epoch:  131
# Testing sample:  5
# The best SSIM through training process: 0.9364864826202393
# The best SSIM epoch:  83
# Testing sample:  6
# The best SSIM through training process: 0.933032751083374
# The best SSIM epoch:  95
# Testing sample:  7
# The best SSIM through training process: 0.9258478283882141
# The best SSIM epoch:  82
# Testing sample:  8
# The best SSIM through training process: 0.9237394332885742
# The best SSIM epoch:  57
# Testing sample:  9
# The best SSIM through training process: 0.9332450032234192
# The best SSIM epoch:  82
# Testing sample:  10
# The best SSIM through training process: 0.9353930950164795
# The best SSIM epoch:  64
# Testing sample:  11
# The best SSIM through training process: 0.9311531782150269
# The best SSIM epoch:  123
# Testing sample:  12
# The best SSIM through training process: 0.9343255162239075
# The best SSIM epoch:  108
# Testing sample:  13
# The best SSIM through training process: 0.9437639713287354
# The best SSIM epoch:  99
# Testing sample:  14
# The best SSIM through training process: 0.9402032494544983
# The best SSIM epoch:  145
# Testing sample:  15
# The best SSIM through training process: 0.9296702742576599
# The best SSIM epoch:  72
# Testing sample:  16
# The best SSIM through training process: 0.9416704177856445
# The best SSIM epoch:  103
# Testing sample:  17
# The best SSIM through training process: 0.9396284818649292
# The best SSIM epoch:  81
# Testing sample:  18
# The best SSIM through training process: 0.9320170879364014
# The best SSIM epoch:  64
# Testing sample:  19
# The best SSIM through training process: 0.9421084523200989
# The best SSIM epoch:  73
# Testing sample:  20
# The best SSIM through training process: 0.9453601837158203
# The best SSIM epoch:  113
# Testing sample:  21
# The best SSIM through training process: 0.9461718797683716
# The best SSIM epoch:  93
# Testing sample:  22
# The best SSIM through training process: 0.9410917162895203
# The best SSIM epoch:  62
# Testing sample:  23
# The best SSIM through training process: 0.9432229399681091
# The best SSIM epoch:  81
# Testing sample:  24
# The best SSIM through training process: 0.9399241209030151
# The best SSIM epoch:  115
# Testing sample:  25
# The best SSIM through training process: 0.935809314250946
# The best SSIM epoch:  80
# Testing sample:  26
# The best SSIM through training process: 0.9390047788619995
# The best SSIM epoch:  79
# Testing sample:  27
# The best SSIM through training process: 0.9269071817398071
# The best SSIM epoch:  97
# Testing sample:  28
# The best SSIM through training process: 0.9300675988197327
# The best SSIM epoch:  74
# Testing sample:  29
# The best SSIM through training process: 0.9373640418052673
# The best SSIM epoch:  100
# Testing sample:  30
# The best SSIM through training process: 0.91621333360672
# The best SSIM epoch:  51
# Testing sample:  31
# The best SSIM through training process: 0.9203316569328308
# The best SSIM epoch:  99
# Testing sample:  32
# The best SSIM through training process: 0.9269675016403198
# The best SSIM epoch:  78
# Testing sample:  33
# The best SSIM through training process: 0.9349507093429565
# The best SSIM epoch:  109
# Testing sample:  34
# The best SSIM through training process: 0.9401660561561584
# The best SSIM epoch:  89
# Testing sample:  35
# The best SSIM through training process: 0.9458619356155396
# The best SSIM epoch:  69
# Testing sample:  36
# The best SSIM through training process: 0.9369199275970459
# The best SSIM epoch:  57
# Testing sample:  37
# The best SSIM through training process: 0.9402570724487305
# The best SSIM epoch:  50
# Testing sample:  38
# The best SSIM through training process: 0.9307780861854553
# The best SSIM epoch:  90
# Testing sample:  39
# The best SSIM through training process: 0.941582441329956
# The best SSIM epoch:  170
# Testing sample:  40
# The best SSIM through training process: 0.94046950340271
# The best SSIM epoch:  110
# Testing sample:  41
# The best SSIM through training process: 0.9347311854362488
# The best SSIM epoch:  110
# Testing sample:  42
# The best SSIM through training process: 0.934497594833374
# The best SSIM epoch:  83
# Testing sample:  43
# The best SSIM through training process: 0.9333591461181641
# The best SSIM epoch:  58
# Testing sample:  44
# The best SSIM through training process: 0.9368064999580383
# The best SSIM epoch:  85
# Testing sample:  45
# The best SSIM through training process: 0.9396368861198425
# The best SSIM epoch:  120
# Testing sample:  46
# The best SSIM through training process: 0.9140064120292664
# The best SSIM epoch:  78
# Testing sample:  47
# The best SSIM through training process: 0.944085955619812
# The best SSIM epoch:  126
# Testing sample:  48
# The best SSIM through training process: 0.9277318716049194
# The best SSIM epoch:  47
# Testing sample:  49
# The best SSIM through training process: 0.8831909894943237
# The best SSIM epoch:  41
# Testing sample:  50
# The best SSIM through training process: 0.9360682964324951
# The best SSIM epoch:  55
# Testing sample:  51
# The best SSIM through training process: 0.9330595135688782
# The best SSIM epoch:  115
# Testing sample:  52
# The best SSIM through training process: 0.9314213991165161
# The best SSIM epoch:  88
# Testing sample:  53
# The best SSIM through training process: 0.9350010752677917
# The best SSIM epoch:  106
# Testing sample:  54
# The best SSIM through training process: 0.9587017297744751
# The best SSIM epoch:  113
# Testing sample:  55
# The best SSIM through training process: 0.9384827017784119
# The best SSIM epoch:  79
# Testing sample:  56
# The best SSIM through training process: 0.9368760585784912
# The best SSIM epoch:  121
# Testing sample:  57
# The best SSIM through training process: 0.9452044367790222
# The best SSIM epoch:  76
# Testing sample:  58
# The best SSIM through training process: 0.9334633946418762
# The best SSIM epoch:  70
# Testing sample:  59
# The best SSIM through training process: 0.9455814957618713
# The best SSIM epoch:  99
# Testing sample:  60
# The best SSIM through training process: 0.917656660079956
# The best SSIM epoch:  74
# Testing sample:  61
# The best SSIM through training process: 0.9409545063972473
# The best SSIM epoch:  97
# Testing sample:  62
# The best SSIM through training process: 0.923499345779419
# The best SSIM epoch:  108
# Testing sample:  63
# The best SSIM through training process: 0.9307036399841309
# The best SSIM epoch:  51
# Testing sample:  64
# The best SSIM through training process: 0.937867283821106
# The best SSIM epoch:  106
# Testing sample:  65
# The best SSIM through training process: 0.9404456615447998
# The best SSIM epoch:  82
# Testing sample:  66
# The best SSIM through training process: 0.9478455781936646
# The best SSIM epoch:  142
# Testing sample:  67
# The best SSIM through training process: 0.9300516247749329
# The best SSIM epoch:  64
# Testing sample:  68
# The best SSIM through training process: 0.9334918856620789
# The best SSIM epoch:  86
# Testing sample:  69
# The best SSIM through training process: 0.9365202784538269
# The best SSIM epoch:  109
# Testing sample:  70
# The best SSIM through training process: 0.935347855091095
# The best SSIM epoch:  126
# Testing sample:  71
# The best SSIM through training process: 0.9246629476547241
# The best SSIM epoch:  51
# Testing sample:  72
# Epoch 174/500, SSIM: 0.9342
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /cheng/metaMRI/metaMRI/run_fastMRI/TTT_eval_test.ipynb Cell 10 line 7
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7079746f7263685943222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6770756d6c7032227d7d/cheng/metaMRI/metaMRI/run_fastMRI/TTT_eval_test.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a> optimizer.step()
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7079746f7263685943222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6770756d6c7032227d7d/cheng/metaMRI/metaMRI/run_fastMRI/TTT_eval_test.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=72'>73</a> #train_loss += loss.item()
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7079746f7263685943222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6770756d6c7032227d7d/cheng/metaMRI/metaMRI/run_fastMRI/TTT_eval_test.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=73'>74</a> #print('TTT loss: ',loss_self.item())
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7079746f7263685943222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6770756d6c7032227d7d/cheng/metaMRI/metaMRI/run_fastMRI/TTT_eval_test.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=74'>75</a> self_loss_history.append(loss_self.item())
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7079746f7263685943222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6770756d6c7032227d7d/cheng/metaMRI/metaMRI/run_fastMRI/TTT_eval_test.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=76'>77</a> ###### evaluation ######
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7079746f7263685943222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6770756d6c7032227d7d/cheng/metaMRI/metaMRI/run_fastMRI/TTT_eval_test.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=77'>78</a> output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
#
# KeyboardInterrupt:
