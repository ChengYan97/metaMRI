# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_rss, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E11.11_joint(l1_1e-5)Q_T300_300epoch/E11.11_joint(l1_1e-5)Q_T300_300epoch_E150_best.pth'
# '/cheng/metaMRI/metaMRI/save/E11.11_joint(l1_1e-5)P_T300_300epoch/E11.11_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E11.11_sup(l1_1e-5)P_T300_300epoch/E11.11_sup(l1_1e-5)P_T300_300epoch_E300_best.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### without TTT

# %%
# loss_l1_history_=[]
loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_rss(input_kspace, model)

    # gt image no normalization: x
    target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()
    
    # A†y
    train_inputs = rss_torch(ifft2c(scale_factor * input_kspace))      # [coils,height,width,2] -> [height,width,2]
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )   # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0))
    train_outputs = train_outputs.squeeze(0) # [2, height, width]
    
    # supervised loss [x, fθ(A†y)]
    output_image_1c = complex_abs(torch.moveaxis(train_outputs, 0, -1 )).unsqueeze(0)    # [2, height, width] -> [1, height, width]
    # # normalization
    # output_image_1c = (output_image_1c - output_image_1c.mean()) / output_image_1c.std()
    # output_image_1c *= target_image_1c.std()
    # output_image_1c += target_image_1c.mean()
    # # L1
    # loss_l1 = (l1_loss(output_image_1c, target_image_1c) / torch.sum(torch.abs(target_image_1c))).item()
    
    # center crop for SSIM
    crop_output_image = center_crop( output_image_1c, crop_size )
    # normalization
    crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
    crop_output_image *= std_crop_target_image
    crop_output_image += mean_crop_target_image
    # SSIM = 1 - loss
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 0it [00:00, ?it/s]
# 100it [01:46,  1.06s/it]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.7617029982805252

# %% [markdown]
# ### Test-time training

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 1500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    
    # input k space
    input_kspace = kspace * mask + 0.0
    # scale factor
    scale_factor = scale_rss(input_kspace, model)
    scale_input_kspace = scale_factor * input_kspace

    # gt image by normalized kspace: x
    target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    train_inputs = rss_torch(ifft2c(scale_input_kspace))      # [coils,height,width,2] -> [height,width,2]
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )   # [2, height, width]
    
    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))
        model_output = model_output.squeeze(0)      # [2, height, width]       
        # S fθ(A†y) [coils, height, width, channel]
        output_sens_image = complex_mul(torch.moveaxis(model_output.unsqueeze(0), 1, -1 ), sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))
    
        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(torch.moveaxis(model_output, 0, -1 )).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        # center crop for SSIM
        crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9316768646240234
# The best SSIM epoch:  636
# Testing sample:  2
# The best SSIM through training process: 0.9039599895477295
# The best SSIM epoch:  1
# Testing sample:  3
# The best SSIM through training process: 0.9216189384460449
# The best SSIM epoch:  955
# Testing sample:  4
# The best SSIM through training process: 0.9248992204666138
# The best SSIM epoch:  3
# Testing sample:  5
# The best SSIM through training process: 0.9181883931159973
# The best SSIM epoch:  771
# Testing sample:  6
# The best SSIM through training process: 0.9231136441230774
# The best SSIM epoch:  1494
# Testing sample:  7
# The best SSIM through training process: 0.9077100157737732
# The best SSIM epoch:  484
# Testing sample:  8
# The best SSIM through training process: 0.9014263153076172
# The best SSIM epoch:  1029
# Testing sample:  9
# The best SSIM through training process: 0.9101821780204773
# The best SSIM epoch:  1450
# Testing sample:  10
# The best SSIM through training process: 0.9205776453018188
# The best SSIM epoch:  1487
# Testing sample:  11
# The best SSIM through training process: 0.9179267883300781
# The best SSIM epoch:  555
# Testing sample:  12
# The best SSIM through training process: 0.926925539970398
# The best SSIM epoch:  701
# Testing sample:  13
# The best SSIM through training process: 0.9259369969367981
# The best SSIM epoch:  1014
# Testing sample:  14
# The best SSIM through training process: 0.9317785501480103
# The best SSIM epoch:  0
# Testing sample:  15
# The best SSIM through training process: 0.9131552577018738
# The best SSIM epoch:  4
# Testing sample:  16
# The best SSIM through training process: 0.9251869916915894
# The best SSIM epoch:  0
# Testing sample:  17
# The best SSIM through training process: 0.9146108627319336
# The best SSIM epoch:  0
# Testing sample:  18
# The best SSIM through training process: 0.9077432751655579
# The best SSIM epoch:  669
# Testing sample:  19
# The best SSIM through training process: 0.917149543762207
# The best SSIM epoch:  658
# Testing sample:  20
# The best SSIM through training process: 0.9330957531929016
# The best SSIM epoch:  3
# Testing sample:  21
# The best SSIM through training process: 0.928286075592041
# The best SSIM epoch:  0
# Testing sample:  22
# The best SSIM through training process: 0.9091184139251709
# The best SSIM epoch:  945
# Testing sample:  23
# The best SSIM through training process: 0.9250838756561279
# The best SSIM epoch:  0
# Testing sample:  24
# The best SSIM through training process: 0.9248199462890625
# The best SSIM epoch:  2
# Testing sample:  25
# The best SSIM through training process: 0.9280693531036377
# The best SSIM epoch:  1006
# Testing sample:  26
# The best SSIM through training process: 0.9311826229095459
# The best SSIM epoch:  1282
# Testing sample:  27
# The best SSIM through training process: 0.9150363802909851
# The best SSIM epoch:  810
# Testing sample:  28
# The best SSIM through training process: 0.9206045866012573
# The best SSIM epoch:  1479
# Testing sample:  29
# The best SSIM through training process: 0.9237744808197021
# The best SSIM epoch:  0
# Testing sample:  30
# The best SSIM through training process: 0.8959494233131409
# The best SSIM epoch:  0
# Testing sample:  31
# The best SSIM through training process: 0.9120297431945801
# The best SSIM epoch:  681
# Testing sample:  32
# The best SSIM through training process: 0.9172707200050354
# The best SSIM epoch:  819
# Testing sample:  33
# The best SSIM through training process: 0.9160879254341125
# The best SSIM epoch:  1405
# Testing sample:  34
# The best SSIM through training process: 0.9069026708602905
# The best SSIM epoch:  1
# Testing sample:  35
# The best SSIM through training process: 0.9247370362281799
# The best SSIM epoch:  728
# Testing sample:  36
# The best SSIM through training process: 0.909827470779419
# The best SSIM epoch:  1471
# Testing sample:  37
# The best SSIM through training process: 0.905476987361908
# The best SSIM epoch:  822
# Testing sample:  38
# The best SSIM through training process: 0.9216311573982239
# The best SSIM epoch:  1374
# Testing sample:  39
# The best SSIM through training process: 0.9158982634544373
# The best SSIM epoch:  45
# Testing sample:  40
# The best SSIM through training process: 0.9345474243164062
# The best SSIM epoch:  1106
# Testing sample:  41
# The best SSIM through training process: 0.9125577807426453
# The best SSIM epoch:  605
# Testing sample:  42
# The best SSIM through training process: 0.9193772077560425
# The best SSIM epoch:  667
# Testing sample:  43
# The best SSIM through training process: 0.9062486886978149
# The best SSIM epoch:  436
# Testing sample:  44
# The best SSIM through training process: 0.9284499287605286
# The best SSIM epoch:  528
# Testing sample:  45
# The best SSIM through training process: 0.9292215704917908
# The best SSIM epoch:  3
# Testing sample:  46
# The best SSIM through training process: 0.9071165323257446
# The best SSIM epoch:  0
# Testing sample:  47
# The best SSIM through training process: 0.9298076033592224
# The best SSIM epoch:  0
# Testing sample:  48
# The best SSIM through training process: 0.9086236953735352
# The best SSIM epoch:  972
# Testing sample:  49
# The best SSIM through training process: 0.8669753670692444
# The best SSIM epoch:  0
# Testing sample:  50
# The best SSIM through training process: 0.9222001433372498
# The best SSIM epoch:  993
# Testing sample:  51
# The best SSIM through training process: 0.9166398048400879
# The best SSIM epoch:  0
# Testing sample:  52
# The best SSIM through training process: 0.9085713028907776
# The best SSIM epoch:  11
# Testing sample:  53
# The best SSIM through training process: 0.9248319864273071
# The best SSIM epoch:  1495
# Testing sample:  54
# The best SSIM through training process: 0.948206901550293
# The best SSIM epoch:  0
# Testing sample:  55
# The best SSIM through training process: 0.9230747818946838
# The best SSIM epoch:  825
# Testing sample:  56
# The best SSIM through training process: 0.9212953448295593
# The best SSIM epoch:  0
# Testing sample:  57
# The best SSIM through training process: 0.9255290627479553
# The best SSIM epoch:  1145
# Testing sample:  58
# The best SSIM through training process: 0.9159435033798218
# The best SSIM epoch:  0
# Testing sample:  59
# The best SSIM through training process: 0.9362484812736511
# The best SSIM epoch:  1
# Testing sample:  60
# The best SSIM through training process: 0.9095872640609741
# The best SSIM epoch:  794
# Testing sample:  61
# The best SSIM through training process: 0.9213206171989441
# The best SSIM epoch:  2
# Testing sample:  62
# The best SSIM through training process: 0.9098140597343445
# The best SSIM epoch:  940
# Testing sample:  63
# The best SSIM through training process: 0.909591555595398
# The best SSIM epoch:  601
# Testing sample:  64
# The best SSIM through training process: 0.9215267896652222
# The best SSIM epoch:  0
# Testing sample:  65
# The best SSIM through training process: 0.9232081174850464
# The best SSIM epoch:  0
# Testing sample:  66
# The best SSIM through training process: 0.9347564578056335
# The best SSIM epoch:  875
# Testing sample:  67
# The best SSIM through training process: 0.9158278107643127
# The best SSIM epoch:  769
# Testing sample:  68
# The best SSIM through training process: 0.9217728972434998
# The best SSIM epoch:  890
# Testing sample:  69
# The best SSIM through training process: 0.9214460253715515
# The best SSIM epoch:  1281
# Testing sample:  70
# The best SSIM through training process: 0.9213199615478516
# The best SSIM epoch:  978
# Testing sample:  71
# The best SSIM through training process: 0.8936596512794495
# The best SSIM epoch:  741
# Testing sample:  72
# The best SSIM through training process: 0.9271275401115417
# The best SSIM epoch:  440
# Testing sample:  73
# The best SSIM through training process: 0.8758284449577332
# The best SSIM epoch:  546
# Testing sample:  74
# The best SSIM through training process: 0.9108256697654724
# The best SSIM epoch:  1447
# Testing sample:  75
# The best SSIM through training process: 0.9107842445373535
# The best SSIM epoch:  856
# Testing sample:  76
# The best SSIM through training process: 0.9154016971588135
# The best SSIM epoch:  2
# Testing sample:  77
# The best SSIM through training process: 0.921158492565155
# The best SSIM epoch:  6
# Testing sample:  78
# The best SSIM through training process: 0.9387825131416321
# The best SSIM epoch:  613
# Testing sample:  79
# The best SSIM through training process: 0.9256628155708313
# The best SSIM epoch:  644
# Testing sample:  80
# The best SSIM through training process: 0.8944534063339233
# The best SSIM epoch:  0
# Testing sample:  81
# The best SSIM through training process: 0.9157169461250305
# The best SSIM epoch:  1223
# Testing sample:  82
# The best SSIM through training process: 0.9102069139480591
# The best SSIM epoch:  3
# Testing sample:  83
# The best SSIM through training process: 0.9281284213066101
# The best SSIM epoch:  737
# Testing sample:  84
# The best SSIM through training process: 0.922304093837738
# The best SSIM epoch:  529
# Testing sample:  85
# The best SSIM through training process: 0.920403003692627
# The best SSIM epoch:  672
# Testing sample:  86
# The best SSIM through training process: 0.8518993854522705
# The best SSIM epoch:  5
# Testing sample:  87
# The best SSIM through training process: 0.9076432585716248
# The best SSIM epoch:  1326
# Testing sample:  88
# The best SSIM through training process: 0.9162158966064453
# The best SSIM epoch:  1270
# Testing sample:  89
# The best SSIM through training process: 0.9206430315971375
# The best SSIM epoch:  651
# Testing sample:  90
# The best SSIM through training process: 0.931463897228241
# The best SSIM epoch:  5
# Testing sample:  91
# The best SSIM through training process: 0.906088650226593
# The best SSIM epoch:  1419
# Testing sample:  92
# The best SSIM through training process: 0.9279435873031616
# The best SSIM epoch:  1023
# Testing sample:  93
# The best SSIM through training process: 0.8997750282287598
# The best SSIM epoch:  808
# Testing sample:  94
# The best SSIM through training process: 0.9096464514732361
# The best SSIM epoch:  1467
# Testing sample:  95
# The best SSIM through training process: 0.9052949547767639
# The best SSIM epoch:  1004
# Testing sample:  96
# The best SSIM through training process: 0.9301355481147766
# The best SSIM epoch:  691
# Testing sample:  97
# The best SSIM through training process: 0.9096373915672302
# The best SSIM epoch:  0
# Testing sample:  98
# The best SSIM through training process: 0.9289995431900024
# The best SSIM epoch:  1325
# Testing sample:  99
# The best SSIM through training process: 0.9279374480247498
# The best SSIM epoch:  0
# Testing sample:  100
# The best SSIM through training process: 0.9180688261985779
# The best SSIM epoch:  1481
# Testing average SSIM loss:  0.9170612531900406
# Testing average SSIM loss epoch:  616.35
