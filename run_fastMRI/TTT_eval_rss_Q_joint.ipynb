# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_rss, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/thesis/revisit_TTT/reproduce/ttt_paper/E_tttpaper_rss_joint(l1_1e-5)Q_T300_300epoch/E_tttpaper_rss_joint(l1_1e-5)Q_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 2000
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_rss(input_kspace, model)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = rss_torch(complex_abs(ifft2c(origk))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = rss_torch(ifft2c(scale_input_kspace))    
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9151804447174072
# The best SSIM epoch:  503
# Testing sample:  2
# The best SSIM through training process: 0.8458361625671387
# The best SSIM epoch:  1
# Testing sample:  3
# The best SSIM through training process: 0.9108821749687195
# The best SSIM epoch:  153
# Testing sample:  4
# The best SSIM through training process: 0.9214189052581787
# The best SSIM epoch:  264
# Testing sample:  5
# The best SSIM through training process: 0.8669397234916687
# The best SSIM epoch:  1726
# Testing sample:  6
# The best SSIM through training process: 0.8967165350914001
# The best SSIM epoch:  488
# Testing sample:  7
# The best SSIM through training process: 0.8698624968528748
# The best SSIM epoch:  1574
# Testing sample:  8
# The best SSIM through training process: 0.8889243602752686
# The best SSIM epoch:  101
# Testing sample:  9
# The best SSIM through training process: 0.8808248043060303
# The best SSIM epoch:  694
# Testing sample:  10
# The best SSIM through training process: 0.8865605592727661
# The best SSIM epoch:  434
# Testing sample:  11
# The best SSIM through training process: 0.9066544771194458
# The best SSIM epoch:  248
# Testing sample:  12
# The best SSIM through training process: 0.919350266456604
# The best SSIM epoch:  241
# Testing sample:  13
# The best SSIM through training process: 0.8792001605033875
# The best SSIM epoch:  1301
# Testing sample:  14
# The best SSIM through training process: 0.889837920665741
# The best SSIM epoch:  1629
# Testing sample:  15
# The best SSIM through training process: 0.8800252676010132
# The best SSIM epoch:  834
# Testing sample:  16
# The best SSIM through training process: 0.8948395848274231
# The best SSIM epoch:  1666
# Testing sample:  17
# The best SSIM through training process: 0.8652291297912598
# The best SSIM epoch:  1
# Testing sample:  18
# The best SSIM through training process: 0.8737757205963135
# The best SSIM epoch:  406
# Testing sample:  19
# The best SSIM through training process: 0.8884438872337341
# The best SSIM epoch:  1282
# Testing sample:  20
# The best SSIM through training process: 0.9156584143638611
# The best SSIM epoch:  1136
# Testing sample:  21
# The best SSIM through training process: 0.9032289981842041
# The best SSIM epoch:  1177
# Testing sample:  22
# The best SSIM through training process: 0.877104640007019
# The best SSIM epoch:  491
# Testing sample:  23
# The best SSIM through training process: 0.8853024840354919
# The best SSIM epoch:  1743
# Testing sample:  24
# The best SSIM through training process: 0.9285157918930054
# The best SSIM epoch:  220
# Testing sample:  25
# The best SSIM through training process: 0.888205885887146
# The best SSIM epoch:  754
# Testing sample:  26
# The best SSIM through training process: 0.8955992460250854
# The best SSIM epoch:  663
# Testing sample:  27
# The best SSIM through training process: 0.9002112150192261
# The best SSIM epoch:  260
# Testing sample:  28
# The best SSIM through training process: 0.903137743473053
# The best SSIM epoch:  237
# Testing sample:  29
# The best SSIM through training process: 0.9131834506988525
# The best SSIM epoch:  398
# Testing sample:  30
# The best SSIM through training process: 0.856249213218689
# The best SSIM epoch:  1122
# Testing sample:  31
# The best SSIM through training process: 0.895697832107544
# The best SSIM epoch:  223
# Testing sample:  32
# The best SSIM through training process: 0.8701151609420776
# The best SSIM epoch:  998
# Testing sample:  33
# The best SSIM through training process: 0.8744516372680664
# The best SSIM epoch:  1334
# Testing sample:  34
# The best SSIM through training process: 0.8618512153625488
# The best SSIM epoch:  1631
# Testing sample:  35
# The best SSIM through training process: 0.9091580510139465
# The best SSIM epoch:  386
# Testing sample:  36
# The best SSIM through training process: 0.8735120892524719
# The best SSIM epoch:  501
# Testing sample:  37
# The best SSIM through training process: 0.876232385635376
# The best SSIM epoch:  510
# Testing sample:  38
# The best SSIM through training process: 0.9001890420913696
# The best SSIM epoch:  380
# Testing sample:  39
# The best SSIM through training process: 0.9319857954978943
# The best SSIM epoch:  238
# Testing sample:  40
# The best SSIM through training process: 0.9262681007385254
# The best SSIM epoch:  227
# Testing sample:  41
# The best SSIM through training process: 0.9084847569465637
# The best SSIM epoch:  218
# Testing sample:  42
# The best SSIM through training process: 0.8648005127906799
# The best SSIM epoch:  1210
# Testing sample:  43
# The best SSIM through training process: 0.867319643497467
# The best SSIM epoch:  5
# Testing sample:  44
# The best SSIM through training process: 0.9167839884757996
# The best SSIM epoch:  228
# Testing sample:  45
# The best SSIM through training process: 0.9034323692321777
# The best SSIM epoch:  1218
# Testing sample:  46
# The best SSIM through training process: 0.8583009243011475
# The best SSIM epoch:  1
# Testing sample:  47
# The best SSIM through training process: 0.9028544425964355
# The best SSIM epoch:  1807
# Testing sample:  48
# The best SSIM through training process: 0.8712437748908997
# The best SSIM epoch:  3
# Testing sample:  49
# The best SSIM through training process: 0.8352000117301941
# The best SSIM epoch:  1
# Testing sample:  50
# The best SSIM through training process: 0.8921107053756714
# The best SSIM epoch:  231
# Testing sample:  51
# The best SSIM through training process: 0.8781160712242126
# The best SSIM epoch:  1432
# Testing sample:  52
# The best SSIM through training process: 0.8525229096412659
# The best SSIM epoch:  1
# Testing sample:  53
# The best SSIM through training process: 0.9160482883453369
# The best SSIM epoch:  282
# Testing sample:  54
# The best SSIM through training process: 0.9451130032539368
# The best SSIM epoch:  385
# Testing sample:  55
# The best SSIM through training process: 0.8854909539222717
# The best SSIM epoch:  787
# Testing sample:  56
# The best SSIM through training process: 0.8763059377670288
# The best SSIM epoch:  1420
# Testing sample:  57
# The best SSIM through training process: 0.9007930755615234
# The best SSIM epoch:  731
# Testing sample:  58
# The best SSIM through training process: 0.8553248643875122
# The best SSIM epoch:  1
# Testing sample:  59
# The best SSIM through training process: 0.9232631921768188
# The best SSIM epoch:  405
# Testing sample:  60
# The best SSIM through training process: 0.8897994756698608
# The best SSIM epoch:  218
# Testing sample:  61
# The best SSIM through training process: 0.9087363481521606
# The best SSIM epoch:  371
# Testing sample:  62
# The best SSIM through training process: 0.9040216207504272
# The best SSIM epoch:  228
# Testing sample:  63
# The best SSIM through training process: 0.8646694421768188
# The best SSIM epoch:  808
# Testing sample:  64
# The best SSIM through training process: 0.8884901404380798
# The best SSIM epoch:  1016
# Testing sample:  65
# The best SSIM through training process: 0.9144355058670044
# The best SSIM epoch:  235
# Testing sample:  66
# The best SSIM through training process: 0.9237048029899597
# The best SSIM epoch:  740
# Testing sample:  67
# The best SSIM through training process: 0.8863511085510254
# The best SSIM epoch:  386
# Testing sample:  68
# The best SSIM through training process: 0.905507504940033
# The best SSIM epoch:  392
# Testing sample:  69
# The best SSIM through training process: 0.8849784731864929
# The best SSIM epoch:  837
# Testing sample:  70
# The best SSIM through training process: 0.9071640968322754
# The best SSIM epoch:  298
# Testing sample:  71
# The best SSIM through training process: 0.854781448841095
# The best SSIM epoch:  378
# Testing sample:  72
# The best SSIM through training process: 0.8985579013824463
# The best SSIM epoch:  566
# Testing sample:  73
# The best SSIM through training process: 0.8409982323646545
# The best SSIM epoch:  1301
# Testing sample:  74
# The best SSIM through training process: 0.8753826022148132
# The best SSIM epoch:  647
# Testing sample:  75
# The best SSIM through training process: 0.892126739025116
# The best SSIM epoch:  180
# Testing sample:  76
# The best SSIM through training process: 0.9004545211791992
# The best SSIM epoch:  567
# Testing sample:  77
# The best SSIM through training process: 0.8741206526756287
# The best SSIM epoch:  1425
# Testing sample:  78
# The best SSIM through training process: 0.9151405692100525
# The best SSIM epoch:  833
# Testing sample:  79
# The best SSIM through training process: 0.9153214693069458
# The best SSIM epoch:  160
# Testing sample:  80
# The best SSIM through training process: 0.8511233925819397
# The best SSIM epoch:  1690
# Testing sample:  81
# The best SSIM through training process: 0.8915315866470337
# The best SSIM epoch:  1200
# Testing sample:  82
# The best SSIM through training process: 0.9039902091026306
# The best SSIM epoch:  281
# Testing sample:  83
# The best SSIM through training process: 0.9111592173576355
# The best SSIM epoch:  379
# Testing sample:  84
# The best SSIM through training process: 0.9116235375404358
# The best SSIM epoch:  145
# Testing sample:  85
# The best SSIM through training process: 0.9037968516349792
# The best SSIM epoch:  237
# Testing sample:  86
# The best SSIM through training process: 0.8366905450820923
# The best SSIM epoch:  3
# Testing sample:  87
# The best SSIM through training process: 0.8841118216514587
# The best SSIM epoch:  283
# Testing sample:  88
# The best SSIM through training process: 0.8943102955818176
# The best SSIM epoch:  231
# Testing sample:  89
# The best SSIM through training process: 0.8960559964179993
# The best SSIM epoch:  674
# Testing sample:  90
# The best SSIM through training process: 0.9124223589897156
# The best SSIM epoch:  918
# Testing sample:  91
# The best SSIM through training process: 0.8977537751197815
# The best SSIM epoch:  333
# Testing sample:  92
# The best SSIM through training process: 0.9118362069129944
# The best SSIM epoch:  221
# Testing sample:  93
# The best SSIM through training process: 0.8810478448867798
# The best SSIM epoch:  166
# Testing sample:  94
# The best SSIM through training process: 0.8753302693367004
# The best SSIM epoch:  413
# Testing sample:  95
# The best SSIM through training process: 0.886728823184967
# The best SSIM epoch:  328
# Testing sample:  96
# The best SSIM through training process: 0.9098868370056152
# The best SSIM epoch:  404
# Testing sample:  97
# The best SSIM through training process: 0.8774449825286865
# The best SSIM epoch:  1689
# Testing sample:  98
# The best SSIM through training process: 0.8826276063919067
# The best SSIM epoch:  986
# Testing sample:  99
# The best SSIM through training process: 0.9209457635879517
# The best SSIM epoch:  814
# Testing sample:  100
# The best SSIM through training process: 0.8944019675254822
# The best SSIM epoch:  451
# Testing average SSIM loss:  0.8909943294525147
# Testing average SSIM loss epoch:  619.73

# %% [markdown]
# without TTT

# %%
COIL = 'rss'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    if COIL == 'rss':
        scale_factor = scale_rss(input_kspace, model)
    elif COIL == 'sensmap': 
        scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 100it [00:38,  2.62it/s]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.9104237449169159
