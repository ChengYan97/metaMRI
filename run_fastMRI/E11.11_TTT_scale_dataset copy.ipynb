# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_rss, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E11.11_joint(l1_1e-5)P_T300_300epoch/E11.11_joint(l1_1e-5)P_T300_300epoch_E150_best.pth'
# '/cheng/metaMRI/metaMRI/save/E11.11_joint(l1_1e-5)P_T300_300epoch/E11.11_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E11.11_sup(l1_1e-5)P_T300_300epoch/E11.11_sup(l1_1e-5)P_T300_300epoch_E300_best.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### without TTT

# %%
# loss_l1_history_=[]
loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_rss(input_kspace, model)

    # gt image no normalization: x
    target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    
    # A†y
    train_inputs = rss_torch(ifft2c(scale_factor * input_kspace))      # [coils,height,width,2] -> [height,width,2]
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )   # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0))
    train_outputs = train_outputs.squeeze(0) # [2, height, width]
    
    # supervised loss [x, fθ(A†y)]
    output_image_1c = complex_abs(torch.moveaxis(train_outputs, 0, -1 )).unsqueeze(0)    # [2, height, width] -> [1, height, width]
    # # normalization
    # output_image_1c = (output_image_1c - output_image_1c.mean()) / output_image_1c.std()
    # output_image_1c *= target_image_1c.std()
    # output_image_1c += target_image_1c.mean()
    # # L1
    # loss_l1 = (l1_loss(output_image_1c, target_image_1c) / torch.sum(torch.abs(target_image_1c))).item()
    
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image_1c = center_crop( target_image_1c, crop_size )
    crop_output_image_1c = center_crop( output_image_1c, crop_size )
    # normalization
    crop_output_image_1c = (crop_output_image_1c - crop_output_image_1c.mean()) / crop_output_image_1c.std()
    crop_output_image_1c *= crop_target_image_1c.std()
    crop_output_image_1c += crop_target_image_1c.mean()
    # SSIM = 1 - loss
    loss_ssim = 1 - ssim_fct(crop_output_image_1c, crop_target_image_1c, data_range = crop_target_image_1c.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 0it [00:00, ?it/s]
# 100it [01:46,  1.06s/it]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.7617029982805252

# %% [markdown]
# ### Test-time training

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 1500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    
    # input k space
    input_kspace = kspace * mask + 0.0
    # scale factor
    scale_factor = scale_rss(input_kspace, model)
    scale_input_kspace = scale_factor * input_kspace

    # gt image by normalized kspace: x
    target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image_1c = center_crop( target_image_1c, crop_size )

    # A†y
    train_inputs = rss_torch(ifft2c(scale_input_kspace))      # [coils,height,width,2] -> [height,width,2]
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )   # [2, height, width]
    
    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))
        model_output = model_output.squeeze(0)      # [2, height, width]       
        # S fθ(A†y) [coils, height, width, channel]
        output_sens_image = complex_mul(torch.moveaxis(model_output.unsqueeze(0), 1, -1 ), sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))
    
        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(torch.moveaxis(model_output, 0, -1 )).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        # # normalization
        # output_image_1c = (output_image_1c - output_image_1c.mean()) / output_image_1c.std()
        # output_image_1c *= target_image_1c.std()
        # output_image_1c += target_image_1c.mean()
        # # L1
        # loss_l1 = (l1_loss(output_image_1c, target_image_1c) / torch.sum(torch.abs(target_image_1c))).item()

        # center crop for SSIM
        crop_output_image_1c = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image_1c = (crop_output_image_1c - crop_output_image_1c.mean()) / crop_output_image_1c.std()
        crop_output_image_1c *= crop_target_image_1c.std()
        crop_output_image_1c += crop_target_image_1c.mean()
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image_1c, crop_target_image_1c, data_range = crop_target_image_1c.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9182688593864441
# The best SSIM epoch:  449
# Testing sample:  2
# The best SSIM through training process: 0.9028963446617126
# The best SSIM epoch:  541
# Testing sample:  3
# The best SSIM through training process: 0.9088656902313232
# The best SSIM epoch:  1125
# Testing sample:  4
# The best SSIM through training process: 0.8785868883132935
# The best SSIM epoch:  1472
# Testing sample:  5
# The best SSIM through training process: 0.9193857312202454
# The best SSIM epoch:  1086
# Testing sample:  6
# The best SSIM through training process: 0.9091310501098633
# The best SSIM epoch:  859
# Testing sample:  7
# The best SSIM through training process: 0.8938630223274231
# The best SSIM epoch:  271
# Testing sample:  8
# The best SSIM through training process: 0.8809667825698853
# The best SSIM epoch:  217
# Testing sample:  9
# The best SSIM through training process: 0.870502769947052
# The best SSIM epoch:  786
# Testing sample:  10
# The best SSIM through training process: 0.8916945457458496
# The best SSIM epoch:  411
# Testing sample:  11
# The best SSIM through training process: 0.8912315368652344
# The best SSIM epoch:  885
# Testing sample:  12
# The best SSIM through training process: 0.8975540399551392
# The best SSIM epoch:  663
# Testing sample:  13
# The best SSIM through training process: 0.9068306684494019
# The best SSIM epoch:  1486
# Testing sample:  14
# The best SSIM through training process: 0.8991851806640625
# The best SSIM epoch:  821
# Testing sample:  15
# The best SSIM through training process: 0.8779520392417908
# The best SSIM epoch:  24
# Testing sample:  16
# The best SSIM through training process: 0.9160676598548889
# The best SSIM epoch:  1017
# Testing sample:  17
# The best SSIM through training process: 0.9160252809524536
# The best SSIM epoch:  477
# Testing sample:  18
# The best SSIM through training process: 0.8767166137695312
# The best SSIM epoch:  476
# Testing sample:  19
# The best SSIM through training process: 0.9183745384216309
# The best SSIM epoch:  483
# Testing sample:  20
# The best SSIM through training process: 0.8845330476760864
# The best SSIM epoch:  331
# Testing sample:  21
# The best SSIM through training process: 0.9085791110992432
# The best SSIM epoch:  696
# Testing sample:  22
# The best SSIM through training process: 0.876733660697937
# The best SSIM epoch:  13
# Testing sample:  23
# The best SSIM through training process: 0.9212988018989563
# The best SSIM epoch:  420
# Testing sample:  24
# The best SSIM through training process: 0.878685712814331
# The best SSIM epoch:  1350
# Testing sample:  25
# The best SSIM through training process: 0.8826494216918945
# The best SSIM epoch:  24
# Testing sample:  26
# The best SSIM through training process: 0.9162381887435913
# The best SSIM epoch:  577
# Testing sample:  27
# The best SSIM through training process: 0.8960719108581543
# The best SSIM epoch:  532
# Testing sample:  28
# The best SSIM through training process: 0.9023455381393433
# The best SSIM epoch:  905
# Testing sample:  29
# The best SSIM through training process: 0.8691852688789368
# The best SSIM epoch:  863
# Testing sample:  30
# The best SSIM through training process: 0.8883301615715027
# The best SSIM epoch:  300
# Testing sample:  31
# The best SSIM through training process: 0.8875454068183899
# The best SSIM epoch:  1189
# Testing sample:  32
# The best SSIM through training process: 0.8753560781478882
# The best SSIM epoch:  161
# Testing sample:  33
# The best SSIM through training process: 0.9025535583496094
# The best SSIM epoch:  1119
# Testing sample:  34
# The best SSIM through training process: 0.8990874886512756
# The best SSIM epoch:  315
# Testing sample:  35
# The best SSIM through training process: 0.9270874857902527
# The best SSIM epoch:  616
# Testing sample:  36
# The best SSIM through training process: 0.8820223212242126
# The best SSIM epoch:  483
# Testing sample:  37
# The best SSIM through training process: 0.8861414194107056
# The best SSIM epoch:  20
# Testing sample:  38
# The best SSIM through training process: 0.9085966348648071
# The best SSIM epoch:  674
# Testing sample:  39
# The best SSIM through training process: 0.8953977823257446
# The best SSIM epoch:  426
# Testing sample:  40
# The best SSIM through training process: 0.9191398620605469
# The best SSIM epoch:  892
# Testing sample:  41
# The best SSIM through training process: 0.879084587097168
# The best SSIM epoch:  1480
# Testing sample:  42
# The best SSIM through training process: 0.90245121717453
# The best SSIM epoch:  508
# Testing sample:  43
# The best SSIM through training process: 0.8957861065864563
# The best SSIM epoch:  435
# Testing sample:  44
# The best SSIM through training process: 0.8832232356071472
# The best SSIM epoch:  424
# Testing sample:  45
# The best SSIM through training process: 0.9093208909034729
# The best SSIM epoch:  722
# Testing sample:  46
# The best SSIM through training process: 0.9005377888679504
# The best SSIM epoch:  258
# Testing sample:  47
# The best SSIM through training process: 0.9003029465675354
# The best SSIM epoch:  332
# Testing sample:  48
# The best SSIM through training process: 0.8936476111412048
# The best SSIM epoch:  692
# Testing sample:  49
# The best SSIM through training process: 0.853011965751648
# The best SSIM epoch:  131
# Testing sample:  50
# The best SSIM through training process: 0.8853555917739868
# The best SSIM epoch:  743
# Testing sample:  51
# The best SSIM through training process: 0.8912091255187988
# The best SSIM epoch:  670
# Testing sample:  52
# The best SSIM through training process: 0.8882129788398743
# The best SSIM epoch:  31
# Testing sample:  53
# The best SSIM through training process: 0.9048367142677307
# The best SSIM epoch:  391
# Testing sample:  54
# The best SSIM through training process: 0.9203615188598633
# The best SSIM epoch:  349
# Testing sample:  55
# The best SSIM through training process: 0.8899019956588745
# The best SSIM epoch:  599
# Testing sample:  56
# The best SSIM through training process: 0.8944599628448486
# The best SSIM epoch:  605
# Testing sample:  57
# The best SSIM through training process: 0.8901650309562683
# The best SSIM epoch:  1404
# Testing sample:  58
# The best SSIM through training process: 0.8870912790298462
# The best SSIM epoch:  262
# Testing sample:  59
# The best SSIM through training process: 0.908320426940918
# The best SSIM epoch:  314
# Testing sample:  60
# The best SSIM through training process: 0.890358567237854
# The best SSIM epoch:  851
# Testing sample:  61
# The best SSIM through training process: 0.8829221129417419
# The best SSIM epoch:  1492
# Testing sample:  62
# The best SSIM through training process: 0.8472613096237183
# The best SSIM epoch:  344
# Testing sample:  63
# The best SSIM through training process: 0.8960225582122803
# The best SSIM epoch:  571
# Testing sample:  64
# The best SSIM through training process: 0.8757197260856628
# The best SSIM epoch:  24
# Testing sample:  65
# The best SSIM through training process: 0.8771079182624817
# The best SSIM epoch:  12
# Testing sample:  66
# The best SSIM through training process: 0.926304280757904
# The best SSIM epoch:  572
# Testing sample:  67
# The best SSIM through training process: 0.8988056778907776
# The best SSIM epoch:  283
# Testing sample:  68
# The best SSIM through training process: 0.9004458785057068
# The best SSIM epoch:  258
# Testing sample:  69
# The best SSIM through training process: 0.8980881571769714
# The best SSIM epoch:  378
# Testing sample:  70
# The best SSIM through training process: 0.8995498418807983
# The best SSIM epoch:  1430
# Testing sample:  71
# The best SSIM through training process: 0.8667851090431213
# The best SSIM epoch:  265
# Testing sample:  72
# The best SSIM through training process: 0.8831332325935364
# The best SSIM epoch:  343
# Testing sample:  73
# The best SSIM through training process: 0.8699749708175659
# The best SSIM epoch:  333
# Testing sample:  74
# The best SSIM through training process: 0.8838769197463989
# The best SSIM epoch:  463
# Testing sample:  75
# The best SSIM through training process: 0.8789840340614319
# The best SSIM epoch:  538
# Testing sample:  76
# The best SSIM through training process: 0.9045072197914124
# The best SSIM epoch:  751
# Testing sample:  77
# The best SSIM through training process: 0.9010438323020935
# The best SSIM epoch:  342
# Testing sample:  78
# The best SSIM through training process: 0.8990814089775085
# The best SSIM epoch:  20
# Testing sample:  79
# The best SSIM through training process: 0.8919331431388855
# The best SSIM epoch:  854
# Testing sample:  80
# The best SSIM through training process: 0.8858099579811096
# The best SSIM epoch:  590
# Testing sample:  81
# The best SSIM through training process: 0.8886183500289917
# The best SSIM epoch:  400
# Testing sample:  82
# The best SSIM through training process: 0.8288446068763733
# The best SSIM epoch:  389
# Testing sample:  83
# The best SSIM through training process: 0.9028237462043762
# The best SSIM epoch:  620
# Testing sample:  84
# The best SSIM through training process: 0.8967174291610718
# The best SSIM epoch:  1233
# Testing sample:  85
# The best SSIM through training process: 0.9024679660797119
# The best SSIM epoch:  732
# Testing sample:  86
# The best SSIM through training process: 0.8436433672904968
# The best SSIM epoch:  294
# Testing sample:  87
# The best SSIM through training process: 0.8861144185066223
# The best SSIM epoch:  255
# Testing sample:  88
# The best SSIM through training process: 0.8907284736633301
# The best SSIM epoch:  448
# Testing sample:  89
# The best SSIM through training process: 0.8823716044425964
# The best SSIM epoch:  24
# Testing sample:  90
# The best SSIM through training process: 0.9107514023780823
# The best SSIM epoch:  345
# Testing sample:  91
# The best SSIM through training process: 0.8659219145774841
# The best SSIM epoch:  595
# Testing sample:  92
# The best SSIM through training process: 0.8816394805908203
# The best SSIM epoch:  719
# Testing sample:  93
# The best SSIM through training process: 0.8710900545120239
# The best SSIM epoch:  382
# Testing sample:  94
# The best SSIM through training process: 0.894173264503479
# The best SSIM epoch:  780
# Testing sample:  95
# The best SSIM through training process: 0.8905585408210754
# The best SSIM epoch:  1153
# Testing sample:  96
# The best SSIM through training process: 0.9065847396850586
# The best SSIM epoch:  555
# Testing sample:  97
# The best SSIM through training process: 0.8950632214546204
# The best SSIM epoch:  298
# Testing sample:  98
# The best SSIM through training process: 0.9148716330528259
# The best SSIM epoch:  517
# Testing sample:  99
# The best SSIM through training process: 0.9126691222190857
# The best SSIM epoch:  560
# Testing sample:  100
# The best SSIM through training process: 0.902176022529602
# The best SSIM epoch:  506
# Testing average SSIM loss:  0.8928450429439545
# Testing average SSIM loss epoch:  573.24
