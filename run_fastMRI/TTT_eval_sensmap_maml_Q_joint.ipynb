# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E14.1_maml_joint(l1_out-5_in-5)Q_T300_300epoch/E14.1_maml_joint(l1_out-5_in-5)Q_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9616278409957886
# The best SSIM epoch:  84
# Testing sample:  2
# The best SSIM through training process: 0.927230954170227
# The best SSIM epoch:  61
# Testing sample:  3
# The best SSIM through training process: 0.9579629302024841
# The best SSIM epoch:  62
# Testing sample:  4
# The best SSIM through training process: 0.9601197838783264
# The best SSIM epoch:  105
# Testing sample:  5
# The best SSIM through training process: 0.9521501064300537
# The best SSIM epoch:  87
# Testing sample:  6
# The best SSIM through training process: 0.9515454769134521
# The best SSIM epoch:  90
# Testing sample:  7
# The best SSIM through training process: 0.9483892321586609
# The best SSIM epoch:  80
# Testing sample:  8
# The best SSIM through training process: 0.9381372332572937
# The best SSIM epoch:  43
# Testing sample:  9
# The best SSIM through training process: 0.9514532089233398
# The best SSIM epoch:  90
# Testing sample:  10
# The best SSIM through training process: 0.9549029469490051
# The best SSIM epoch:  56
# Testing sample:  11
# The best SSIM through training process: 0.9550166726112366
# The best SSIM epoch:  85
# Testing sample:  12
# The best SSIM through training process: 0.9573180675506592
# The best SSIM epoch:  82
# Testing sample:  13
# The best SSIM through training process: 0.9587643146514893
# The best SSIM epoch:  81
# Testing sample:  14
# The best SSIM through training process: 0.9608622193336487
# The best SSIM epoch:  121
# Testing sample:  15
# The best SSIM through training process: 0.9501667618751526
# The best SSIM epoch:  71
# Testing sample:  16
# The best SSIM through training process: 0.95441734790802
# The best SSIM epoch:  130
# Testing sample:  17
# The best SSIM through training process: 0.9550893902778625
# The best SSIM epoch:  80
# Testing sample:  18
# The best SSIM through training process: 0.9487082958221436
# The best SSIM epoch:  63
# Testing sample:  19
# The best SSIM through training process: 0.9522230625152588
# The best SSIM epoch:  89
# Testing sample:  20
# The best SSIM through training process: 0.9670153260231018
# The best SSIM epoch:  103
# Testing sample:  21
# The best SSIM through training process: 0.9633722901344299
# The best SSIM epoch:  81
# Testing sample:  22
# The best SSIM through training process: 0.9578317403793335
# The best SSIM epoch:  48
# Testing sample:  23
# The best SSIM through training process: 0.9575167894363403
# The best SSIM epoch:  119
# Testing sample:  24
# The best SSIM through training process: 0.963987410068512
# The best SSIM epoch:  95
# Testing sample:  25
# The best SSIM through training process: 0.9573631882667542
# The best SSIM epoch:  70
# Testing sample:  26
# The best SSIM through training process: 0.959010124206543
# The best SSIM epoch:  70
# Testing sample:  27
# The best SSIM through training process: 0.9492887258529663
# The best SSIM epoch:  75
# Testing sample:  28
# The best SSIM through training process: 0.9499343633651733
# The best SSIM epoch:  77
# Testing sample:  29
# The best SSIM through training process: 0.961669385433197
# The best SSIM epoch:  77
# Testing sample:  30
# The best SSIM through training process: 0.9404705166816711
# The best SSIM epoch:  64
# Testing sample:  31
# The best SSIM through training process: 0.9415920972824097
# The best SSIM epoch:  74
# Testing sample:  32
# The best SSIM through training process: 0.9503201246261597
# The best SSIM epoch:  81
# Testing sample:  33
# The best SSIM through training process: 0.9510622620582581
# The best SSIM epoch:  101
# Testing sample:  34
# The best SSIM through training process: 0.9520107507705688
# The best SSIM epoch:  124
# Testing sample:  35
# The best SSIM through training process: 0.955898106098175
# The best SSIM epoch:  91
# Testing sample:  36
# The best SSIM through training process: 0.9562187790870667
# The best SSIM epoch:  51
# Testing sample:  37
# The best SSIM through training process: 0.9526351094245911
# The best SSIM epoch:  67
# Testing sample:  38
# The best SSIM through training process: 0.9499395489692688
# The best SSIM epoch:  100
# Testing sample:  39
# The best SSIM through training process: 0.9627614617347717
# The best SSIM epoch:  155
# Testing sample:  40
# The best SSIM through training process: 0.9604505896568298
# The best SSIM epoch:  97
# Testing sample:  41
# The best SSIM through training process: 0.9525192379951477
# The best SSIM epoch:  79
# Testing sample:  42
# The best SSIM through training process: 0.9508959054946899
# The best SSIM epoch:  87
# Testing sample:  43
# The best SSIM through training process: 0.9533917307853699
# The best SSIM epoch:  48
# Testing sample:  44
# The best SSIM through training process: 0.960599958896637
# The best SSIM epoch:  69
# Testing sample:  45
# The best SSIM through training process: 0.961768627166748
# The best SSIM epoch:  106
# Testing sample:  46
# The best SSIM through training process: 0.9350022673606873
# The best SSIM epoch:  75
# Testing sample:  47
# The best SSIM through training process: 0.9626981019973755
# The best SSIM epoch:  119
# Testing sample:  48
# The best SSIM through training process: 0.9429972171783447
# The best SSIM epoch:  52
# Testing sample:  49
# The best SSIM through training process: 0.8968558311462402
# The best SSIM epoch:  65
# Testing sample:  50
# The best SSIM through training process: 0.950912356376648
# The best SSIM epoch:  54
# Testing sample:  51
# The best SSIM through training process: 0.9483920335769653
# The best SSIM epoch:  145
# Testing sample:  52
# The best SSIM through training process: 0.9486618638038635
# The best SSIM epoch:  98
# Testing sample:  53
# The best SSIM through training process: 0.9565984010696411
# The best SSIM epoch:  99
# Testing sample:  54
# The best SSIM through training process: 0.9719004034996033
# The best SSIM epoch:  111
# Testing sample:  55
# The best SSIM through training process: 0.9610897898674011
# The best SSIM epoch:  75
# Testing sample:  56
# The best SSIM through training process: 0.955114483833313
# The best SSIM epoch:  91
# Testing sample:  57
# The best SSIM through training process: 0.9637285470962524
# The best SSIM epoch:  76
# Testing sample:  58
# The best SSIM through training process: 0.9488043785095215
# The best SSIM epoch:  95
# Testing sample:  59
# The best SSIM through training process: 0.96833735704422
# The best SSIM epoch:  87
# Testing sample:  60
# The best SSIM through training process: 0.9405955672264099
# The best SSIM epoch:  56
# Testing sample:  61
# The best SSIM through training process: 0.9586244821548462
# The best SSIM epoch:  69
# Testing sample:  62
# The best SSIM through training process: 0.9454423785209656
# The best SSIM epoch:  104
# Testing sample:  63
# The best SSIM through training process: 0.9478347897529602
# The best SSIM epoch:  56
# Testing sample:  64
# The best SSIM through training process: 0.9562193155288696
# The best SSIM epoch:  102
# Testing sample:  65
# The best SSIM through training process: 0.9624242186546326
# The best SSIM epoch:  65
# Testing sample:  66
# The best SSIM through training process: 0.9700171947479248
# The best SSIM epoch:  84
# Testing sample:  67
# The best SSIM through training process: 0.94618159532547
# The best SSIM epoch:  69
# Testing sample:  68
# The best SSIM through training process: 0.9521303176879883
# The best SSIM epoch:  95
# Testing sample:  69
# The best SSIM through training process: 0.9501267075538635
# The best SSIM epoch:  104
# Testing sample:  70
# The best SSIM through training process: 0.9574806094169617
# The best SSIM epoch:  93
# Testing sample:  71
# The best SSIM through training process: 0.9445939660072327
# The best SSIM epoch:  45
# Testing sample:  72
# The best SSIM through training process: 0.9588102102279663
# The best SSIM epoch:  85
# Testing sample:  73
# The best SSIM through training process: 0.9423051476478577
# The best SSIM epoch:  112
# Testing sample:  74
# The best SSIM through training process: 0.9457948207855225
# The best SSIM epoch:  72
# Testing sample:  75
# The best SSIM through training process: 0.9515393972396851
# The best SSIM epoch:  45
# Testing sample:  76
# The best SSIM through training process: 0.9541395902633667
# The best SSIM epoch:  99
# Testing sample:  77
# The best SSIM through training process: 0.960689127445221
# The best SSIM epoch:  98
# Testing sample:  78
# The best SSIM through training process: 0.9684858918190002
# The best SSIM epoch:  102
# Testing sample:  79
# The best SSIM through training process: 0.9588499069213867
# The best SSIM epoch:  62
# Testing sample:  80
# The best SSIM through training process: 0.9374721050262451
# The best SSIM epoch:  116
# Testing sample:  81
# The best SSIM through training process: 0.9544590711593628
# The best SSIM epoch:  128
# Testing sample:  82
# The best SSIM through training process: 0.9512731432914734
# The best SSIM epoch:  83
# Testing sample:  83
# The best SSIM through training process: 0.9537389278411865
# The best SSIM epoch:  79
# Testing sample:  84
# The best SSIM through training process: 0.9613736867904663
# The best SSIM epoch:  55
# Testing sample:  85
# The best SSIM through training process: 0.9632712006568909
# The best SSIM epoch:  54
# Testing sample:  86
# The best SSIM through training process: 0.9053668975830078
# The best SSIM epoch:  77
# Testing sample:  87
# The best SSIM through training process: 0.9400694966316223
# The best SSIM epoch:  66
# Testing sample:  88
# The best SSIM through training process: 0.9519966840744019
# The best SSIM epoch:  55
# Testing sample:  89
# The best SSIM through training process: 0.9595584273338318
# The best SSIM epoch:  70
# Testing sample:  90
# The best SSIM through training process: 0.9628310203552246
# The best SSIM epoch:  110
# Testing sample:  91
# The best SSIM through training process: 0.9430419206619263
# The best SSIM epoch:  103
# Testing sample:  92
# The best SSIM through training process: 0.9564355611801147
# The best SSIM epoch:  80
# Testing sample:  93
# The best SSIM through training process: 0.9360044002532959
# The best SSIM epoch:  55
# Testing sample:  94
# The best SSIM through training process: 0.9461880922317505
# The best SSIM epoch:  51
# Testing sample:  95
# The best SSIM through training process: 0.9409438967704773
# The best SSIM epoch:  86
# Testing sample:  96
# The best SSIM through training process: 0.9582113027572632
# The best SSIM epoch:  71
# Testing sample:  97
# The best SSIM through training process: 0.9473584890365601
# The best SSIM epoch:  97
# Testing sample:  98
# The best SSIM through training process: 0.951339602470398
# The best SSIM epoch:  86
# Testing sample:  99
# The best SSIM through training process: 0.9692831039428711
# The best SSIM epoch:  111
# Testing sample:  100
# The best SSIM through training process: 0.9564419984817505
# The best SSIM epoch:  86
# Testing average SSIM loss:  0.9526564729213715
# Testing average SSIM loss epoch:  83.47
