# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop,scale_rss, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttkspace_sensmap_sup(l1_1e-5)P_T300_300epoch/E_tttkspace_sensmap_sup(l1_1e-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9484962821006775
# The best SSIM epoch:  132
# Testing sample:  2
# The best SSIM through training process: 0.9172204732894897
# The best SSIM epoch:  155
# Testing sample:  3
# The best SSIM through training process: 0.9421205520629883
# The best SSIM epoch:  103
# Testing sample:  4
# The best SSIM through training process: 0.9465338587760925
# The best SSIM epoch:  140
# Testing sample:  5
# The best SSIM through training process: 0.9456470012664795
# The best SSIM epoch:  142
# Testing sample:  6
# The best SSIM through training process: 0.9399256706237793
# The best SSIM epoch:  126
# Testing sample:  7
# The best SSIM through training process: 0.9379479289054871
# The best SSIM epoch:  167
# Testing sample:  8
# The best SSIM through training process: 0.9272375702857971
# The best SSIM epoch:  80
# Testing sample:  9
# The best SSIM through training process: 0.9402968883514404
# The best SSIM epoch:  169
# Testing sample:  10
# The best SSIM through training process: 0.9409186244010925
# The best SSIM epoch:  132
# Testing sample:  11
# The best SSIM through training process: 0.9412298798561096
# The best SSIM epoch:  131
# Testing sample:  12
# The best SSIM through training process: 0.9423920512199402
# The best SSIM epoch:  149
# Testing sample:  13
# The best SSIM through training process: 0.9529588222503662
# The best SSIM epoch:  177
# Testing sample:  14
# The best SSIM through training process: 0.953843891620636
# The best SSIM epoch:  166
# Testing sample:  15
# The best SSIM through training process: 0.9329512119293213
# The best SSIM epoch:  163
# Testing sample:  16
# The best SSIM through training process: 0.9492391347885132
# The best SSIM epoch:  200
# Testing sample:  17
# The best SSIM through training process: 0.9480817914009094
# The best SSIM epoch:  143
# Testing sample:  18
# The best SSIM through training process: 0.9336561560630798
# The best SSIM epoch:  121
# Testing sample:  19
# The best SSIM through training process: 0.9465579986572266
# The best SSIM epoch:  189
# Testing sample:  20
# The best SSIM through training process: 0.9578937888145447
# The best SSIM epoch:  288
# Testing sample:  21
# The best SSIM through training process: 0.9525764584541321
# The best SSIM epoch:  247
# Testing sample:  22
# The best SSIM through training process: 0.9445657134056091
# The best SSIM epoch:  120
# Testing sample:  23
# The best SSIM through training process: 0.9528201222419739
# The best SSIM epoch:  164
# Testing sample:  24
# The best SSIM through training process: 0.9500846862792969
# The best SSIM epoch:  120
# Testing sample:  25
# The best SSIM through training process: 0.9437587857246399
# The best SSIM epoch:  167
# Testing sample:  26
# The best SSIM through training process: 0.9445644617080688
# The best SSIM epoch:  128
# Testing sample:  27
# The best SSIM through training process: 0.9359915852546692
# The best SSIM epoch:  133
# Testing sample:  28
# The best SSIM through training process: 0.9369484782218933
# The best SSIM epoch:  110
# Testing sample:  29
# The best SSIM through training process: 0.9507119059562683
# The best SSIM epoch:  146
# Testing sample:  30
# The best SSIM through training process: 0.9274393916130066
# The best SSIM epoch:  181
# Testing sample:  31
# The best SSIM through training process: 0.9259010553359985
# The best SSIM epoch:  119
# Testing sample:  32
# The best SSIM through training process: 0.9378841519355774
# The best SSIM epoch:  204
# Testing sample:  33
# The best SSIM through training process: 0.9437171816825867
# The best SSIM epoch:  184
# Testing sample:  34
# The best SSIM through training process: 0.9495634436607361
# The best SSIM epoch:  159
# Testing sample:  35
# The best SSIM through training process: 0.9494073987007141
# The best SSIM epoch:  115
# Testing sample:  36
# The best SSIM through training process: 0.9399146437644958
# The best SSIM epoch:  122
# Testing sample:  37
# The best SSIM through training process: 0.9444487690925598
# The best SSIM epoch:  95
# Testing sample:  38
# The best SSIM through training process: 0.9377174973487854
# The best SSIM epoch:  138
# Testing sample:  39
# The best SSIM through training process: 0.9530385136604309
# The best SSIM epoch:  175
# Testing sample:  40
# The best SSIM through training process: 0.9447548985481262
# The best SSIM epoch:  137
# Testing sample:  41
# The best SSIM through training process: 0.9400061964988708
# The best SSIM epoch:  134
# Testing sample:  42
# The best SSIM through training process: 0.9421648979187012
# The best SSIM epoch:  148
# Testing sample:  43
# The best SSIM through training process: 0.9411064386367798
# The best SSIM epoch:  123
# Testing sample:  44
# The best SSIM through training process: 0.9483106732368469
# The best SSIM epoch:  108
# Testing sample:  45
# The best SSIM through training process: 0.950068473815918
# The best SSIM epoch:  299
# Testing sample:  46
# The best SSIM through training process: 0.9241761565208435
# The best SSIM epoch:  114
# Testing sample:  47
# The best SSIM through training process: 0.9551156163215637
# The best SSIM epoch:  188
# Testing sample:  48
# The best SSIM through training process: 0.9317751526832581
# The best SSIM epoch:  135
# Testing sample:  49
# The best SSIM through training process: 0.8913677334785461
# The best SSIM epoch:  89
# Testing sample:  50
# The best SSIM through training process: 0.9396957159042358
# The best SSIM epoch:  91
# Testing sample:  51
# The best SSIM through training process: 0.9403475522994995
# The best SSIM epoch:  205
# Testing sample:  52
# The best SSIM through training process: 0.9408548474311829
# The best SSIM epoch:  150
# Testing sample:  53
# The best SSIM through training process: 0.9441220164299011
# The best SSIM epoch:  143
# Testing sample:  54
# The best SSIM through training process: 0.9667971730232239
# The best SSIM epoch:  148
# Testing sample:  55
# The best SSIM through training process: 0.9482486248016357
# The best SSIM epoch:  153
# Testing sample:  56
# The best SSIM through training process: 0.9470870494842529
# The best SSIM epoch:  222
# Testing sample:  57
# The best SSIM through training process: 0.9540227651596069
# The best SSIM epoch:  196
# Testing sample:  58
# The best SSIM through training process: 0.9408586025238037
# The best SSIM epoch:  120
# Testing sample:  59
# The best SSIM through training process: 0.9576523900032043
# The best SSIM epoch:  128
# Testing sample:  60
# The best SSIM through training process: 0.9277775883674622
# The best SSIM epoch:  98
# Testing sample:  61
# The best SSIM through training process: 0.9493223428726196
# The best SSIM epoch:  157
# Testing sample:  62
# The best SSIM through training process: 0.9344433546066284
# The best SSIM epoch:  146
# Testing sample:  63
# The best SSIM through training process: 0.9357004165649414
# The best SSIM epoch:  146
# Testing sample:  64
# The best SSIM through training process: 0.947151243686676
# The best SSIM epoch:  236
# Testing sample:  65
# The best SSIM through training process: 0.9496486186981201
# The best SSIM epoch:  134
# Testing sample:  66
# The best SSIM through training process: 0.9611294269561768
# The best SSIM epoch:  189
# Testing sample:  67
# The best SSIM through training process: 0.9361398220062256
# The best SSIM epoch:  121
# Testing sample:  68
# The best SSIM through training process: 0.9430816769599915
# The best SSIM epoch:  134
# Testing sample:  69
# The best SSIM through training process: 0.9387879371643066
# The best SSIM epoch:  211
# Testing sample:  70
# The best SSIM through training process: 0.9421851634979248
# The best SSIM epoch:  138
# Testing sample:  71
# The best SSIM through training process: 0.9276583194732666
# The best SSIM epoch:  98
# Testing sample:  72
# The best SSIM through training process: 0.9444893598556519
# The best SSIM epoch:  169
# Testing sample:  73
# The best SSIM through training process: 0.9321790933609009
# The best SSIM epoch:  141
# Testing sample:  74
# The best SSIM through training process: 0.931638240814209
# The best SSIM epoch:  124
# Testing sample:  75
# The best SSIM through training process: 0.9384769797325134
# The best SSIM epoch:  101
# Testing sample:  76
# The best SSIM through training process: 0.9397183656692505
# The best SSIM epoch:  127
# Testing sample:  77
# The best SSIM through training process: 0.9530183672904968
# The best SSIM epoch:  153
# Testing sample:  78
# The best SSIM through training process: 0.9603244662284851
# The best SSIM epoch:  229
# Testing sample:  79
# The best SSIM through training process: 0.9452234506607056
# The best SSIM epoch:  95
# Testing sample:  80
# The best SSIM through training process: 0.9310966730117798
# The best SSIM epoch:  157
# Testing sample:  81
# The best SSIM through training process: 0.9418444037437439
# The best SSIM epoch:  235
# Testing sample:  82
# The best SSIM through training process: 0.9366562366485596
# The best SSIM epoch:  153
# Testing sample:  83
# The best SSIM through training process: 0.9420572519302368
# The best SSIM epoch:  160
# Testing sample:  84
# The best SSIM through training process: 0.9478551745414734
# The best SSIM epoch:  86
# Testing sample:  85
# The best SSIM through training process: 0.9545897245407104
# The best SSIM epoch:  124
# Testing sample:  86
# The best SSIM through training process: 0.8974624276161194
# The best SSIM epoch:  100
# Testing sample:  87
# The best SSIM through training process: 0.9295468926429749
# The best SSIM epoch:  117
# Testing sample:  88
# The best SSIM through training process: 0.9412453770637512
# The best SSIM epoch:  108
# Testing sample:  89
# The best SSIM through training process: 0.9466611742973328
# The best SSIM epoch:  137
# Testing sample:  90
# The best SSIM through training process: 0.9527863264083862
# The best SSIM epoch:  221
# Testing sample:  91
# The best SSIM through training process: 0.9326382875442505
# The best SSIM epoch:  142
# Testing sample:  92
# The best SSIM through training process: 0.941860556602478
# The best SSIM epoch:  121
# Testing sample:  93
# The best SSIM through training process: 0.9223018884658813
# The best SSIM epoch:  91
# Testing sample:  94
# The best SSIM through training process: 0.9333831071853638
# The best SSIM epoch:  123
# Testing sample:  95
# The best SSIM through training process: 0.929574191570282
# The best SSIM epoch:  122
# Testing sample:  96
# The best SSIM through training process: 0.9456387758255005
# The best SSIM epoch:  125
# Testing sample:  97
# The best SSIM through training process: 0.9379727840423584
# The best SSIM epoch:  135
# Testing sample:  98
# The best SSIM through training process: 0.93939208984375
# The best SSIM epoch:  256
# Testing sample:  99
# The best SSIM through training process: 0.959557294845581
# The best SSIM epoch:  242
# Testing sample:  100
# The best SSIM through training process: 0.9462959170341492
# The best SSIM epoch:  142
# Testing average SSIM loss:  0.9416324758529663
# Testing average SSIM loss epoch:  149.75

# %%
fig, axes = plt.subplots(1, 2, dpi= 300)

axes[0].imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[0].axis('off')

axes[1].imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[1].set_title('Ground Truth')
axes[1].axis('off')

plt.subplots_adjust(wspace=0.1)
plt.show()

# %% [markdown]
# without TTT

# %%
# model_blank = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
# model_blank = model_blank.to(device)

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    if COIL == 'rss':
        scale_factor = scale_rss(input_kspace, model)
    elif COIL == 'sensmap': 
        scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 100it [11:55,  7.16s/it]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.7587876319885254
