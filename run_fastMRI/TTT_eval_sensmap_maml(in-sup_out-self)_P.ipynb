# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_TTTmaml_in-sup_out-self(l1_out-5_in-3_AS-2)P_T300_300epoch/E_TTTmaml_in-sup_out-self(l1_out-5_in-3_AS-2)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %% [markdown]
# Sensmap

# %%
background_flip = True
eval_with_binary_mask = False
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9395765066146851
# The best SSIM epoch:  231
# Testing sample:  2
# The best SSIM through training process: 0.9090477228164673
# The best SSIM epoch:  195
# Testing sample:  3
# The best SSIM through training process: 0.9326470494270325
# The best SSIM epoch:  148
# Testing sample:  4
# The best SSIM through training process: 0.9333828687667847
# The best SSIM epoch:  328
# Testing sample:  5
# The best SSIM through training process: 0.9380056858062744
# The best SSIM epoch:  202
# Testing sample:  6
# The best SSIM through training process: 0.9263581037521362
# The best SSIM epoch:  227
# Testing sample:  7
# The best SSIM through training process: 0.9310852289199829
# The best SSIM epoch:  209
# Testing sample:  8
# The best SSIM through training process: 0.9203795790672302
# The best SSIM epoch:  107
# Testing sample:  9
# The best SSIM through training process: 0.9333724975585938
# The best SSIM epoch:  217
# Testing sample:  10
# The best SSIM through training process: 0.9324651956558228
# The best SSIM epoch:  146
# Testing sample:  11
# The best SSIM through training process: 0.9295644760131836
# The best SSIM epoch:  241
# Testing sample:  12
# The best SSIM through training process: 0.9276657104492188
# The best SSIM epoch:  260
# Testing sample:  13
# The best SSIM through training process: 0.9420745372772217
# The best SSIM epoch:  212
# Testing sample:  14
# The best SSIM through training process: 0.9436588287353516
# The best SSIM epoch:  321
# Testing sample:  15
# The best SSIM through training process: 0.9312439560890198
# The best SSIM epoch:  147
# Testing sample:  16
# The best SSIM through training process: 0.9335624575614929
# The best SSIM epoch:  321
# Testing sample:  17
# The best SSIM through training process: 0.9410204291343689
# The best SSIM epoch:  115
# Testing sample:  18
# The best SSIM through training process: 0.9329266548156738
# The best SSIM epoch:  133
# Testing sample:  19
# The best SSIM through training process: 0.9397066235542297
# The best SSIM epoch:  252
# Testing sample:  20
# The best SSIM through training process: 0.9458122849464417
# The best SSIM epoch:  350
# Testing sample:  21
# The best SSIM through training process: 0.9409345388412476
# The best SSIM epoch:  255
# Testing sample:  22
# The best SSIM through training process: 0.9399546980857849
# The best SSIM epoch:  110
# Testing sample:  23
# The best SSIM through training process: 0.9443057775497437
# The best SSIM epoch:  220
# Testing sample:  24
# The best SSIM through training process: 0.9339976906776428
# The best SSIM epoch:  270
# Testing sample:  25
# The best SSIM through training process: 0.9332184195518494
# The best SSIM epoch:  182
# Testing sample:  26
# The best SSIM through training process: 0.9343072175979614
# The best SSIM epoch:  212
# Testing sample:  27
# The best SSIM through training process: 0.9176729917526245
# The best SSIM epoch:  249
# Testing sample:  28
# The best SSIM through training process: 0.927590012550354
# The best SSIM epoch:  191
# Testing sample:  29
# The best SSIM through training process: 0.9399780631065369
# The best SSIM epoch:  301
# Testing sample:  30
# The best SSIM through training process: 0.9230607151985168
# The best SSIM epoch:  181
# Testing sample:  31
# The best SSIM through training process: 0.911908745765686
# The best SSIM epoch:  176
# Testing sample:  32
# The best SSIM through training process: 0.9329140186309814
# The best SSIM epoch:  164
# Testing sample:  33
# The best SSIM through training process: 0.9273360967636108
# The best SSIM epoch:  344
# Testing sample:  34
# The best SSIM through training process: 0.938318133354187
# The best SSIM epoch:  241
# Testing sample:  35
# The best SSIM through training process: 0.9411454200744629
# The best SSIM epoch:  168
# Testing sample:  36
# The best SSIM through training process: 0.9330000877380371
# The best SSIM epoch:  124
# Testing sample:  37
# The best SSIM through training process: 0.9383225440979004
# The best SSIM epoch:  84
# Testing sample:  38
# The best SSIM through training process: 0.9246339201927185
# The best SSIM epoch:  213
# Testing sample:  39
# The best SSIM through training process: 0.9488418698310852
# The best SSIM epoch:  397
# Testing sample:  40
# The best SSIM through training process: 0.9341523051261902
# The best SSIM epoch:  345
# Testing sample:  41
# The best SSIM through training process: 0.9268681406974792
# The best SSIM epoch:  190
# Testing sample:  42
# The best SSIM through training process: 0.9354632496833801
# The best SSIM epoch:  182
# Testing sample:  43
# The best SSIM through training process: 0.9326673746109009
# The best SSIM epoch:  121
# Testing sample:  44
# The best SSIM through training process: 0.9382128715515137
# The best SSIM epoch:  164
# Testing sample:  45
# The best SSIM through training process: 0.9398109316825867
# The best SSIM epoch:  362
# Testing sample:  46
# The best SSIM through training process: 0.9247506856918335
# The best SSIM epoch:  115
# Testing sample:  47
# The best SSIM through training process: 0.9446080327033997
# The best SSIM epoch:  351
# Testing sample:  48
# The best SSIM through training process: 0.9280163645744324
# The best SSIM epoch:  124
# Testing sample:  49
# The best SSIM through training process: 0.8921730518341064
# The best SSIM epoch:  51
# Testing sample:  50
# The best SSIM through training process: 0.934173583984375
# The best SSIM epoch:  138
# Testing sample:  51
# The best SSIM through training process: 0.9243621826171875
# The best SSIM epoch:  374
# Testing sample:  52
# The best SSIM through training process: 0.9366990327835083
# The best SSIM epoch:  179
# Testing sample:  53
# The best SSIM through training process: 0.9315459132194519
# The best SSIM epoch:  282
# Testing sample:  54
# The best SSIM through training process: 0.9516754150390625
# The best SSIM epoch:  322
# Testing sample:  55
# The best SSIM through training process: 0.937245786190033
# The best SSIM epoch:  196
# Testing sample:  56
# The best SSIM through training process: 0.9398372173309326
# The best SSIM epoch:  249
# Testing sample:  57
# The best SSIM through training process: 0.9409765601158142
# The best SSIM epoch:  198
# Testing sample:  58
# The best SSIM through training process: 0.9355250597000122
# The best SSIM epoch:  209
# Testing sample:  59
# The best SSIM through training process: 0.9495630264282227
# The best SSIM epoch:  209
# Testing sample:  60
# The best SSIM through training process: 0.9242029786109924
# The best SSIM epoch:  156
# Testing sample:  61
# The best SSIM through training process: 0.9291055798530579
# The best SSIM epoch:  257
# Testing sample:  62
# The best SSIM through training process: 0.9229786396026611
# The best SSIM epoch:  226
# Testing sample:  63
# The best SSIM through training process: 0.9281301498413086
# The best SSIM epoch:  163
# Testing sample:  64
# The best SSIM through training process: 0.9320233464241028
# The best SSIM epoch:  285
# Testing sample:  65
# The best SSIM through training process: 0.9424694180488586
# The best SSIM epoch:  172
# Testing sample:  66
# The best SSIM through training process: 0.9499732255935669
# The best SSIM epoch:  240
# Testing sample:  67
# The best SSIM through training process: 0.9339885711669922
# The best SSIM epoch:  154
# Testing sample:  68
# The best SSIM through training process: 0.9359058737754822
# The best SSIM epoch:  188
# Testing sample:  69
# The best SSIM through training process: 0.9211015105247498
# The best SSIM epoch:  287
# Testing sample:  70
# The best SSIM through training process: 0.925897479057312
# The best SSIM epoch:  266
# Testing sample:  71
# The best SSIM through training process: 0.9228218793869019
# The best SSIM epoch:  100
# Testing sample:  72
# The best SSIM through training process: 0.9377583861351013
# The best SSIM epoch:  205
# Testing sample:  73
# The best SSIM through training process: 0.9292019009590149
# The best SSIM epoch:  220
# Testing sample:  74
# The best SSIM through training process: 0.9224205017089844
# The best SSIM epoch:  159
# Testing sample:  75
# The best SSIM through training process: 0.9362572431564331
# The best SSIM epoch:  135
# Testing sample:  76
# The best SSIM through training process: 0.9284077286720276
# The best SSIM epoch:  220
# Testing sample:  77
# The best SSIM through training process: 0.9457534551620483
# The best SSIM epoch:  193
# Testing sample:  78
# The best SSIM through training process: 0.9546185731887817
# The best SSIM epoch:  293
# Testing sample:  79
# The best SSIM through training process: 0.9353047013282776
# The best SSIM epoch:  138
# Testing sample:  80
# The best SSIM through training process: 0.9207457304000854
# The best SSIM epoch:  309
# Testing sample:  81
# The best SSIM through training process: 0.9336785078048706
# The best SSIM epoch:  435
# Testing sample:  82
# The best SSIM through training process: 0.9258038997650146
# The best SSIM epoch:  202
# Testing sample:  83
# The best SSIM through training process: 0.9391306638717651
# The best SSIM epoch:  205
# Testing sample:  84
# The best SSIM through training process: 0.941688597202301
# The best SSIM epoch:  136
# Testing sample:  85
# The best SSIM through training process: 0.9450509548187256
# The best SSIM epoch:  138
# Testing sample:  86
# The best SSIM through training process: 0.8988144397735596
# The best SSIM epoch:  90
# Testing sample:  87
# The best SSIM through training process: 0.9207946062088013
# The best SSIM epoch:  161
# Testing sample:  88
# The best SSIM through training process: 0.9299237728118896
# The best SSIM epoch:  157
# Testing sample:  89
# The best SSIM through training process: 0.933966875076294
# The best SSIM epoch:  161
# Testing sample:  90
# The best SSIM through training process: 0.9451524615287781
# The best SSIM epoch:  236
# Testing sample:  91
# The best SSIM through training process: 0.9200329780578613
# The best SSIM epoch:  236
# Testing sample:  92
# The best SSIM through training process: 0.9260955452919006
# The best SSIM epoch:  196
# Testing sample:  93
# The best SSIM through training process: 0.9133661389350891
# The best SSIM epoch:  139
# Testing sample:  94
# The best SSIM through training process: 0.9323036074638367
# The best SSIM epoch:  104
# Testing sample:  95
# The best SSIM through training process: 0.9198723435401917
# The best SSIM epoch:  240
# Testing sample:  96
# The best SSIM through training process: 0.9395334124565125
# The best SSIM epoch:  178
# Testing sample:  97
# The best SSIM through training process: 0.9355881214141846
# The best SSIM epoch:  235
# Testing sample:  98
# The best SSIM through training process: 0.9300904273986816
# The best SSIM epoch:  306
# Testing sample:  99
# The best SSIM through training process: 0.9468074440956116
# The best SSIM epoch:  409
# Testing sample:  100
# The best SSIM through training process: 0.9361968040466309
# The best SSIM epoch:  184
# Testing average SSIM loss:  0.932662826180458
# Testing average SSIM loss epoch:  213.19

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 100it [01:30,  1.10it/s]

# %%
#print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.7591848111152649
