# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E13.1_image_sup(l1_1e-5)P_T300_300epoch/E13.1_image_sup(l1_1e-5)P_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E13.1_sup(l1_1e-5)P_T300_300epoch/E13.1_sup(l1_1e-5)P_T300_300epoch_E49.pth'
# '/cheng/metaMRI/metaMRI/save/E13.1_joint(l1_1e-5)P_T300_300epoch/E13.1_joint(l1_1e-5)P_T300_300epoch_E50.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training
#  - no background flipping
#  - background mask the output but no ground truth

# %%
background_flip = False

# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0   # [coils,height,width,2]

    # A†y
    train_inputs = torch.moveaxis(rss_torch(ifft2c(input_kspace)), -1, 0)   # [2, height, width]
    train_inputs, mean, std = normalize_separate_over_ch(train_inputs, eps=1e-11)
    
    # gt image by normalized kspace: x
    target_image_1c = rss_torch(complex_abs(ifft2c(origk))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    binary_mask_target_image_1c = (target_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
    crop_binary_mask_target_image_1c = center_crop( binary_mask_target_image_1c, crop_size )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]  
        model_output = model_output.squeeze(0) * std + mean     
        model_output = torch.moveaxis(model_output.unsqueeze(0), 1, -1 )    #[1, height, width, 2]

        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, input_kspace) / torch.sum(torch.abs(input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
        # center crop for SSIM
        crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
    
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Training Self-Loss: {loss_self.item():.4f}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9172107577323914
# The best SSIM epoch:  213
# Testing sample:  2
# The best SSIM through training process: 0.864666759967804
# The best SSIM epoch:  262
# Testing sample:  3
# The best SSIM through training process: 0.8826671838760376
# The best SSIM epoch:  312
# Testing sample:  4
# The best SSIM through training process: 0.8927406072616577
# The best SSIM epoch:  454
# Testing sample:  5
# The best SSIM through training process: 0.8841856718063354
# The best SSIM epoch:  388
# Testing sample:  6
# The best SSIM through training process: 0.9007297158241272
# The best SSIM epoch:  191
# Testing sample:  7
# The best SSIM through training process: 0.8817299604415894
# The best SSIM epoch:  296
# Testing sample:  8
# The best SSIM through training process: 0.858948826789856
# The best SSIM epoch:  209
# Testing sample:  9
# The best SSIM through training process: 0.873852550983429
# The best SSIM epoch:  324
# Testing sample:  10
# The best SSIM through training process: 0.8733603954315186
# The best SSIM epoch:  305
# Testing sample:  11
# The best SSIM through training process: 0.8750428557395935
# The best SSIM epoch:  334
# Testing sample:  12
# The best SSIM through training process: 0.8857787251472473
# The best SSIM epoch:  285
# Testing sample:  13
# The best SSIM through training process: 0.9012753963470459
# The best SSIM epoch:  449
# Testing sample:  14
# The best SSIM through training process: 0.9099225401878357
# The best SSIM epoch:  494
# Testing sample:  15
# The best SSIM through training process: 0.8819260597229004
# The best SSIM epoch:  341
# Testing sample:  16
# The best SSIM through training process: 0.9083242416381836
# The best SSIM epoch:  347
# Testing sample:  17
# The best SSIM through training process: 0.8928080201148987
# The best SSIM epoch:  449
# Testing sample:  18
# The best SSIM through training process: 0.864850640296936
# The best SSIM epoch:  331
# Testing sample:  19
# The best SSIM through training process: 0.9040152430534363
# The best SSIM epoch:  240
# Testing sample:  20
# The best SSIM through training process: 0.9358676671981812
# The best SSIM epoch:  117
# Testing sample:  21
# The best SSIM through training process: 0.9299217462539673
# The best SSIM epoch:  119
# Testing sample:  22
# The best SSIM through training process: 0.8766971826553345
# The best SSIM epoch:  255
# Testing sample:  23
# The best SSIM through training process: 0.9029524326324463
# The best SSIM epoch:  495
# Testing sample:  24
# The best SSIM through training process: 0.8968125581741333
# The best SSIM epoch:  349
# Testing sample:  25
# The best SSIM through training process: 0.8879406452178955
# The best SSIM epoch:  315
# Testing sample:  26
# The best SSIM through training process: 0.9094283580780029
# The best SSIM epoch:  119
# Testing sample:  27
# The best SSIM through training process: 0.8661555051803589
# The best SSIM epoch:  304
# Testing sample:  28
# The best SSIM through training process: 0.8797533512115479
# The best SSIM epoch:  234
# Testing sample:  29
# The best SSIM through training process: 0.8960680961608887
# The best SSIM epoch:  471
# Testing sample:  30
# The best SSIM through training process: 0.8743912577629089
# The best SSIM epoch:  113
# Testing sample:  31
# The best SSIM through training process: 0.8623228073120117
# The best SSIM epoch:  314
# Testing sample:  32
# The best SSIM through training process: 0.8829270601272583
# The best SSIM epoch:  346
# Testing sample:  33
# The best SSIM through training process: 0.8923456072807312
# The best SSIM epoch:  388
# Testing sample:  34
# The best SSIM through training process: 0.8837346434593201
# The best SSIM epoch:  494
# Testing sample:  35
# The best SSIM through training process: 0.9120262265205383
# The best SSIM epoch:  165
# Testing sample:  36
# The best SSIM through training process: 0.8729753494262695
# The best SSIM epoch:  293
# Testing sample:  37
# The best SSIM through training process: 0.8758530020713806
# The best SSIM epoch:  237
# Testing sample:  38
# The best SSIM through training process: 0.894432544708252
# The best SSIM epoch:  144
# Testing sample:  39
# The best SSIM through training process: 0.9164312481880188
# The best SSIM epoch:  283
# Testing sample:  40
# The best SSIM through training process: 0.9053133726119995
# The best SSIM epoch:  255
# Testing sample:  41
# The best SSIM through training process: 0.8751580119132996
# The best SSIM epoch:  307
# Testing sample:  42
# The best SSIM through training process: 0.8942161202430725
# The best SSIM epoch:  443
# Testing sample:  43
# The best SSIM through training process: 0.8922975659370422
# The best SSIM epoch:  93
# Testing sample:  44
# The best SSIM through training process: 0.8911654949188232
# The best SSIM epoch:  261
# Testing sample:  45
# The best SSIM through training process: 0.9245514869689941
# The best SSIM epoch:  125
# Testing sample:  46
# The best SSIM through training process: 0.863143801689148
# The best SSIM epoch:  498
# Testing sample:  47
# The best SSIM through training process: 0.9112664461135864
# The best SSIM epoch:  405
# Testing sample:  48
# The best SSIM through training process: 0.8917409777641296
# The best SSIM epoch:  103
# Testing sample:  49
# The best SSIM through training process: 0.8101716041564941
# The best SSIM epoch:  494
# Testing sample:  50
# The best SSIM through training process: 0.8935251235961914
# The best SSIM epoch:  143
# Testing sample:  51
# The best SSIM through training process: 0.8982616662979126
# The best SSIM epoch:  276
# Testing sample:  52
# The best SSIM through training process: 0.8769176602363586
# The best SSIM epoch:  498
# Testing sample:  53
# The best SSIM through training process: 0.888463020324707
# The best SSIM epoch:  233
# Testing sample:  54
# The best SSIM through training process: 0.9277440905570984
# The best SSIM epoch:  416
# Testing sample:  55
# The best SSIM through training process: 0.8887642025947571
# The best SSIM epoch:  265
# Testing sample:  56
# The best SSIM through training process: 0.8986203670501709
# The best SSIM epoch:  493
# Testing sample:  57
# The best SSIM through training process: 0.8995735049247742
# The best SSIM epoch:  291
# Testing sample:  58
# The best SSIM through training process: 0.8860974907875061
# The best SSIM epoch:  494
# Testing sample:  59
# The best SSIM through training process: 0.9134436845779419
# The best SSIM epoch:  163
# Testing sample:  60
# The best SSIM through training process: 0.8619927763938904
# The best SSIM epoch:  316
# Testing sample:  61
# The best SSIM through training process: 0.8798505663871765
# The best SSIM epoch:  360
# Testing sample:  62
# The best SSIM through training process: 0.8617843985557556
# The best SSIM epoch:  295
# Testing sample:  63
# The best SSIM through training process: 0.9001135230064392
# The best SSIM epoch:  80
# Testing sample:  64
# The best SSIM through training process: 0.8910556435585022
# The best SSIM epoch:  349
# Testing sample:  65
# The best SSIM through training process: 0.8826471567153931
# The best SSIM epoch:  261
# Testing sample:  66
# The best SSIM through training process: 0.9286374449729919
# The best SSIM epoch:  206
# Testing sample:  67
# The best SSIM through training process: 0.8979923129081726
# The best SSIM epoch:  136
# Testing sample:  68
# The best SSIM through training process: 0.904175341129303
# The best SSIM epoch:  147
# Testing sample:  69
# The best SSIM through training process: 0.8831146359443665
# The best SSIM epoch:  370
# Testing sample:  70
# The best SSIM through training process: 0.8772675395011902
# The best SSIM epoch:  295
# Testing sample:  71
# The best SSIM through training process: 0.8469434380531311
# The best SSIM epoch:  283
# Testing sample:  72
# The best SSIM through training process: 0.8903601169586182
# The best SSIM epoch:  298
# Testing sample:  73
# The best SSIM through training process: 0.8540095090866089
# The best SSIM epoch:  190
# Testing sample:  74
# The best SSIM through training process: 0.887606143951416
# The best SSIM epoch:  137
# Testing sample:  75
# The best SSIM through training process: 0.8698344230651855
# The best SSIM epoch:  270
# Testing sample:  76
# The best SSIM through training process: 0.8986351490020752
# The best SSIM epoch:  212
# Testing sample:  77
# The best SSIM through training process: 0.902142345905304
# The best SSIM epoch:  498
# Testing sample:  78
# The best SSIM through training process: 0.9188829660415649
# The best SSIM epoch:  334
# Testing sample:  79
# The best SSIM through training process: 0.8879541754722595
# The best SSIM epoch:  213
# Testing sample:  80
# The best SSIM through training process: 0.8660570979118347
# The best SSIM epoch:  452
# Testing sample:  81
# The best SSIM through training process: 0.9162681102752686
# The best SSIM epoch:  122
# Testing sample:  82
# The best SSIM through training process: 0.8758239150047302
# The best SSIM epoch:  277
# Testing sample:  83
# The best SSIM through training process: 0.8988821506500244
# The best SSIM epoch:  258
# Testing sample:  84
# The best SSIM through training process: 0.8840348124504089
# The best SSIM epoch:  230
# Testing sample:  85
# The best SSIM through training process: 0.885185956954956
# The best SSIM epoch:  241
# Testing sample:  86
# The best SSIM through training process: 0.8245022296905518
# The best SSIM epoch:  179
# Testing sample:  87
# The best SSIM through training process: 0.8700698018074036
# The best SSIM epoch:  160
# Testing sample:  88
# The best SSIM through training process: 0.8685123920440674
# The best SSIM epoch:  275
# Testing sample:  89
# The best SSIM through training process: 0.8967671394348145
# The best SSIM epoch:  296
# Testing sample:  90
# The best SSIM through training process: 0.9315073490142822
# The best SSIM epoch:  109
# Testing sample:  91
# The best SSIM through training process: 0.8827248215675354
# The best SSIM epoch:  235
# Testing sample:  92
# The best SSIM through training process: 0.8797351717948914
# The best SSIM epoch:  281
# Testing sample:  93
# The best SSIM through training process: 0.8450455069541931
# The best SSIM epoch:  240
# Testing sample:  94
# The best SSIM through training process: 0.8594537377357483
# The best SSIM epoch:  389
# Testing sample:  95
# The best SSIM through training process: 0.8583425879478455
# The best SSIM epoch:  280
# Testing sample:  96
# The best SSIM through training process: 0.8886536955833435
# The best SSIM epoch:  319
# Testing sample:  97
# The best SSIM through training process: 0.8819091320037842
# The best SSIM epoch:  495
# Testing sample:  98
# The best SSIM through training process: 0.9126699566841125
# The best SSIM epoch:  100
# Testing sample:  99
# The best SSIM through training process: 0.929381787776947
# The best SSIM epoch:  350
# Testing sample:  100
# The best SSIM through training process: 0.8927570581436157
# The best SSIM epoch:  186
# Testing average SSIM loss:  0.8880679315328598
# Testing average SSIM loss epoch:  287.59

# %%
len(best_loss_ssim_history)
# Out:
# 100

# %%
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing average SSIM loss:  0.8880679315328598
# Testing average SSIM loss epoch:  287.59

# %%
adapt_step_loss = []
adapt_step_loss.append(0)
adapt_step_loss.append(1)
adapt_step_loss.append(3)
adapt_step_loss
# Out:
# [0, 1, 3]

# %%
fig, axes = plt.subplots(1, 2, dpi= 300)

axes[0].imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[0].axis('off')

axes[1].imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[1].set_title('Ground Truth')
axes[1].axis('off')

plt.subplots_adjust(wspace=0.1)
plt.show()
