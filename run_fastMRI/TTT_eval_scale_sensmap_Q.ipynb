# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_rss, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttpaper_sensmap_joint(l1_1e-5)Q_T300_300epoch/E_tttpaper_sensmap_joint(l1_1e-5)Q_T300_300epoch_E300.pth'
# '/cheng/metaMRI/metaMRI/save/E_12.5_W_joint(l1_1e-5)P_T300_300epoch/E_12.5_W_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E12.1_maml(l1_out-3-5_in-5)P_T300_300epoch/E12.1_maml(l1_out-3-5_in-5)P_T300_300epoch_E300.pth'
# '/cheng/metaMRI/metaMRI/save/E11/E11.12_joint(l1_1e-5)P_T300_300epoch/E11.12_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
#'/cheng/metaMRI/metaMRI/save/E12.1_joint(l1_1e-5)P_T300_300epoch/E_12.1_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_rss(input_kspace, model)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk * scale_factor), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.961073100566864
# The best SSIM epoch:  110
# Testing sample:  2
# The best SSIM through training process: 0.9256294369697571
# The best SSIM epoch:  76
# Testing sample:  3
# The best SSIM through training process: 0.957497239112854
# The best SSIM epoch:  74
# Testing sample:  4
# The best SSIM through training process: 0.9597775936126709
# The best SSIM epoch:  124
# Testing sample:  5
# The best SSIM through training process: 0.9518955945968628
# The best SSIM epoch:  105
# Testing sample:  6
# The best SSIM through training process: 0.9507807493209839
# The best SSIM epoch:  100
# Testing sample:  7
# The best SSIM through training process: 0.9482244849205017
# The best SSIM epoch:  96
# Testing sample:  8
# The best SSIM through training process: 0.9381837844848633
# The best SSIM epoch:  70
# Testing sample:  9
# The best SSIM through training process: 0.9509103298187256
# The best SSIM epoch:  105
# Testing sample:  10
# The best SSIM through training process: 0.9551315307617188
# The best SSIM epoch:  77
# Testing sample:  11
# The best SSIM through training process: 0.954216718673706
# The best SSIM epoch:  95
# Testing sample:  12
# The best SSIM through training process: 0.9567625522613525
# The best SSIM epoch:  108
# Testing sample:  13
# The best SSIM through training process: 0.9593711495399475
# The best SSIM epoch:  102
# Testing sample:  14
# The best SSIM through training process: 0.9611012935638428
# The best SSIM epoch:  112
# Testing sample:  15
# The best SSIM through training process: 0.9495802521705627
# The best SSIM epoch:  87
# Testing sample:  16
# The best SSIM through training process: 0.9538508057594299
# The best SSIM epoch:  147
# Testing sample:  17
# The best SSIM through training process: 0.9561198949813843
# The best SSIM epoch:  88
# Testing sample:  18
# The best SSIM through training process: 0.9488534927368164
# The best SSIM epoch:  67
# Testing sample:  19
# The best SSIM through training process: 0.9513971209526062
# The best SSIM epoch:  104
# Testing sample:  20
# The best SSIM through training process: 0.9662319421768188
# The best SSIM epoch:  118
# Testing sample:  21
# The best SSIM through training process: 0.9627768993377686
# The best SSIM epoch:  110
# Testing sample:  22
# The best SSIM through training process: 0.9575432538986206
# The best SSIM epoch:  60
# Testing sample:  23
# The best SSIM through training process: 0.9574254751205444
# The best SSIM epoch:  134
# Testing sample:  24
# The best SSIM through training process: 0.9619513750076294
# The best SSIM epoch:  91
# Testing sample:  25
# The best SSIM through training process: 0.9566009640693665
# The best SSIM epoch:  85
# Testing sample:  26
# The best SSIM through training process: 0.9585449695587158
# The best SSIM epoch:  86
# Testing sample:  27
# The best SSIM through training process: 0.949087381362915
# The best SSIM epoch:  96
# Testing sample:  28
# The best SSIM through training process: 0.9497693777084351
# The best SSIM epoch:  100
# Testing sample:  29
# The best SSIM through training process: 0.961193323135376
# The best SSIM epoch:  90
# Testing sample:  30
# The best SSIM through training process: 0.9399576187133789
# The best SSIM epoch:  139
# Testing sample:  31
# The best SSIM through training process: 0.9416980147361755
# The best SSIM epoch:  93
# Testing sample:  32
# The best SSIM through training process: 0.9499821662902832
# The best SSIM epoch:  105
# Testing sample:  33
# The best SSIM through training process: 0.9508184790611267
# The best SSIM epoch:  148
# Testing sample:  34
# The best SSIM through training process: 0.9517912864685059
# The best SSIM epoch:  156
# Testing sample:  35
# The best SSIM through training process: 0.956163763999939
# The best SSIM epoch:  105
# Testing sample:  36
# The best SSIM through training process: 0.9557201266288757
# The best SSIM epoch:  49
# Testing sample:  37
# The best SSIM through training process: 0.9529342651367188
# The best SSIM epoch:  88
# Testing sample:  38
# The best SSIM through training process: 0.949417769908905
# The best SSIM epoch:  118
# Testing sample:  39
# The best SSIM through training process: 0.9627494812011719
# The best SSIM epoch:  202
# Testing sample:  40
# The best SSIM through training process: 0.9588485360145569
# The best SSIM epoch:  113
# Testing sample:  41
# The best SSIM through training process: 0.9519312977790833
# The best SSIM epoch:  90
# Testing sample:  42
# The best SSIM through training process: 0.9518839716911316
# The best SSIM epoch:  99
# Testing sample:  43
# The best SSIM through training process: 0.9529240131378174
# The best SSIM epoch:  52
# Testing sample:  44
# The best SSIM through training process: 0.9601853489875793
# The best SSIM epoch:  78
# Testing sample:  45
# The best SSIM through training process: 0.962053656578064
# The best SSIM epoch:  147
# Testing sample:  46
# The best SSIM through training process: 0.9351114630699158
# The best SSIM epoch:  88
# Testing sample:  47
# The best SSIM through training process: 0.9632577300071716
# The best SSIM epoch:  140
# Testing sample:  48
# The best SSIM through training process: 0.9423163533210754
# The best SSIM epoch:  59
# Testing sample:  49
# The best SSIM through training process: 0.8986875414848328
# The best SSIM epoch:  65
# Testing sample:  50
# The best SSIM through training process: 0.9506052136421204
# The best SSIM epoch:  56
# Testing sample:  51
# The best SSIM through training process: 0.9480642080307007
# The best SSIM epoch:  167
# Testing sample:  52
# The best SSIM through training process: 0.9484173059463501
# The best SSIM epoch:  113
# Testing sample:  53
# The best SSIM through training process: 0.9565117955207825
# The best SSIM epoch:  113
# Testing sample:  54
# The best SSIM through training process: 0.9714760184288025
# The best SSIM epoch:  133
# Testing sample:  55
# The best SSIM through training process: 0.9615894556045532
# The best SSIM epoch:  93
# Testing sample:  56
# The best SSIM through training process: 0.9559134840965271
# The best SSIM epoch:  104
# Testing sample:  57
# The best SSIM through training process: 0.963901162147522
# The best SSIM epoch:  96
# Testing sample:  58
# The best SSIM through training process: 0.948147714138031
# The best SSIM epoch:  98
# Testing sample:  59
# The best SSIM through training process: 0.9673475027084351
# The best SSIM epoch:  108
# Testing sample:  60
# The best SSIM through training process: 0.9403752088546753
# The best SSIM epoch:  61
# Testing sample:  61
# The best SSIM through training process: 0.9583793878555298
# The best SSIM epoch:  95
# Testing sample:  62
# The best SSIM through training process: 0.9451445937156677
# The best SSIM epoch:  115
# Testing sample:  63
# The best SSIM through training process: 0.9475204944610596
# The best SSIM epoch:  62
# Testing sample:  64
# The best SSIM through training process: 0.9568017721176147
# The best SSIM epoch:  121
# Testing sample:  65
# The best SSIM through training process: 0.9618751406669617
# The best SSIM epoch:  80
# Testing sample:  66
# The best SSIM through training process: 0.9702706933021545
# The best SSIM epoch:  103
# Testing sample:  67
# The best SSIM through training process: 0.9459481239318848
# The best SSIM epoch:  89
# Testing sample:  68
# The best SSIM through training process: 0.9522016048431396
# The best SSIM epoch:  94
# Testing sample:  69
# The best SSIM through training process: 0.9511620998382568
# The best SSIM epoch:  138
# Testing sample:  70
# The best SSIM through training process: 0.9568935036659241
# The best SSIM epoch:  98
# Testing sample:  71
# The best SSIM through training process: 0.9447728991508484
# The best SSIM epoch:  50
# Testing sample:  72
# The best SSIM through training process: 0.9589605927467346
# The best SSIM epoch:  93
# Testing sample:  73
# The best SSIM through training process: 0.9416815042495728
# The best SSIM epoch:  95
# Testing sample:  74
# The best SSIM through training process: 0.9448581337928772
# The best SSIM epoch:  80
# Testing sample:  75
# The best SSIM through training process: 0.9518940448760986
# The best SSIM epoch:  57
# Testing sample:  76
# The best SSIM through training process: 0.9535547494888306
# The best SSIM epoch:  106
# Testing sample:  77
# The best SSIM through training process: 0.9615562558174133
# The best SSIM epoch:  126
# Testing sample:  78
# The best SSIM through training process: 0.9685670733451843
# The best SSIM epoch:  134
# Testing sample:  79
# The best SSIM through training process: 0.9581749439239502
# The best SSIM epoch:  73
# Testing sample:  80
# The best SSIM through training process: 0.9374921917915344
# The best SSIM epoch:  140
# Testing sample:  81
# The best SSIM through training process: 0.9532264471054077
# The best SSIM epoch:  129
# Testing sample:  82
# The best SSIM through training process: 0.9505218863487244
# The best SSIM epoch:  103
# Testing sample:  83
# The best SSIM through training process: 0.9533186554908752
# The best SSIM epoch:  82
# Testing sample:  84
# The best SSIM through training process: 0.9618698954582214
# The best SSIM epoch:  58
# Testing sample:  85
# The best SSIM through training process: 0.9626154899597168
# The best SSIM epoch:  69
# Testing sample:  86
# The best SSIM through training process: 0.9053356647491455
# The best SSIM epoch:  70
# Testing sample:  87
# The best SSIM through training process: 0.9393825531005859
# The best SSIM epoch:  77
# Testing sample:  88
# The best SSIM through training process: 0.9519231915473938
# The best SSIM epoch:  83
# Testing sample:  89
# The best SSIM through training process: 0.9597651958465576
# The best SSIM epoch:  91
# Testing sample:  90
# The best SSIM through training process: 0.962282657623291
# The best SSIM epoch:  95
# Testing sample:  91
# The best SSIM through training process: 0.9422219395637512
# The best SSIM epoch:  144
# Testing sample:  92
# The best SSIM through training process: 0.9558372497558594
# The best SSIM epoch:  97
# Testing sample:  93
# The best SSIM through training process: 0.9357131719589233
# The best SSIM epoch:  56
# Testing sample:  94
# The best SSIM through training process: 0.9462988972663879
# The best SSIM epoch:  65
# Testing sample:  95
# The best SSIM through training process: 0.9406543970108032
# The best SSIM epoch:  115
# Testing sample:  96
# The best SSIM through training process: 0.9579195976257324
# The best SSIM epoch:  100
# Testing sample:  97
# The best SSIM through training process: 0.947614848613739
# The best SSIM epoch:  123
# Testing sample:  98
# The best SSIM through training process: 0.9509283900260925
# The best SSIM epoch:  104
# Testing sample:  99
# The best SSIM through training process: 0.9686217308044434
# The best SSIM epoch:  138
# Testing sample:  100
# The best SSIM through training process: 0.9563422799110413
# The best SSIM epoch:  108
# Testing average SSIM loss:  0.9524236798286438
# Testing average SSIM loss epoch:  99.49

# %%
fig, axes = plt.subplots(1, 2, dpi= 300)

axes[0].imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[0].axis('off')

axes[1].imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[1].set_title('Ground Truth')
axes[1].axis('off')

plt.subplots_adjust(wspace=0.1)
plt.show()
