# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E14.2_maml_out_k-sup(l1_out-5_in-5)Q_T300_300epoch/E14.2_maml_out_k-sup(l1_out-5_in-5)Q_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9673693776130676
# The best SSIM epoch:  102
# Testing sample:  2
# The best SSIM through training process: 0.9278498291969299
# The best SSIM epoch:  65
# Testing sample:  3
# The best SSIM through training process: 0.960387110710144
# The best SSIM epoch:  76
# Testing sample:  4
# The best SSIM through training process: 0.9661362171173096
# The best SSIM epoch:  122
# Testing sample:  5
# The best SSIM through training process: 0.9550907611846924
# The best SSIM epoch:  73
# Testing sample:  6
# The best SSIM through training process: 0.9583099484443665
# The best SSIM epoch:  95
# Testing sample:  7
# The best SSIM through training process: 0.9481788277626038
# The best SSIM epoch:  77
# Testing sample:  8
# The best SSIM through training process: 0.9377683401107788
# The best SSIM epoch:  52
# Testing sample:  9
# The best SSIM through training process: 0.9533442258834839
# The best SSIM epoch:  88
# Testing sample:  10
# The best SSIM through training process: 0.9576643705368042
# The best SSIM epoch:  67
# Testing sample:  11
# The best SSIM through training process: 0.9582703113555908
# The best SSIM epoch:  102
# Testing sample:  12
# The best SSIM through training process: 0.9620891213417053
# The best SSIM epoch:  109
# Testing sample:  13
# The best SSIM through training process: 0.967012882232666
# The best SSIM epoch:  91
# Testing sample:  14
# The best SSIM through training process: 0.966941773891449
# The best SSIM epoch:  116
# Testing sample:  15
# The best SSIM through training process: 0.9451040029525757
# The best SSIM epoch:  95
# Testing sample:  16
# The best SSIM through training process: 0.9666412472724915
# The best SSIM epoch:  96
# Testing sample:  17
# The best SSIM through training process: 0.9593809843063354
# The best SSIM epoch:  62
# Testing sample:  18
# The best SSIM through training process: 0.9462883472442627
# The best SSIM epoch:  59
# Testing sample:  19
# The best SSIM through training process: 0.9571858048439026
# The best SSIM epoch:  75
# Testing sample:  20
# The best SSIM through training process: 0.9723523855209351
# The best SSIM epoch:  100
# Testing sample:  21
# The best SSIM through training process: 0.9691917896270752
# The best SSIM epoch:  87
# Testing sample:  22
# The best SSIM through training process: 0.9563754796981812
# The best SSIM epoch:  57
# Testing sample:  23
# The best SSIM through training process: 0.9633030295372009
# The best SSIM epoch:  93
# Testing sample:  24
# The best SSIM through training process: 0.9680048227310181
# The best SSIM epoch:  107
# Testing sample:  25
# The best SSIM through training process: 0.9588282108306885
# The best SSIM epoch:  70
# Testing sample:  26
# The best SSIM through training process: 0.9620524644851685
# The best SSIM epoch:  83
# Testing sample:  27
# The best SSIM through training process: 0.9551256895065308
# The best SSIM epoch:  79
# Testing sample:  28
# The best SSIM through training process: 0.9538255333900452
# The best SSIM epoch:  78
# Testing sample:  29
# The best SSIM through training process: 0.9651318192481995
# The best SSIM epoch:  96
# Testing sample:  30
# The best SSIM through training process: 0.9387422204017639
# The best SSIM epoch:  55
# Testing sample:  31
# The best SSIM through training process: 0.9466299414634705
# The best SSIM epoch:  86
# Testing sample:  32
# The best SSIM through training process: 0.9500198364257812
# The best SSIM epoch:  83
# Testing sample:  33
# The best SSIM through training process: 0.9613807201385498
# The best SSIM epoch:  104
# Testing sample:  34
# The best SSIM through training process: 0.9579112529754639
# The best SSIM epoch:  101
# Testing sample:  35
# The best SSIM through training process: 0.957671582698822
# The best SSIM epoch:  87
# Testing sample:  36
# The best SSIM through training process: 0.9583016037940979
# The best SSIM epoch:  49
# Testing sample:  37
# The best SSIM through training process: 0.9519206285476685
# The best SSIM epoch:  53
# Testing sample:  38
# The best SSIM through training process: 0.956002950668335
# The best SSIM epoch:  98
# Testing sample:  39
# The best SSIM through training process: 0.9673317670822144
# The best SSIM epoch:  154
# Testing sample:  40
# The best SSIM through training process: 0.9661822319030762
# The best SSIM epoch:  100
# Testing sample:  41
# The best SSIM through training process: 0.9581228494644165
# The best SSIM epoch:  75
# Testing sample:  42
# The best SSIM through training process: 0.9531510472297668
# The best SSIM epoch:  89
# Testing sample:  43
# The best SSIM through training process: 0.9548566937446594
# The best SSIM epoch:  52
# Testing sample:  44
# The best SSIM through training process: 0.9610791802406311
# The best SSIM epoch:  74
# Testing sample:  45
# The best SSIM through training process: 0.9676420092582703
# The best SSIM epoch:  104
# Testing sample:  46
# The best SSIM through training process: 0.9309189319610596
# The best SSIM epoch:  64
# Testing sample:  47
# The best SSIM through training process: 0.9686816930770874
# The best SSIM epoch:  104
# Testing sample:  48
# The best SSIM through training process: 0.9426308870315552
# The best SSIM epoch:  51
# Testing sample:  49
# The best SSIM through training process: 0.8920463919639587
# The best SSIM epoch:  40
# Testing sample:  50
# The best SSIM through training process: 0.9517982006072998
# The best SSIM epoch:  58
# Testing sample:  51
# The best SSIM through training process: 0.9603444933891296
# The best SSIM epoch:  103
# Testing sample:  52
# The best SSIM through training process: 0.9502543807029724
# The best SSIM epoch:  85
# Testing sample:  53
# The best SSIM through training process: 0.9589099884033203
# The best SSIM epoch:  98
# Testing sample:  54
# The best SSIM through training process: 0.9788488745689392
# The best SSIM epoch:  142
# Testing sample:  55
# The best SSIM through training process: 0.9629467129707336
# The best SSIM epoch:  78
# Testing sample:  56
# The best SSIM through training process: 0.9599460959434509
# The best SSIM epoch:  94
# Testing sample:  57
# The best SSIM through training process: 0.9674656391143799
# The best SSIM epoch:  100
# Testing sample:  58
# The best SSIM through training process: 0.9518822431564331
# The best SSIM epoch:  72
# Testing sample:  59
# The best SSIM through training process: 0.9710446000099182
# The best SSIM epoch:  111
# Testing sample:  60
# The best SSIM through training process: 0.9354905486106873
# The best SSIM epoch:  60
# Testing sample:  61
# The best SSIM through training process: 0.967237651348114
# The best SSIM epoch:  96
# Testing sample:  62
# The best SSIM through training process: 0.9500699043273926
# The best SSIM epoch:  114
# Testing sample:  63
# The best SSIM through training process: 0.9494091272354126
# The best SSIM epoch:  55
# Testing sample:  64
# The best SSIM through training process: 0.9678501486778259
# The best SSIM epoch:  116
# Testing sample:  65
# The best SSIM through training process: 0.9622374773025513
# The best SSIM epoch:  79
# Testing sample:  66
# The best SSIM through training process: 0.9745753407478333
# The best SSIM epoch:  118
# Testing sample:  67
# The best SSIM through training process: 0.9446178674697876
# The best SSIM epoch:  76
# Testing sample:  68
# The best SSIM through training process: 0.9524896740913391
# The best SSIM epoch:  97
# Testing sample:  69
# The best SSIM through training process: 0.9644182920455933
# The best SSIM epoch:  107
# Testing sample:  70
# The best SSIM through training process: 0.9641587734222412
# The best SSIM epoch:  92
# Testing sample:  71
# The best SSIM through training process: 0.9441972970962524
# The best SSIM epoch:  57
# Testing sample:  72
# The best SSIM through training process: 0.9612956643104553
# The best SSIM epoch:  81
# Testing sample:  73
# The best SSIM through training process: 0.9399898648262024
# The best SSIM epoch:  72
# Testing sample:  74
# The best SSIM through training process: 0.9498535394668579
# The best SSIM epoch:  71
# Testing sample:  75
# The best SSIM through training process: 0.9481090307235718
# The best SSIM epoch:  54
# Testing sample:  76
# The best SSIM through training process: 0.9576359391212463
# The best SSIM epoch:  104
# Testing sample:  77
# The best SSIM through training process: 0.9643388390541077
# The best SSIM epoch:  97
# Testing sample:  78
# The best SSIM through training process: 0.9727009534835815
# The best SSIM epoch:  95
# Testing sample:  79
# The best SSIM through training process: 0.9592723846435547
# The best SSIM epoch:  70
# Testing sample:  80
# The best SSIM through training process: 0.944370687007904
# The best SSIM epoch:  99
# Testing sample:  81
# The best SSIM through training process: 0.9583167433738708
# The best SSIM epoch:  106
# Testing sample:  82
# The best SSIM through training process: 0.954445481300354
# The best SSIM epoch:  110
# Testing sample:  83
# The best SSIM through training process: 0.9578648209571838
# The best SSIM epoch:  76
# Testing sample:  84
# The best SSIM through training process: 0.9616367816925049
# The best SSIM epoch:  61
# Testing sample:  85
# The best SSIM through training process: 0.9633502960205078
# The best SSIM epoch:  74
# Testing sample:  86
# The best SSIM through training process: 0.8971176743507385
# The best SSIM epoch:  64
# Testing sample:  87
# The best SSIM through training process: 0.9434350728988647
# The best SSIM epoch:  70
# Testing sample:  88
# The best SSIM through training process: 0.9549286365509033
# The best SSIM epoch:  59
# Testing sample:  89
# The best SSIM through training process: 0.9631273150444031
# The best SSIM epoch:  76
# Testing sample:  90
# The best SSIM through training process: 0.9665945768356323
# The best SSIM epoch:  90
# Testing sample:  91
# The best SSIM through training process: 0.948665976524353
# The best SSIM epoch:  105
# Testing sample:  92
# The best SSIM through training process: 0.9619670510292053
# The best SSIM epoch:  81
# Testing sample:  93
# The best SSIM through training process: 0.9370194673538208
# The best SSIM epoch:  63
# Testing sample:  94
# The best SSIM through training process: 0.9435678720474243
# The best SSIM epoch:  55
# Testing sample:  95
# Epoch 8/500, SSIM: 0.9029
