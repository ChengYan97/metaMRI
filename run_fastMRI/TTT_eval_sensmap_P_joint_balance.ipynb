# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttpaper_sensmap_balance_joint(l1_1e-5)P_T300_300epoch/E_tttpaper_sensmap_balance_joint(l1_1e-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9501468539237976
# The best SSIM epoch:  271
# Testing sample:  2
# The best SSIM through training process: 0.9024434089660645
# The best SSIM epoch:  313
# Testing sample:  3
# The best SSIM through training process: 0.9432895183563232
# The best SSIM epoch:  263
# Testing sample:  4
# The best SSIM through training process: 0.9482523202896118
# The best SSIM epoch:  446
# Testing sample:  5
# The best SSIM through training process: 0.9355440735816956
# The best SSIM epoch:  363
# Testing sample:  6
# The best SSIM through training process: 0.9365395903587341
# The best SSIM epoch:  314
# Testing sample:  7
# The best SSIM through training process: 0.9320569634437561
# The best SSIM epoch:  398
# Testing sample:  8
# The best SSIM through training process: 0.9257089495658875
# The best SSIM epoch:  155
# Testing sample:  9
# The best SSIM through training process: 0.9406673312187195
# The best SSIM epoch:  312
# Testing sample:  10
# The best SSIM through training process: 0.9390929341316223
# The best SSIM epoch:  232
# Testing sample:  11
# The best SSIM through training process: 0.9408831596374512
# The best SSIM epoch:  380
# Testing sample:  12
# The best SSIM through training process: 0.9431688189506531
# The best SSIM epoch:  391
# Testing sample:  13
# The best SSIM through training process: 0.9484935998916626
# The best SSIM epoch:  325
# Testing sample:  14
# The best SSIM through training process: 0.9496400952339172
# The best SSIM epoch:  464
# Testing sample:  15
# The best SSIM through training process: 0.936791181564331
# The best SSIM epoch:  264
# Testing sample:  16
# The best SSIM through training process: 0.9445969462394714
# The best SSIM epoch:  498
# Testing sample:  17
# The best SSIM through training process: 0.9404845237731934
# The best SSIM epoch:  251
# Testing sample:  18
# The best SSIM through training process: 0.9314911365509033
# The best SSIM epoch:  157
# Testing sample:  19
# The best SSIM through training process: 0.9395810961723328
# The best SSIM epoch:  327
# Testing sample:  20
# The best SSIM through training process: 0.9571118950843811
# The best SSIM epoch:  491
# Testing sample:  21
# The best SSIM through training process: 0.9471533298492432
# The best SSIM epoch:  423
# Testing sample:  22
# The best SSIM through training process: 0.9431107640266418
# The best SSIM epoch:  170
# Testing sample:  23
# The best SSIM through training process: 0.9476014375686646
# The best SSIM epoch:  489
# Testing sample:  24
# The best SSIM through training process: 0.9467151761054993
# The best SSIM epoch:  384
# Testing sample:  25
# The best SSIM through training process: 0.9428644180297852
# The best SSIM epoch:  252
# Testing sample:  26
# The best SSIM through training process: 0.9394545555114746
# The best SSIM epoch:  270
# Testing sample:  27
# The best SSIM through training process: 0.9354646801948547
# The best SSIM epoch:  301
# Testing sample:  28
# The best SSIM through training process: 0.9320017099380493
# The best SSIM epoch:  227
# Testing sample:  29
# The best SSIM through training process: 0.950005054473877
# The best SSIM epoch:  396
# Testing sample:  30
# The best SSIM through training process: 0.9207133650779724
# The best SSIM epoch:  340
# Testing sample:  31
# The best SSIM through training process: 0.9262433648109436
# The best SSIM epoch:  280
# Testing sample:  32
# The best SSIM through training process: 0.9355697631835938
# The best SSIM epoch:  307
# Testing sample:  33
# The best SSIM through training process: 0.9387781620025635
# The best SSIM epoch:  479
# Testing sample:  34
# The best SSIM through training process: 0.9402977228164673
# The best SSIM epoch:  411
# Testing sample:  35
# The best SSIM through training process: 0.9451386332511902
# The best SSIM epoch:  223
# Testing sample:  36
# The best SSIM through training process: 0.9402251839637756
# The best SSIM epoch:  174
# Testing sample:  37
# The best SSIM through training process: 0.9416646361351013
# The best SSIM epoch:  142
# Testing sample:  38
# The best SSIM through training process: 0.9352871775627136
# The best SSIM epoch:  271
# Testing sample:  39
# The best SSIM through training process: 0.9557994604110718
# The best SSIM epoch:  480
# Testing sample:  40
# The best SSIM through training process: 0.9466094970703125
# The best SSIM epoch:  391
# Testing sample:  41
# The best SSIM through training process: 0.9383509159088135
# The best SSIM epoch:  271
# Testing sample:  42
# The best SSIM through training process: 0.9359994530677795
# The best SSIM epoch:  359
# Testing sample:  43
# The best SSIM through training process: 0.9346359372138977
# The best SSIM epoch:  188
# Testing sample:  44
# The best SSIM through training process: 0.9451454877853394
# The best SSIM epoch:  313
# Testing sample:  45
# The best SSIM through training process: 0.9457018971443176
# The best SSIM epoch:  467
# Testing sample:  46
# The best SSIM through training process: 0.919174075126648
# The best SSIM epoch:  222
# Testing sample:  47
# The best SSIM through training process: 0.9510303139686584
# The best SSIM epoch:  483
# Testing sample:  48
# The best SSIM through training process: 0.9252585768699646
# The best SSIM epoch:  145
# Testing sample:  49
# The best SSIM through training process: 0.8829255104064941
# The best SSIM epoch:  100
# Testing sample:  50
# The best SSIM through training process: 0.9365137219429016
# The best SSIM epoch:  129
# Testing sample:  51
# The best SSIM through training process: 0.9336761832237244
# The best SSIM epoch:  477
# Testing sample:  52
# The best SSIM through training process: 0.9353248476982117
# The best SSIM epoch:  442
# Testing sample:  53
# The best SSIM through training process: 0.9422489404678345
# The best SSIM epoch:  362
# Testing sample:  54
# The best SSIM through training process: 0.9649175405502319
# The best SSIM epoch:  454
# Testing sample:  55
# The best SSIM through training process: 0.9473941326141357
# The best SSIM epoch:  252
# Testing sample:  56
# The best SSIM through training process: 0.9435826539993286
# The best SSIM epoch:  472
# Testing sample:  57
# The best SSIM through training process: 0.9526029825210571
# The best SSIM epoch:  335
# Testing sample:  58
# The best SSIM through training process: 0.936653733253479
# The best SSIM epoch:  348
# Testing sample:  59
# The best SSIM through training process: 0.9558247327804565
# The best SSIM epoch:  280
# Testing sample:  60
# The best SSIM through training process: 0.9252797365188599
# The best SSIM epoch:  245
# Testing sample:  61
# The best SSIM through training process: 0.9448522925376892
# The best SSIM epoch:  345
# Testing sample:  62
# The best SSIM through training process: 0.9317718744277954
# The best SSIM epoch:  383
# Testing sample:  63
# The best SSIM through training process: 0.9278481602668762
# The best SSIM epoch:  191
# Testing sample:  64
# The best SSIM through training process: 0.945188045501709
# The best SSIM epoch:  493
# Testing sample:  65
# The best SSIM through training process: 0.9473931789398193
# The best SSIM epoch:  272
# Testing sample:  66
# The best SSIM through training process: 0.9551880955696106
# The best SSIM epoch:  421
# Testing sample:  67
# The best SSIM through training process: 0.9349028468132019
# The best SSIM epoch:  181
# Testing sample:  68
# The best SSIM through training process: 0.940924882888794
# The best SSIM epoch:  298
# Testing sample:  69
# The best SSIM through training process: 0.9406793713569641
# The best SSIM epoch:  449
# Testing sample:  70
# The best SSIM through training process: 0.9406936764717102
# The best SSIM epoch:  382
# Testing sample:  71
# The best SSIM through training process: 0.9246566891670227
# The best SSIM epoch:  168
# Testing sample:  72
# The best SSIM through training process: 0.9456676840782166
# The best SSIM epoch:  291
# Testing sample:  73
# The best SSIM through training process: 0.9245361089706421
# The best SSIM epoch:  405
# Testing sample:  74
# The best SSIM through training process: 0.9282118082046509
# The best SSIM epoch:  257
# Testing sample:  75
# The best SSIM through training process: 0.935804009437561
# The best SSIM epoch:  204
# Testing sample:  76
# The best SSIM through training process: 0.939835250377655
# The best SSIM epoch:  300
# Testing sample:  77
# The best SSIM through training process: 0.9483226537704468
# The best SSIM epoch:  404
# Testing sample:  78
# The best SSIM through training process: 0.9598485231399536
# The best SSIM epoch:  391
# Testing sample:  79
# The best SSIM through training process: 0.9415816068649292
# The best SSIM epoch:  219
# Testing sample:  80
# The best SSIM through training process: 0.9214510917663574
# The best SSIM epoch:  497
# Testing sample:  81
# The best SSIM through training process: 0.9402501583099365
# The best SSIM epoch:  492
# Testing sample:  82
# The best SSIM through training process: 0.938319981098175
# The best SSIM epoch:  395
# Testing sample:  83
# The best SSIM through training process: 0.9453478455543518
# The best SSIM epoch:  250
# Testing sample:  84
# The best SSIM through training process: 0.9463546276092529
# The best SSIM epoch:  193
# Testing sample:  85
# The best SSIM through training process: 0.9483155012130737
# The best SSIM epoch:  277
# Testing sample:  86
# The best SSIM through training process: 0.8870806694030762
# The best SSIM epoch:  77
# Testing sample:  87
# The best SSIM through training process: 0.9234364032745361
# The best SSIM epoch:  229
# Testing sample:  88
# The best SSIM through training process: 0.9360251426696777
# The best SSIM epoch:  226
# Testing sample:  89
# The best SSIM through training process: 0.9473364949226379
# The best SSIM epoch:  276
# Testing sample:  90
# The best SSIM through training process: 0.9494289755821228
# The best SSIM epoch:  443
# Testing sample:  91
# The best SSIM through training process: 0.9318603277206421
# The best SSIM epoch:  327
# Testing sample:  92
# The best SSIM through training process: 0.9404253363609314
# The best SSIM epoch:  273
# Testing sample:  93
# The best SSIM through training process: 0.9172583818435669
# The best SSIM epoch:  239
# Testing sample:  94
# The best SSIM through training process: 0.9328996539115906
# The best SSIM epoch:  131
# Testing sample:  95
# The best SSIM through training process: 0.9259167909622192
# The best SSIM epoch:  346
# Testing sample:  96
# The best SSIM through training process: 0.9452478885650635
# The best SSIM epoch:  236
# Testing sample:  97
# The best SSIM through training process: 0.9356999397277832
# The best SSIM epoch:  486
# Testing sample:  98
# The best SSIM through training process: 0.934974730014801
# The best SSIM epoch:  365
# Testing sample:  99
# The best SSIM through training process: 0.9564054608345032
# The best SSIM epoch:  476
# Testing sample:  100
# The best SSIM through training process: 0.9408724904060364
# The best SSIM epoch:  266
# Testing average SSIM loss:  0.9385173851251603
# Testing average SSIM loss epoch:  319.23

# %% [markdown]
# without TTT

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 100it [01:30,  1.10it/s]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.7334694278240204
