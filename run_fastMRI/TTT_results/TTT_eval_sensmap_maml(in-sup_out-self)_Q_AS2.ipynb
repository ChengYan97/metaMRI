# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_TTTmaml_in-sup_out-self(l1_out-5_in-3_AS-2)Q_T300_300epoch/E_TTTmaml_in-sup_out-self(l1_out-5_in-3_AS-2)Q_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %% [markdown]
# Sensmap

# %%
background_flip = True
eval_with_binary_mask = False
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 200
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9462487697601318
# The best SSIM epoch:  148
# Testing sample:  2
# The best SSIM through training process: 0.9101487994194031
# The best SSIM epoch:  99
# Testing sample:  3
# The best SSIM through training process: 0.9464781880378723
# The best SSIM epoch:  63
# Testing sample:  4
# The best SSIM through training process: 0.9463536739349365
# The best SSIM epoch:  126
# Testing sample:  5
# The best SSIM through training process: 0.9414160251617432
# The best SSIM epoch:  120
# Testing sample:  6
# The best SSIM through training process: 0.933849036693573
# The best SSIM epoch:  126
# Testing sample:  7
# The best SSIM through training process: 0.9327869415283203
# The best SSIM epoch:  123
# Testing sample:  8
# The best SSIM through training process: 0.9285776615142822
# The best SSIM epoch:  62
# Testing sample:  9
# The best SSIM through training process: 0.9428005814552307
# The best SSIM epoch:  103
# Testing sample:  10
# The best SSIM through training process: 0.9433302879333496
# The best SSIM epoch:  66
# Testing sample:  11
# The best SSIM through training process: 0.9407051801681519
# The best SSIM epoch:  100
# Testing sample:  12
# The best SSIM through training process: 0.9419695138931274
# The best SSIM epoch:  127
# Testing sample:  13
# The best SSIM through training process: 0.9495465755462646
# The best SSIM epoch:  120
# Testing sample:  14
# The best SSIM through training process: 0.9453858733177185
# The best SSIM epoch:  124
# Testing sample:  15
# The best SSIM through training process: 0.9403702616691589
# The best SSIM epoch:  74
# Testing sample:  16
# The best SSIM through training process: 0.9400583505630493
# The best SSIM epoch:  161
# Testing sample:  17
# The best SSIM through training process: 0.9477232694625854
# The best SSIM epoch:  93
# Testing sample:  18
# The best SSIM through training process: 0.9394829869270325
# The best SSIM epoch:  60
# Testing sample:  19
# The best SSIM through training process: 0.9406116604804993
# The best SSIM epoch:  152
# Testing sample:  20
# The best SSIM through training process: 0.9502081274986267
# The best SSIM epoch:  162
# Testing sample:  21
# The best SSIM through training process: 0.9439482688903809
# The best SSIM epoch:  121
# Testing sample:  22
# The best SSIM through training process: 0.9489993453025818
# The best SSIM epoch:  47
# Testing sample:  23
# The best SSIM through training process: 0.9482899308204651
# The best SSIM epoch:  162
# Testing sample:  24
# The best SSIM through training process: 0.9483076930046082
# The best SSIM epoch:  113
# Testing sample:  25
# The best SSIM through training process: 0.9475706219673157
# The best SSIM epoch:  84
# Testing sample:  26
# The best SSIM through training process: 0.9416079521179199
# The best SSIM epoch:  110
# Testing sample:  27
# The best SSIM through training process: 0.9371191263198853
# The best SSIM epoch:  115
# Testing sample:  28
# The best SSIM through training process: 0.9377543926239014
# The best SSIM epoch:  106
# Testing sample:  29
# The best SSIM through training process: 0.9479280710220337
# The best SSIM epoch:  112
# Testing sample:  30
# The best SSIM through training process: 0.9250165820121765
# The best SSIM epoch:  75
# Testing sample:  31
# The best SSIM through training process: 0.9296867847442627
# The best SSIM epoch:  103
# Testing sample:  32
# The best SSIM through training process: 0.9395056962966919
# The best SSIM epoch:  80
# Testing sample:  33
# The best SSIM through training process: 0.9329169988632202
# The best SSIM epoch:  139
# Testing sample:  34
# The best SSIM through training process: 0.9401366710662842
# The best SSIM epoch:  126
# Testing sample:  35
# The best SSIM through training process: 0.9454889893531799
# The best SSIM epoch:  103
# Testing sample:  36
# The best SSIM through training process: 0.945738673210144
# The best SSIM epoch:  63
# Testing sample:  37
# The best SSIM through training process: 0.945582926273346
# The best SSIM epoch:  57
# Testing sample:  38
# The best SSIM through training process: 0.9352537393569946
# The best SSIM epoch:  139
# Testing sample:  39
# The best SSIM through training process: 0.9449512362480164
# The best SSIM epoch:  173
# Testing sample:  40
# The best SSIM through training process: 0.9446645975112915
# The best SSIM epoch:  124
# Testing sample:  41
# The best SSIM through training process: 0.9372918009757996
# The best SSIM epoch:  104
# Testing sample:  42
# The best SSIM through training process: 0.937171220779419
# The best SSIM epoch:  79
# Testing sample:  43
# The best SSIM through training process: 0.9391710162162781
# The best SSIM epoch:  79
# Testing sample:  44
# The best SSIM through training process: 0.9486730098724365
# The best SSIM epoch:  85
# Testing sample:  45
# The best SSIM through training process: 0.936451256275177
# The best SSIM epoch:  132
# Testing sample:  46
# The best SSIM through training process: 0.9258158802986145
# The best SSIM epoch:  61
# Testing sample:  47
# The best SSIM through training process: 0.9469473361968994
# The best SSIM epoch:  157
# Testing sample:  48
# The best SSIM through training process: 0.9307944178581238
# The best SSIM epoch:  73
# Testing sample:  49
# The best SSIM through training process: 0.8906494975090027
# The best SSIM epoch:  36
# Testing sample:  50
# The best SSIM through training process: 0.9415581226348877
# The best SSIM epoch:  74
# Testing sample:  51
# The best SSIM through training process: 0.9288708567619324
# The best SSIM epoch:  173
# Testing sample:  52
# The best SSIM through training process: 0.939181387424469
# The best SSIM epoch:  199
# Testing sample:  53
# The best SSIM through training process: 0.9416518211364746
# The best SSIM epoch:  133
# Testing sample:  54
# The best SSIM through training process: 0.9617884159088135
# The best SSIM epoch:  146
# Testing sample:  55
# The best SSIM through training process: 0.9512495398521423
# The best SSIM epoch:  90
# Testing sample:  56
# The best SSIM through training process: 0.9425669312477112
# The best SSIM epoch:  117
# Testing sample:  57
# The best SSIM through training process: 0.951462984085083
# The best SSIM epoch:  104
# Testing sample:  58
# The best SSIM through training process: 0.9400227069854736
# The best SSIM epoch:  91
# Testing sample:  59
# The best SSIM through training process: 0.9492486715316772
# The best SSIM epoch:  164
# Testing sample:  60
# The best SSIM through training process: 0.9277130961418152
# The best SSIM epoch:  79
# Testing sample:  61
# The best SSIM through training process: 0.946102499961853
# The best SSIM epoch:  119
# Testing sample:  62
# The best SSIM through training process: 0.9305501580238342
# The best SSIM epoch:  115
# Testing sample:  63
# The best SSIM through training process: 0.9336905479431152
# The best SSIM epoch:  79
# Testing sample:  64
# The best SSIM through training process: 0.9412750005722046
# The best SSIM epoch:  150
# Testing sample:  65
# The best SSIM through training process: 0.9481966495513916
# The best SSIM epoch:  70
# Testing sample:  66
# The best SSIM through training process: 0.9525773525238037
# The best SSIM epoch:  151
# Testing sample:  67
# The best SSIM through training process: 0.93256014585495
# The best SSIM epoch:  99
# Testing sample:  68
# The best SSIM through training process: 0.9417992234230042
# The best SSIM epoch:  107
# Testing sample:  69
# The best SSIM through training process: 0.9362865686416626
# The best SSIM epoch:  171
# Testing sample:  70
# The best SSIM through training process: 0.9406705498695374
# The best SSIM epoch:  114
# Testing sample:  71
# The best SSIM through training process: 0.9304148554801941
# The best SSIM epoch:  56
# Testing sample:  72
# The best SSIM through training process: 0.9475729465484619
# The best SSIM epoch:  88
# Testing sample:  73
# The best SSIM through training process: 0.9298287034034729
# The best SSIM epoch:  105
# Testing sample:  74
# The best SSIM through training process: 0.9280338287353516
# The best SSIM epoch:  125
# Testing sample:  75
# The best SSIM through training process: 0.9399996399879456
# The best SSIM epoch:  47
# Testing sample:  76
# The best SSIM through training process: 0.9295307397842407
# The best SSIM epoch:  143
# Testing sample:  77
# The best SSIM through training process: 0.9466095566749573
# The best SSIM epoch:  79
# Testing sample:  78
# The best SSIM through training process: 0.9619923233985901
# The best SSIM epoch:  144
# Testing sample:  79
# The best SSIM through training process: 0.9471834301948547
# The best SSIM epoch:  73
# Testing sample:  80
# The best SSIM through training process: 0.9207040071487427
# The best SSIM epoch:  143
# Testing sample:  81
# The best SSIM through training process: 0.9284875392913818
# The best SSIM epoch:  136
# Testing sample:  82
# The best SSIM through training process: 0.9391263127326965
# The best SSIM epoch:  153
# Testing sample:  83
# The best SSIM through training process: 0.9461634159088135
# The best SSIM epoch:  109
# Testing sample:  84
# The best SSIM through training process: 0.948883056640625
# The best SSIM epoch:  61
# Testing sample:  85
# The best SSIM through training process: 0.9511817097663879
# The best SSIM epoch:  76
# Testing sample:  86
# The best SSIM through training process: 0.8949503898620605
# The best SSIM epoch:  60
# Testing sample:  87
# The best SSIM through training process: 0.9261875748634338
# The best SSIM epoch:  103
# Testing sample:  88
# The best SSIM through training process: 0.9420126676559448
# The best SSIM epoch:  71
# Testing sample:  89
# The best SSIM through training process: 0.9498556852340698
# The best SSIM epoch:  85
# Testing sample:  90
# The best SSIM through training process: 0.9464033246040344
# The best SSIM epoch:  143
# Testing sample:  91
# The best SSIM through training process: 0.9256129264831543
# The best SSIM epoch:  157
# Testing sample:  92
# The best SSIM through training process: 0.9423415064811707
# The best SSIM epoch:  92
# Testing sample:  93
# The best SSIM through training process: 0.9230265021324158
# The best SSIM epoch:  66
# Testing sample:  94
# The best SSIM through training process: 0.9381811022758484
# The best SSIM epoch:  50
# Testing sample:  95
# The best SSIM through training process: 0.9274041652679443
# The best SSIM epoch:  108
# Testing sample:  96
# The best SSIM through training process: 0.9467774629592896
# The best SSIM epoch:  86
# Testing sample:  97
# The best SSIM through training process: 0.9350957870483398
# The best SSIM epoch:  116
# Testing sample:  98
# The best SSIM through training process: 0.9364936947822571
# The best SSIM epoch:  149
# Testing sample:  99
# The best SSIM through training process: 0.950415849685669
# The best SSIM epoch:  158
# Testing sample:  100
# The best SSIM through training process: 0.9354389905929565
# The best SSIM epoch:  118
# Testing average SSIM loss:  0.9392641842365265
# Testing average SSIM loss epoch:  108.12

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 78it [00:58,  1.27it/s]
# 100it [01:16,  1.32it/s]

# %%
#print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.8705591517686844
