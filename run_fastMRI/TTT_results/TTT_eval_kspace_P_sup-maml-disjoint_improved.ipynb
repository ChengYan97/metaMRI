# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E14.4_maml_in1-4_out_k3-4(l1_out-5_in-5)P_T300_300epoch/E14.4_maml_in1-4_out_k3-4(l1_out-5_in-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
flipped_mask2d = np.logical_not(mask2d).astype(int)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)
flipped_mask = torch.tensor(flipped_mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)
flipped_mask = flipped_mask.to(device)

# %% [markdown]
# ### Test-time training

# %% [markdown]
# ONLY enhance the imaging part, training loss is the same

# %%
background_flip = True
eval_with_binary_mask = False
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        # M(3/4)   FS fθ(A†y) = A fθ(A†y)
        kspace_output = fft2c(complex_mul(model_output, sens_maps)) * flipped_mask
        # M(3/4) + M(1/4)
        improved_kspace_output = kspace_output + scale_input_kspace

        improved_output_image_1c = complex_abs(complex_mul(ifft2c(improved_kspace_output), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)


        # output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (improved_output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( improved_output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9465662240982056
# The best SSIM epoch:  257
# Testing sample:  2
# The best SSIM through training process: 0.897661030292511
# The best SSIM epoch:  188
# Testing sample:  3
# The best SSIM through training process: 0.946230411529541
# The best SSIM epoch:  229
# Testing sample:  4
# The best SSIM through training process: 0.9505788087844849
# The best SSIM epoch:  285
# Testing sample:  5
# The best SSIM through training process: 0.9273910522460938
# The best SSIM epoch:  219
# Testing sample:  6
# The best SSIM through training process: 0.9304304718971252
# The best SSIM epoch:  287
# Testing sample:  7
# The best SSIM through training process: 0.9210543036460876
# The best SSIM epoch:  341
# Testing sample:  8
# The best SSIM through training process: 0.9250267148017883
# The best SSIM epoch:  165
# Testing sample:  9
# The best SSIM through training process: 0.9419720768928528
# The best SSIM epoch:  224
# Testing sample:  10
# The best SSIM through training process: 0.943790078163147
# The best SSIM epoch:  202
# Testing sample:  11
# The best SSIM through training process: 0.9393543601036072
# The best SSIM epoch:  274
# Testing sample:  12
# The best SSIM through training process: 0.9430510401725769
# The best SSIM epoch:  300
# Testing sample:  13
# The best SSIM through training process: 0.9511452317237854
# The best SSIM epoch:  229
# Testing sample:  14
# The best SSIM through training process: 0.9483887553215027
# The best SSIM epoch:  314
# Testing sample:  15
# The best SSIM through training process: 0.9369850754737854
# The best SSIM epoch:  213
# Testing sample:  16
# The best SSIM through training process: 0.9347609877586365
# The best SSIM epoch:  339
# Testing sample:  17
# The best SSIM through training process: 0.9397618174552917
# The best SSIM epoch:  212
# Testing sample:  18
# The best SSIM through training process: 0.9377380609512329
# The best SSIM epoch:  194
# Testing sample:  19
# The best SSIM through training process: 0.9335387349128723
# The best SSIM epoch:  201
# Testing sample:  20
# The best SSIM through training process: 0.9468699097633362
# The best SSIM epoch:  245
# Testing sample:  21
# The best SSIM through training process: 0.9408832788467407
# The best SSIM epoch:  232
# Testing sample:  22
# The best SSIM through training process: 0.9487882256507874
# The best SSIM epoch:  191
# Testing sample:  23
# The best SSIM through training process: 0.9388929009437561
# The best SSIM epoch:  312
# Testing sample:  24
# The best SSIM through training process: 0.9524516463279724
# The best SSIM epoch:  282
# Testing sample:  25
# The best SSIM through training process: 0.9446066617965698
# The best SSIM epoch:  192
# Testing sample:  26
# The best SSIM through training process: 0.9366018772125244
# The best SSIM epoch:  187
# Testing sample:  27
# The best SSIM through training process: 0.9341511726379395
# The best SSIM epoch:  246
# Testing sample:  28
# The best SSIM through training process: 0.9381628036499023
# The best SSIM epoch:  260
# Testing sample:  29
# The best SSIM through training process: 0.9479263424873352
# The best SSIM epoch:  240
# Testing sample:  30
# The best SSIM through training process: 0.919180154800415
# The best SSIM epoch:  172
# Testing sample:  31
# The best SSIM through training process: 0.9259578585624695
# The best SSIM epoch:  216
# Testing sample:  32
# The best SSIM through training process: 0.9406737089157104
# The best SSIM epoch:  207
# Testing sample:  33
# The best SSIM through training process: 0.9438709616661072
# The best SSIM epoch:  295
# Testing sample:  34
# The best SSIM through training process: 0.9304529428482056
# The best SSIM epoch:  419
# Testing sample:  35
# The best SSIM through training process: 0.9469826817512512
# The best SSIM epoch:  222
# Testing sample:  36
# The best SSIM through training process: 0.9443380236625671
# The best SSIM epoch:  177
# Testing sample:  37
# The best SSIM through training process: 0.9447346925735474
# The best SSIM epoch:  161
# Testing sample:  38
# The best SSIM through training process: 0.9345173835754395
# The best SSIM epoch:  272
# Testing sample:  39
# The best SSIM through training process: 0.9552001357078552
# The best SSIM epoch:  407
# Testing sample:  40
# The best SSIM through training process: 0.947097659111023
# The best SSIM epoch:  293
# Testing sample:  41
# The best SSIM through training process: 0.9404497742652893
# The best SSIM epoch:  243
# Testing sample:  42
# The best SSIM through training process: 0.9389296174049377
# The best SSIM epoch:  215
# Testing sample:  43
# The best SSIM through training process: 0.93535977602005
# The best SSIM epoch:  142
# Testing sample:  44
# The best SSIM through training process: 0.94793701171875
# The best SSIM epoch:  231
# Testing sample:  45
# The best SSIM through training process: 0.9268063902854919
# The best SSIM epoch:  140
# Testing sample:  46
# The best SSIM through training process: 0.92119300365448
# The best SSIM epoch:  150
# Testing sample:  47
# The best SSIM through training process: 0.9350424408912659
# The best SSIM epoch:  406
# Testing sample:  48
# The best SSIM through training process: 0.9265071749687195
# The best SSIM epoch:  121
# Testing sample:  49
# The best SSIM through training process: 0.8937820792198181
# The best SSIM epoch:  161
# Testing sample:  50
# The best SSIM through training process: 0.936843991279602
# The best SSIM epoch:  131
# Testing sample:  51
# The best SSIM through training process: 0.9232192039489746
# The best SSIM epoch:  201
# Testing sample:  52
# The best SSIM through training process: 0.9329482316970825
# The best SSIM epoch:  280
# Testing sample:  53
# The best SSIM through training process: 0.9426237344741821
# The best SSIM epoch:  309
# Testing sample:  54
# The best SSIM through training process: 0.9659774899482727
# The best SSIM epoch:  249
# Testing sample:  55
# The best SSIM through training process: 0.9486510753631592
# The best SSIM epoch:  219
# Testing sample:  56
# The best SSIM through training process: 0.9437769651412964
# The best SSIM epoch:  274
# Testing sample:  57
# The best SSIM through training process: 0.958277702331543
# The best SSIM epoch:  247
# Testing sample:  58
# The best SSIM through training process: 0.9324160218238831
# The best SSIM epoch:  272
# Testing sample:  59
# The best SSIM through training process: 0.9518185257911682
# The best SSIM epoch:  285
# Testing sample:  60
# The best SSIM through training process: 0.9271234273910522
# The best SSIM epoch:  195
# Testing sample:  61
# The best SSIM through training process: 0.9504238963127136
# The best SSIM epoch:  242
# Testing sample:  62
# The best SSIM through training process: 0.934052586555481
# The best SSIM epoch:  263
# Testing sample:  63
# The best SSIM through training process: 0.9283677935600281
# The best SSIM epoch:  136
# Testing sample:  64
# The best SSIM through training process: 0.9502379298210144
# The best SSIM epoch:  241
# Testing sample:  65
# The best SSIM through training process: 0.9490500092506409
# The best SSIM epoch:  275
# Testing sample:  66
# The best SSIM through training process: 0.9522430300712585
# The best SSIM epoch:  327
# Testing sample:  67
# The best SSIM through training process: 0.9303982257843018
# The best SSIM epoch:  141
# Testing sample:  68
# The best SSIM through training process: 0.9379568696022034
# The best SSIM epoch:  265
# Testing sample:  69
# The best SSIM through training process: 0.944955050945282
# The best SSIM epoch:  218
# Testing sample:  70
# The best SSIM through training process: 0.9434807896614075
# The best SSIM epoch:  260
# Testing sample:  71
# The best SSIM through training process: 0.9333000779151917
# The best SSIM epoch:  162
# Testing sample:  72
# The best SSIM through training process: 0.9450939297676086
# The best SSIM epoch:  230
# Testing sample:  73
# The best SSIM through training process: 0.9211008548736572
# The best SSIM epoch:  345
# Testing sample:  74
# The best SSIM through training process: 0.9232854843139648
# The best SSIM epoch:  176
# Testing sample:  75
# The best SSIM through training process: 0.9377357959747314
# The best SSIM epoch:  199
# Testing sample:  76
# The best SSIM through training process: 0.9324283003807068
# The best SSIM epoch:  321
# Testing sample:  77
# The best SSIM through training process: 0.9476030468940735
# The best SSIM epoch:  157
# Testing sample:  78
# The best SSIM through training process: 0.9609869122505188
# The best SSIM epoch:  264
# Testing sample:  79
# The best SSIM through training process: 0.9459155201911926
# The best SSIM epoch:  232
# Testing sample:  80
# The best SSIM through training process: 0.9127858281135559
# The best SSIM epoch:  411
# Testing sample:  81
# The best SSIM through training process: 0.9347530603408813
# The best SSIM epoch:  243
# Testing sample:  82
# The best SSIM through training process: 0.9365652799606323
# The best SSIM epoch:  268
# Testing sample:  83
# The best SSIM through training process: 0.9433004856109619
# The best SSIM epoch:  179
# Testing sample:  84
# The best SSIM through training process: 0.9496036767959595
# The best SSIM epoch:  219
# Testing sample:  85
# The best SSIM through training process: 0.9531829953193665
# The best SSIM epoch:  242
# Testing sample:  86
# The best SSIM through training process: 0.9100685715675354
# The best SSIM epoch:  183
# Testing sample:  87
# The best SSIM through training process: 0.9271213412284851
# The best SSIM epoch:  236
# Testing sample:  88
# The best SSIM through training process: 0.938698947429657
# The best SSIM epoch:  191
# Testing sample:  89
# The best SSIM through training process: 0.9484589099884033
# The best SSIM epoch:  214
# Testing sample:  90
# The best SSIM through training process: 0.9436699748039246
# The best SSIM epoch:  175
# Testing sample:  91
# The best SSIM through training process: 0.9274119138717651
# The best SSIM epoch:  310
# Testing sample:  92
# The best SSIM through training process: 0.9416261911392212
# The best SSIM epoch:  216
# Testing sample:  93
# The best SSIM through training process: 0.9202213287353516
# The best SSIM epoch:  207
# Testing sample:  94
# The best SSIM through training process: 0.9373387694358826
# The best SSIM epoch:  164
# Testing sample:  95
# The best SSIM through training process: 0.9262664914131165
# The best SSIM epoch:  256
# Testing sample:  96
# The best SSIM through training process: 0.9463353753089905
# The best SSIM epoch:  218
# Testing sample:  97
# The best SSIM through training process: 0.931395411491394
# The best SSIM epoch:  393
# Testing sample:  98
# The best SSIM through training process: 0.9275492429733276
# The best SSIM epoch:  186
# Testing sample:  99
# The best SSIM through training process: 0.9522196054458618
# The best SSIM epoch:  374
# Testing sample:  100
# The best SSIM through training process: 0.9378357529640198
# The best SSIM epoch:  155
# Testing average SSIM loss:  0.9380247515439987
# Testing average SSIM loss epoch:  238.66

# %% [markdown]
# without TTT

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    model_output = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    model_output = torch.moveaxis(model_output, 1, -1 )
    output_sens_image = complex_mul(model_output, sens_maps)
    # FS fθ(A†y)
    Fimg = fft2c(output_sens_image)
    # M(3/4)   FS fθ(A†y) = A fθ(A†y)
    Fimg_forward = Fimg * flipped_mask
    # M(3/4) + M(1/4)
    improved_kspace_output = Fimg_forward + scale_input_kspace

    improved_output_image_1c = complex_abs(complex_mul(ifft2c(improved_kspace_output), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)

    # center crop for SSIM
    crop_output_image = center_crop( improved_output_image_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 0it [00:00, ?it/s]
# 100it [00:38,  2.57it/s]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.8601677006483078
