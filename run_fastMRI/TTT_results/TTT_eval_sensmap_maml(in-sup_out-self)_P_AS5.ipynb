# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_TTTmaml_in-sup_out-self(l1_out-5_in-3_AS-5)P_T300_300epoch/E_TTTmaml_in-sup_out-self(l1_out-5_in-3_AS-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %% [markdown]
# Sensmap

# %%
background_flip = True
eval_with_binary_mask = False
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 1500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9458889365196228
# The best SSIM epoch:  1056
# Testing sample:  2
# The best SSIM through training process: 0.9140146374702454
# The best SSIM epoch:  558
# Testing sample:  3
# The best SSIM through training process: 0.9404339790344238
# The best SSIM epoch:  698
# Testing sample:  4
# The best SSIM through training process: 0.9422064423561096
# The best SSIM epoch:  1315
# Testing sample:  5
# The best SSIM through training process: 0.9425087571144104
# The best SSIM epoch:  940
# Testing sample:  6
# The best SSIM through training process: 0.9383878111839294
# The best SSIM epoch:  834
# Testing sample:  7
# The best SSIM through training process: 0.935981273651123
# The best SSIM epoch:  787
# Testing sample:  8
# The best SSIM through training process: 0.923556387424469
# The best SSIM epoch:  424
# Testing sample:  9
# The best SSIM through training process: 0.9415054321289062
# The best SSIM epoch:  1027
# Testing sample:  10
# The best SSIM through training process: 0.9374213218688965
# The best SSIM epoch:  573
# Testing sample:  11
# The best SSIM through training process: 0.9373766779899597
# The best SSIM epoch:  1223
# Testing sample:  12
# The best SSIM through training process: 0.9382910132408142
# The best SSIM epoch:  1289
# Testing sample:  13
# The best SSIM through training process: 0.9488891959190369
# The best SSIM epoch:  969
# Testing sample:  14
# The best SSIM through training process: 0.9543671011924744
# The best SSIM epoch:  1436
# Testing sample:  15
# The best SSIM through training process: 0.9354485273361206
# The best SSIM epoch:  664
# Testing sample:  16
# The best SSIM through training process: 0.945128858089447
# The best SSIM epoch:  1469
# Testing sample:  17
# The best SSIM through training process: 0.9494488835334778
# The best SSIM epoch:  534
# Testing sample:  18
# The best SSIM through training process: 0.9348862767219543
# The best SSIM epoch:  616
# Testing sample:  19
# The best SSIM through training process: 0.9436119794845581
# The best SSIM epoch:  1202
# Testing sample:  20
# The best SSIM through training process: 0.956261932849884
# The best SSIM epoch:  1385
# Testing sample:  21
# The best SSIM through training process: 0.9519639015197754
# The best SSIM epoch:  1239
# Testing sample:  22
# The best SSIM through training process: 0.9443541765213013
# The best SSIM epoch:  492
# Testing sample:  23
# The best SSIM through training process: 0.9498924612998962
# The best SSIM epoch:  1066
# Testing sample:  24
# The best SSIM through training process: 0.9434800744056702
# The best SSIM epoch:  1116
# Testing sample:  25
# The best SSIM through training process: 0.9427757263183594
# The best SSIM epoch:  796
# Testing sample:  26
# The best SSIM through training process: 0.9452698826789856
# The best SSIM epoch:  951
# Testing sample:  27
# The best SSIM through training process: 0.932881772518158
# The best SSIM epoch:  1219
# Testing sample:  28
# The best SSIM through training process: 0.9313616156578064
# The best SSIM epoch:  852
# Testing sample:  29
# The best SSIM through training process: 0.9462811350822449
# The best SSIM epoch:  1115
# Testing sample:  30
# The best SSIM through training process: 0.9281209111213684
# The best SSIM epoch:  550
# Testing sample:  31
# The best SSIM through training process: 0.9233729243278503
# The best SSIM epoch:  895
# Testing sample:  32
# The best SSIM through training process: 0.9366437792778015
# The best SSIM epoch:  722
# Testing sample:  33
# The best SSIM through training process: 0.939318835735321
# The best SSIM epoch:  1192
# Testing sample:  34
# The best SSIM through training process: 0.9447277188301086
# The best SSIM epoch:  983
# Testing sample:  35
# The best SSIM through training process: 0.9437962770462036
# The best SSIM epoch:  743
# Testing sample:  36
# The best SSIM through training process: 0.9410695433616638
# The best SSIM epoch:  513
# Testing sample:  37
# The best SSIM through training process: 0.9424622058868408
# The best SSIM epoch:  460
# Testing sample:  38
# The best SSIM through training process: 0.9333525896072388
# The best SSIM epoch:  903
# Testing sample:  39
# The best SSIM through training process: 0.9555287957191467
# The best SSIM epoch:  1103
# Testing sample:  40
# The best SSIM through training process: 0.9444019198417664
# The best SSIM epoch:  1316
# Testing sample:  41
# The best SSIM through training process: 0.9345751404762268
# The best SSIM epoch:  1113
# Testing sample:  42
# The best SSIM through training process: 0.9413296580314636
# The best SSIM epoch:  855
# Testing sample:  43
# The best SSIM through training process: 0.9390747547149658
# The best SSIM epoch:  511
# Testing sample:  44
# The best SSIM through training process: 0.9441125392913818
# The best SSIM epoch:  744
# Testing sample:  45
# The best SSIM through training process: 0.94745934009552
# The best SSIM epoch:  1193
# Testing sample:  46
# The best SSIM through training process: 0.927651047706604
# The best SSIM epoch:  360
# Testing sample:  47
# The best SSIM through training process: 0.9531621932983398
# The best SSIM epoch:  1480
# Testing sample:  48
# The best SSIM through training process: 0.9326205253601074
# The best SSIM epoch:  559
# Testing sample:  49
# The best SSIM through training process: 0.8948996663093567
# The best SSIM epoch:  141
# Testing sample:  50
# The best SSIM through training process: 0.9385614395141602
# The best SSIM epoch:  564
# Testing sample:  51
# The best SSIM through training process: 0.9376533031463623
# The best SSIM epoch:  1413
# Testing sample:  52
# The best SSIM through training process: 0.940321147441864
# The best SSIM epoch:  708
# Testing sample:  53
# The best SSIM through training process: 0.9431235790252686
# The best SSIM epoch:  1241
# Testing sample:  54
# The best SSIM through training process: 0.9591952562332153
# The best SSIM epoch:  1465
# Testing sample:  55
# The best SSIM through training process: 0.9479250907897949
# The best SSIM epoch:  756
# Testing sample:  56
# The best SSIM through training process: 0.9454131722450256
# The best SSIM epoch:  979
# Testing sample:  57
# The best SSIM through training process: 0.9526974558830261
# The best SSIM epoch:  979
# Testing sample:  58
# The best SSIM through training process: 0.9397666454315186
# The best SSIM epoch:  638
# Testing sample:  59
# The best SSIM through training process: 0.9532617330551147
# The best SSIM epoch:  1365
# Testing sample:  60
# The best SSIM through training process: 0.9296976923942566
# The best SSIM epoch:  568
# Testing sample:  61
# The best SSIM through training process: 0.9416818022727966
# The best SSIM epoch:  1229
# Testing sample:  62
# The best SSIM through training process: 0.9262071847915649
# The best SSIM epoch:  1163
# Testing sample:  63
# The best SSIM through training process: 0.9351774454116821
# The best SSIM epoch:  552
# Testing sample:  64
# The best SSIM through training process: 0.9440946578979492
# The best SSIM epoch:  1446
# Testing sample:  65
# The best SSIM through training process: 0.9466593861579895
# The best SSIM epoch:  700
# Testing sample:  66
# The best SSIM through training process: 0.9586259126663208
# The best SSIM epoch:  1288
# Testing sample:  67
# The best SSIM through training process: 0.9385618567466736
# The best SSIM epoch:  698
# Testing sample:  68
# The best SSIM through training process: 0.9412535429000854
# The best SSIM epoch:  1071
# Testing sample:  69
# The best SSIM through training process: 0.9333733320236206
# The best SSIM epoch:  1489
# Testing sample:  70
# The best SSIM through training process: 0.9376280307769775
# The best SSIM epoch:  1178
# Testing sample:  71
# The best SSIM through training process: 0.925826370716095
# The best SSIM epoch:  427
# Testing sample:  72
# The best SSIM through training process: 0.9442571997642517
# The best SSIM epoch:  1070
# Testing sample:  73
# The best SSIM through training process: 0.9318077564239502
# The best SSIM epoch:  620
# Testing sample:  74
# The best SSIM through training process: 0.9316920638084412
# The best SSIM epoch:  987
# Testing sample:  75
# The best SSIM through training process: 0.9385194182395935
# The best SSIM epoch:  552
# Testing sample:  76
# The best SSIM through training process: 0.9365329146385193
# The best SSIM epoch:  1202
# Testing sample:  77
# The best SSIM through training process: 0.9509091973304749
# The best SSIM epoch:  825
# Testing sample:  78
# The best SSIM through training process: 0.958277702331543
# The best SSIM epoch:  1408
# Testing sample:  79
# The best SSIM through training process: 0.9407175779342651
# The best SSIM epoch:  666
# Testing sample:  80
# The best SSIM through training process: 0.9279674291610718
# The best SSIM epoch:  1159
# Testing sample:  81
# The best SSIM through training process: 0.9423114061355591
# The best SSIM epoch:  1332
# Testing sample:  82
# The best SSIM through training process: 0.934922993183136
# The best SSIM epoch:  1225
# Testing sample:  83
# The best SSIM through training process: 0.9456775188446045
# The best SSIM epoch:  1048
# Testing sample:  84
# The best SSIM through training process: 0.9449539184570312
# The best SSIM epoch:  527
# Testing sample:  85
# The best SSIM through training process: 0.9480728507041931
# The best SSIM epoch:  570
# Testing sample:  86
# The best SSIM through training process: 0.9034631252288818
# The best SSIM epoch:  155
# Testing sample:  87
# The best SSIM through training process: 0.926871120929718
# The best SSIM epoch:  584
# Testing sample:  88
# The best SSIM through training process: 0.9380402565002441
# The best SSIM epoch:  754
# Testing sample:  89
# The best SSIM through training process: 0.9460691213607788
# The best SSIM epoch:  877
# Testing sample:  90
# The best SSIM through training process: 0.9523624777793884
# The best SSIM epoch:  1301
# Testing sample:  91
# The best SSIM through training process: 0.930809497833252
# The best SSIM epoch:  1079
# Testing sample:  92
# The best SSIM through training process: 0.9366114139556885
# The best SSIM epoch:  1064
# Testing sample:  93
# The best SSIM through training process: 0.9162139892578125
# The best SSIM epoch:  539
# Testing sample:  94
# The best SSIM through training process: 0.9350492358207703
# The best SSIM epoch:  610
# Testing sample:  95
# The best SSIM through training process: 0.9246699810028076
# The best SSIM epoch:  915
# Testing sample:  96
# The best SSIM through training process: 0.9445605278015137
# The best SSIM epoch:  1096
# Testing sample:  97
# The best SSIM through training process: 0.9393290281295776
# The best SSIM epoch:  916
# Testing sample:  98
# The best SSIM through training process: 0.9405221939086914
# The best SSIM epoch:  1189
# Testing sample:  99
# The best SSIM through training process: 0.9561684727668762
# The best SSIM epoch:  1444
# Testing sample:  100
# The best SSIM through training process: 0.94285649061203
# The best SSIM epoch:  779
# Testing average SSIM loss:  0.9396847945451736
# Testing average SSIM loss epoch:  925.91

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 100it [02:42,  1.62s/it]

# %%
#print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.8112502801418304
