# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E14.1_maml_joint(l1_out-5_in-5)P_T300_300epoch/E14.1_maml_joint(l1_out-5_in-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.93864506483078
# The best SSIM epoch:  163
# Testing sample:  2
# The best SSIM through training process: 0.910972535610199
# The best SSIM epoch:  195
# Testing sample:  3
# The best SSIM through training process: 0.9275651574134827
# The best SSIM epoch:  152
# Testing sample:  4
# The best SSIM through training process: 0.9242576956748962
# The best SSIM epoch:  206
# Testing sample:  5
# The best SSIM through training process: 0.9393587708473206
# The best SSIM epoch:  183
# Testing sample:  6
# The best SSIM through training process: 0.9275673031806946
# The best SSIM epoch:  176
# Testing sample:  7
# The best SSIM through training process: 0.9298676252365112
# The best SSIM epoch:  279
# Testing sample:  8
# The best SSIM through training process: 0.9224290251731873
# The best SSIM epoch:  131
# Testing sample:  9
# The best SSIM through training process: 0.9309994578361511
# The best SSIM epoch:  145
# Testing sample:  10
# The best SSIM through training process: 0.9321874976158142
# The best SSIM epoch:  128
# Testing sample:  11
# The best SSIM through training process: 0.922603189945221
# The best SSIM epoch:  185
# Testing sample:  12
# The best SSIM through training process: 0.9233270883560181
# The best SSIM epoch:  241
# Testing sample:  13
# The best SSIM through training process: 0.9424310922622681
# The best SSIM epoch:  284
# Testing sample:  14
# The best SSIM through training process: 0.9444643259048462
# The best SSIM epoch:  319
# Testing sample:  15
# The best SSIM through training process: 0.9329279065132141
# The best SSIM epoch:  126
# Testing sample:  16
# The best SSIM through training process: 0.9345983862876892
# The best SSIM epoch:  381
# Testing sample:  17
# The best SSIM through training process: 0.9430763125419617
# The best SSIM epoch:  160
# Testing sample:  18
# The best SSIM through training process: 0.9322070479393005
# The best SSIM epoch:  103
# Testing sample:  19
# The best SSIM through training process: 0.94072425365448
# The best SSIM epoch:  214
# Testing sample:  20
# The best SSIM through training process: 0.9492173194885254
# The best SSIM epoch:  337
# Testing sample:  21
# The best SSIM through training process: 0.9439445734024048
# The best SSIM epoch:  255
# Testing sample:  22
# The best SSIM through training process: 0.9379929304122925
# The best SSIM epoch:  100
# Testing sample:  23
# The best SSIM through training process: 0.9437246322631836
# The best SSIM epoch:  256
# Testing sample:  24
# The best SSIM through training process: 0.9293864369392395
# The best SSIM epoch:  238
# Testing sample:  25
# The best SSIM through training process: 0.9348731637001038
# The best SSIM epoch:  118
# Testing sample:  26
# The best SSIM through training process: 0.9362536072731018
# The best SSIM epoch:  162
# Testing sample:  27
# The best SSIM through training process: 0.9129839539527893
# The best SSIM epoch:  170
# Testing sample:  28
# The best SSIM through training process: 0.9233012199401855
# The best SSIM epoch:  179
# Testing sample:  29
# The best SSIM through training process: 0.9358481764793396
# The best SSIM epoch:  220
# Testing sample:  30
# The best SSIM through training process: 0.9252753257751465
# The best SSIM epoch:  162
# Testing sample:  31
# The best SSIM through training process: 0.9111211895942688
# The best SSIM epoch:  157
# Testing sample:  32
# The best SSIM through training process: 0.9322496652603149
# The best SSIM epoch:  135
# Testing sample:  33
# The best SSIM through training process: 0.9293938279151917
# The best SSIM epoch:  338
# Testing sample:  34
# The best SSIM through training process: 0.9387964606285095
# The best SSIM epoch:  221
# Testing sample:  35
# The best SSIM through training process: 0.9436182379722595
# The best SSIM epoch:  157
# Testing sample:  36
# The best SSIM through training process: 0.9325553774833679
# The best SSIM epoch:  116
# Testing sample:  37
# The best SSIM through training process: 0.9387072920799255
# The best SSIM epoch:  118
# Testing sample:  38
# The best SSIM through training process: 0.9254633188247681
# The best SSIM epoch:  169
# Testing sample:  39
# The best SSIM through training process: 0.9458515644073486
# The best SSIM epoch:  324
# Testing sample:  40
# The best SSIM through training process: 0.9301032423973083
# The best SSIM epoch:  289
# Testing sample:  41
# The best SSIM through training process: 0.9220057725906372
# The best SSIM epoch:  166
# Testing sample:  42
# The best SSIM through training process: 0.9365457892417908
# The best SSIM epoch:  161
# Testing sample:  43
# The best SSIM through training process: 0.9344645142555237
# The best SSIM epoch:  124
# Testing sample:  44
# The best SSIM through training process: 0.9330124258995056
# The best SSIM epoch:  143
# Testing sample:  45
# The best SSIM through training process: 0.9399640560150146
# The best SSIM epoch:  304
# Testing sample:  46
# The best SSIM through training process: 0.9269118309020996
# The best SSIM epoch:  143
# Testing sample:  47
# The best SSIM through training process: 0.9456495642662048
# The best SSIM epoch:  394
# Testing sample:  48
# The best SSIM through training process: 0.9301146864891052
# The best SSIM epoch:  131
# Testing sample:  49
# The best SSIM through training process: 0.8925536274909973
# The best SSIM epoch:  75
# Testing sample:  50
# The best SSIM through training process: 0.9350915551185608
# The best SSIM epoch:  139
# Testing sample:  51
# The best SSIM through training process: 0.9239539504051208
# The best SSIM epoch:  338
# Testing sample:  52
# The best SSIM through training process: 0.9359143376350403
# The best SSIM epoch:  216
# Testing sample:  53
# The best SSIM through training process: 0.9285630583763123
# The best SSIM epoch:  248
# Testing sample:  54
# The best SSIM through training process: 0.9513725638389587
# The best SSIM epoch:  249
# Testing sample:  55
# The best SSIM through training process: 0.9378512501716614
# The best SSIM epoch:  165
# Testing sample:  56
# The best SSIM through training process: 0.9392738342285156
# The best SSIM epoch:  238
# Testing sample:  57
# The best SSIM through training process: 0.9390296339988708
# The best SSIM epoch:  168
# Testing sample:  58
# The best SSIM through training process: 0.9364852905273438
# The best SSIM epoch:  212
# Testing sample:  59
# The best SSIM through training process: 0.9480547904968262
# The best SSIM epoch:  201
# Testing sample:  60
# The best SSIM through training process: 0.9220459461212158
# The best SSIM epoch:  123
# Testing sample:  61
# The best SSIM through training process: 0.9268008470535278
# The best SSIM epoch:  175
# Testing sample:  62
# The best SSIM through training process: 0.9170196652412415
# The best SSIM epoch:  166
# Testing sample:  63
# The best SSIM through training process: 0.9305416941642761
# The best SSIM epoch:  169
# Testing sample:  64
# The best SSIM through training process: 0.9332302212715149
# The best SSIM epoch:  285
# Testing sample:  65
# The best SSIM through training process: 0.9383325576782227
# The best SSIM epoch:  127
# Testing sample:  66
# The best SSIM through training process: 0.9482753276824951
# The best SSIM epoch:  203
# Testing sample:  67
# The best SSIM through training process: 0.9354727864265442
# The best SSIM epoch:  129
# Testing sample:  68
# The best SSIM through training process: 0.9386329054832458
# The best SSIM epoch:  140
# Testing sample:  69
# The best SSIM through training process: 0.9236119389533997
# The best SSIM epoch:  220
# Testing sample:  70
# The best SSIM through training process: 0.9226728081703186
# The best SSIM epoch:  183
# Testing sample:  71
# The best SSIM through training process: 0.9221915602684021
# The best SSIM epoch:  96
# Testing sample:  72
# The best SSIM through training process: 0.9351302981376648
# The best SSIM epoch:  131
# Testing sample:  73
# The best SSIM through training process: 0.9297519326210022
# The best SSIM epoch:  226
# Testing sample:  74
# The best SSIM through training process: 0.9207150936126709
# The best SSIM epoch:  149
# Testing sample:  75
# The best SSIM through training process: 0.9322586059570312
# The best SSIM epoch:  130
# Testing sample:  76
# The best SSIM through training process: 0.9278801083564758
# The best SSIM epoch:  253
# Testing sample:  77
# The best SSIM through training process: 0.9468926787376404
# The best SSIM epoch:  165
# Testing sample:  78
# The best SSIM through training process: 0.9545170068740845
# The best SSIM epoch:  225
# Testing sample:  79
# The best SSIM through training process: 0.9335566163063049
# The best SSIM epoch:  149
# Testing sample:  80
# The best SSIM through training process: 0.9200184941291809
# The best SSIM epoch:  297
# Testing sample:  81
# The best SSIM through training process: 0.9316547513008118
# The best SSIM epoch:  310
# Testing sample:  82
# The best SSIM through training process: 0.9251304864883423
# The best SSIM epoch:  184
# Testing sample:  83
# The best SSIM through training process: 0.9370207190513611
# The best SSIM epoch:  208
# Testing sample:  84
# The best SSIM through training process: 0.9385198950767517
# The best SSIM epoch:  131
# Testing sample:  85
# The best SSIM through training process: 0.9425997734069824
# The best SSIM epoch:  148
# Testing sample:  86
# The best SSIM through training process: 0.9022072553634644
# The best SSIM epoch:  117
# Testing sample:  87
# The best SSIM through training process: 0.9222861528396606
# The best SSIM epoch:  157
# Testing sample:  88
# The best SSIM through training process: 0.9298510551452637
# The best SSIM epoch:  138
# Testing sample:  89
# The best SSIM through training process: 0.9356018900871277
# The best SSIM epoch:  166
# Testing sample:  90
# The best SSIM through training process: 0.9448220729827881
# The best SSIM epoch:  239
# Testing sample:  91
# The best SSIM through training process: 0.9177612662315369
# The best SSIM epoch:  176
# Testing sample:  92
# The best SSIM through training process: 0.9235609173774719
# The best SSIM epoch:  212
# Testing sample:  93
# The best SSIM through training process: 0.9097193479537964
# The best SSIM epoch:  124
# Testing sample:  94
# The best SSIM through training process: 0.9326974749565125
# The best SSIM epoch:  101
# Testing sample:  95
# The best SSIM through training process: 0.916532039642334
# The best SSIM epoch:  145
# Testing sample:  96
# The best SSIM through training process: 0.9395348429679871
# The best SSIM epoch:  159
# Testing sample:  97
# The best SSIM through training process: 0.9323669672012329
# The best SSIM epoch:  284
# Testing sample:  98
# The best SSIM through training process: 0.9312739372253418
# The best SSIM epoch:  211
# Testing sample:  99
# The best SSIM through training process: 0.9423127770423889
# The best SSIM epoch:  308
# Testing sample:  100
# The best SSIM through training process: 0.9371365904808044
# The best SSIM epoch:  164
# Testing average SSIM loss:  0.9318982309103012
# Testing average SSIM loss epoch:  192.3

# %% [markdown]
# visualization

# %%
iterator = iter(test_dataloader)

# %%
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 180
batch = next(iterator)
origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
fname
# Out:
# ('file_brain_AXT2_209_6001308',)

# %%
origk = origk.squeeze(0).to(device)
sens_maps = sens_maps.squeeze(0).to(device)
sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
binary_background_mask = binary_background_mask.to(device)

# input k space
input_kspace = origk * mask + 0.0
# scale factor
scale_factor = scale_sensmap(input_kspace, model)
scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

# gt image by normalized kspace: x
target_image_1c = complex_abs(complex_mul(ifft2c(origk * scale_factor), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
# sensmap combine
# target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
crop_target_image = center_crop( target_image_1c, crop_size )
std_crop_target_image = crop_target_image.std()
mean_crop_target_image = crop_target_image.mean()

# A†y
# train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
train_inputs = torch.moveaxis( train_inputs , -1, 0 )

loss_l1_history = []
loss_ssim_history = []
self_loss_history = []
model_ttt = copy.deepcopy(model)
optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

best_loss_ssim = 0.0
for iteration in range(TTT_epoch): 
    ###### training ######
    # fθ(A†y)
    model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
    model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
    # S fθ(A†y) [coils, height, width, channel]
    if background_flip == True: 
        output_sens_image = torch.zeros(sens_maps.shape).to(device) 
        for j,s in enumerate(sens_maps):
            ss = s.clone()
            ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
            output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
            output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

    else: 
        output_sens_image = complex_mul(model_output, sens_maps)
    # FS fθ(A†y)
    Fimg = fft2c(output_sens_image)
    # MFS fθ(A†y) = A fθ(A†y)
    Fimg_forward = Fimg * mask
    # consistency loss [y, Afθ(A†y)]
    loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

    optimizer.zero_grad()
    loss_self.backward()
    optimizer.step()
    #train_loss += loss.item()
    #print('TTT loss: ',loss_self.item())
    self_loss_history.append(loss_self.item())

    ###### evaluation ######
    output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
    if eval_with_binary_mask == True: 
        binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
        # center crop for SSIM
        crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
    else: 
        # center crop for SSIM
        crop_output_image = center_crop( output_image_1c, crop_size )
    # normalization
    crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
    crop_output_image *= std_crop_target_image
    crop_output_image += mean_crop_target_image
    # SSIM = 1 - loss
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    if best_loss_ssim < loss_ssim: 
        best_loss_ssim = loss_ssim
        best_crop_output_image = crop_output_image
    print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
    print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

    #loss_l1_history.append(loss_l1)
    loss_ssim_history.append(loss_ssim)


best_loss_ssim = max(loss_ssim_history)
print('The best SSIM through training process:', best_loss_ssim)
best_loss_ssim_epoch = np.argmax(loss_ssim_history)
print('The best SSIM epoch: ', best_loss_ssim_epoch)
# Out:
# The best SSIM through training process: 0.930763304233551
# The best SSIM epoch:  143

# %%
best_loss_ssim
# Out:
# 0.930763304233551

# %%
plt.figure(dpi=400)
plt.imshow(best_crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.figure(dpi=400)
plt.imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
plt.axis('off')
plt.show()
