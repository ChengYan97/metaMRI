# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttpaper_sensmap_balance_joint(l1_1e-5)Q_T300_300epoch/E_tttpaper_sensmap_balance_joint(l1_1e-5)Q_T300_300epoch_E300.pth'
model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj )
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.95212322473526
# The best SSIM epoch:  456
# Testing sample:  2
# The best SSIM through training process: 0.9129394888877869
# The best SSIM epoch:  298
# Testing sample:  3
# The best SSIM through training process: 0.9487565755844116
# The best SSIM epoch:  209
# Testing sample:  4
# The best SSIM through training process: 0.9495052099227905
# The best SSIM epoch:  412
# Testing sample:  5
# The best SSIM through training process: 0.9410394430160522
# The best SSIM epoch:  309
# Testing sample:  6
# The best SSIM through training process: 0.9411262273788452
# The best SSIM epoch:  420
# Testing sample:  7
# The best SSIM through training process: 0.9363251328468323
# The best SSIM epoch:  297
# Testing sample:  8
# The best SSIM through training process: 0.9231253266334534
# The best SSIM epoch:  3
# Testing sample:  9
# The best SSIM through training process: 0.9437260031700134
# The best SSIM epoch:  302
# Testing sample:  10
# The best SSIM through training process: 0.9449577927589417
# The best SSIM epoch:  189
# Testing sample:  11
# The best SSIM through training process: 0.9430506229400635
# The best SSIM epoch:  319
# Testing sample:  12
# The best SSIM through training process: 0.9463242888450623
# The best SSIM epoch:  338
# Testing sample:  13
# The best SSIM through training process: 0.9509412050247192
# The best SSIM epoch:  30
# Testing sample:  14
# The best SSIM through training process: 0.9504092931747437
# The best SSIM epoch:  163
# Testing sample:  15
# The best SSIM through training process: 0.9369345307350159
# The best SSIM epoch:  299
# Testing sample:  16
# The best SSIM through training process: 0.9488868713378906
# The best SSIM epoch:  185
# Testing sample:  17
# The best SSIM through training process: 0.9411025047302246
# The best SSIM epoch:  216
# Testing sample:  18
# The best SSIM through training process: 0.9376255869865417
# The best SSIM epoch:  167
# Testing sample:  19
# The best SSIM through training process: 0.9444199204444885
# The best SSIM epoch:  361
# Testing sample:  20
# The best SSIM through training process: 0.9647014737129211
# The best SSIM epoch:  341
# Testing sample:  21
# The best SSIM through training process: 0.9584844708442688
# The best SSIM epoch:  320
# Testing sample:  22
# The best SSIM through training process: 0.945701539516449
# The best SSIM epoch:  185
# Testing sample:  23
# The best SSIM through training process: 0.9493662714958191
# The best SSIM epoch:  331
# Testing sample:  24
# The best SSIM through training process: 0.9558128118515015
# The best SSIM epoch:  315
# Testing sample:  25
# The best SSIM through training process: 0.950824499130249
# The best SSIM epoch:  221
# Testing sample:  26
# The best SSIM through training process: 0.943308413028717
# The best SSIM epoch:  3
# Testing sample:  27
# The best SSIM through training process: 0.9420901536941528
# The best SSIM epoch:  214
# Testing sample:  28
# The best SSIM through training process: 0.9393817186355591
# The best SSIM epoch:  267
# Testing sample:  29
# The best SSIM through training process: 0.9538617730140686
# The best SSIM epoch:  306
# Testing sample:  30
# The best SSIM through training process: 0.9224027395248413
# The best SSIM epoch:  206
# Testing sample:  31
# The best SSIM through training process: 0.9319015145301819
# The best SSIM epoch:  197
# Testing sample:  32
# The best SSIM through training process: 0.935195803642273
# The best SSIM epoch:  329
# Testing sample:  33
# The best SSIM through training process: 0.9422682523727417
# The best SSIM epoch:  37
# Testing sample:  34
# The best SSIM through training process: 0.9396646022796631
# The best SSIM epoch:  308
# Testing sample:  35
# The best SSIM through training process: 0.9430396556854248
# The best SSIM epoch:  251
# Testing sample:  36
# The best SSIM through training process: 0.9499448537826538
# The best SSIM epoch:  142
# Testing sample:  37
# The best SSIM through training process: 0.9466789960861206
# The best SSIM epoch:  142
# Testing sample:  38
# The best SSIM through training process: 0.934688150882721
# The best SSIM epoch:  11
# Testing sample:  39
# The best SSIM through training process: 0.9560260772705078
# The best SSIM epoch:  472
# Testing sample:  40
# The best SSIM through training process: 0.9530224800109863
# The best SSIM epoch:  353
# Testing sample:  41
# The best SSIM through training process: 0.9387418031692505
# The best SSIM epoch:  301
# Testing sample:  42
# The best SSIM through training process: 0.9315099120140076
# The best SSIM epoch:  370
# Testing sample:  43
# The best SSIM through training process: 0.9372355937957764
# The best SSIM epoch:  2
# Testing sample:  44
# The best SSIM through training process: 0.9520415663719177
# The best SSIM epoch:  172
# Testing sample:  45
# The best SSIM through training process: 0.9537092447280884
# The best SSIM epoch:  361
# Testing sample:  46
# The best SSIM through training process: 0.9193134903907776
# The best SSIM epoch:  263
# Testing sample:  47
# The best SSIM through training process: 0.9568471908569336
# The best SSIM epoch:  229
# Testing sample:  48
# The best SSIM through training process: 0.9240031242370605
# The best SSIM epoch:  3
# Testing sample:  49
# The best SSIM through training process: 0.8793116211891174
# The best SSIM epoch:  325
# Testing sample:  50
# The best SSIM through training process: 0.9324278831481934
# The best SSIM epoch:  266
# Testing sample:  51
# The best SSIM through training process: 0.9409350752830505
# The best SSIM epoch:  156
# Testing sample:  52
# The best SSIM through training process: 0.933292806148529
# The best SSIM epoch:  368
# Testing sample:  53
# The best SSIM through training process: 0.9431785345077515
# The best SSIM epoch:  322
# Testing sample:  54
# The best SSIM through training process: 0.9702838659286499
# The best SSIM epoch:  339
# Testing sample:  55
# The best SSIM through training process: 0.9513502717018127
# The best SSIM epoch:  297
# Testing sample:  56
# The best SSIM through training process: 0.9430111050605774
# The best SSIM epoch:  380
# Testing sample:  57
# The best SSIM through training process: 0.9571659564971924
# The best SSIM epoch:  346
# Testing sample:  58
# The best SSIM through training process: 0.9383107423782349
# The best SSIM epoch:  306
# Testing sample:  59
# The best SSIM through training process: 0.9579727053642273
# The best SSIM epoch:  377
# Testing sample:  60
# The best SSIM through training process: 0.9274011254310608
# The best SSIM epoch:  178
# Testing sample:  61
# The best SSIM through training process: 0.9525662660598755
# The best SSIM epoch:  280
# Testing sample:  62
# The best SSIM through training process: 0.9350650310516357
# The best SSIM epoch:  274
# Testing sample:  63
# The best SSIM through training process: 0.9311106204986572
# The best SSIM epoch:  247
# Testing sample:  64
# The best SSIM through training process: 0.9545241594314575
# The best SSIM epoch:  408
# Testing sample:  65
# The best SSIM through training process: 0.9452102184295654
# The best SSIM epoch:  3
# Testing sample:  66
# The best SSIM through training process: 0.9600889086723328
# The best SSIM epoch:  485
# Testing sample:  67
# The best SSIM through training process: 0.9319115877151489
# The best SSIM epoch:  284
# Testing sample:  68
# The best SSIM through training process: 0.9432954788208008
# The best SSIM epoch:  266
# Testing sample:  69
# The best SSIM through training process: 0.9525824189186096
# The best SSIM epoch:  329
# Testing sample:  70
# The best SSIM through training process: 0.9461398124694824
# The best SSIM epoch:  339
# Testing sample:  71
# The best SSIM through training process: 0.935701847076416
# The best SSIM epoch:  127
# Testing sample:  72
# The best SSIM through training process: 0.9510177373886108
# The best SSIM epoch:  229
# Testing sample:  73
# The best SSIM through training process: 0.9302622675895691
# The best SSIM epoch:  297
# Testing sample:  74
# The best SSIM through training process: 0.9324133396148682
# The best SSIM epoch:  318
# Testing sample:  75
# The best SSIM through training process: 0.9342461824417114
# The best SSIM epoch:  3
# Testing sample:  76
# The best SSIM through training process: 0.9385342001914978
# The best SSIM epoch:  12
# Testing sample:  77
# The best SSIM through training process: 0.9463521242141724
# The best SSIM epoch:  352
# Testing sample:  78
# The best SSIM through training process: 0.9648570418357849
# The best SSIM epoch:  317
# Testing sample:  79
# The best SSIM through training process: 0.9459565281867981
# The best SSIM epoch:  4
# Testing sample:  80
# The best SSIM through training process: 0.9268978238105774
# The best SSIM epoch:  325
# Testing sample:  81
# The best SSIM through training process: 0.945210337638855
# The best SSIM epoch:  405
# Testing sample:  82
# The best SSIM through training process: 0.9391282796859741
# The best SSIM epoch:  313
# Testing sample:  83
# The best SSIM through training process: 0.9532358646392822
# The best SSIM epoch:  137
# Testing sample:  84
# The best SSIM through training process: 0.9501921534538269
# The best SSIM epoch:  3
# Testing sample:  85
# The best SSIM through training process: 0.9461564421653748
# The best SSIM epoch:  3
# Testing sample:  86
# The best SSIM through training process: 0.8833622336387634
# The best SSIM epoch:  213
# Testing sample:  87
# The best SSIM through training process: 0.9218197464942932
# The best SSIM epoch:  179
# Testing sample:  88
# The best SSIM through training process: 0.937506377696991
# The best SSIM epoch:  224
# Testing sample:  89
# The best SSIM through training process: 0.9574995040893555
# The best SSIM epoch:  212
# Testing sample:  90
# The best SSIM through training process: 0.9579633474349976
# The best SSIM epoch:  333
# Testing sample:  91
# The best SSIM through training process: 0.9309281706809998
# The best SSIM epoch:  486
# Testing sample:  92
# The best SSIM through training process: 0.9469034075737
# The best SSIM epoch:  219
# Testing sample:  93
# The best SSIM through training process: 0.9205598831176758
# The best SSIM epoch:  6
# Testing sample:  94
# The best SSIM through training process: 0.9333774447441101
# The best SSIM epoch:  151
# Testing sample:  95
# The best SSIM through training process: 0.9291890859603882
# The best SSIM epoch:  242
# Testing sample:  96
# The best SSIM through training process: 0.9494136571884155
# The best SSIM epoch:  221
# Testing sample:  97
# The best SSIM through training process: 0.9387818574905396
# The best SSIM epoch:  436
# Testing sample:  98
# The best SSIM through training process: 0.9423753023147583
# The best SSIM epoch:  335
# Testing sample:  99
# The best SSIM through training process: 0.9629089832305908
# The best SSIM epoch:  498
# Testing sample:  100
# The best SSIM through training process: 0.9386914968490601
# The best SSIM epoch:  418
# Testing average SSIM loss:  0.941836662888527
# Testing average SSIM loss epoch:  252.18

# %% [markdown]
# without TTT

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    if COIL == 'rss':
        scale_factor = scale_rss(input_kspace, model)
    elif COIL == 'sensmap': 
        scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 0it [00:00, ?it/s]
# 100it [00:53,  1.88it/s]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.9096605777740479
