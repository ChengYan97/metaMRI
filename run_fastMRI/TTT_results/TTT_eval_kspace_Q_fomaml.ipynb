# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)Q_T300_300epoch/E14.3_maml(1st)_out_k-sup(l1_out-5_in-5)Q_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9670770764350891
# The best SSIM epoch:  95
# Testing sample:  2
# The best SSIM through training process: 0.927634060382843
# The best SSIM epoch:  55
# Testing sample:  3
# The best SSIM through training process: 0.9597812294960022
# The best SSIM epoch:  80
# Testing sample:  4
# The best SSIM through training process: 0.9650290012359619
# The best SSIM epoch:  135
# Testing sample:  5
# The best SSIM through training process: 0.9557116031646729
# The best SSIM epoch:  80
# Testing sample:  6
# The best SSIM through training process: 0.958295464515686
# The best SSIM epoch:  92
# Testing sample:  7
# The best SSIM through training process: 0.9481160044670105
# The best SSIM epoch:  69
# Testing sample:  8
# The best SSIM through training process: 0.9369783997535706
# The best SSIM epoch:  55
# Testing sample:  9
# The best SSIM through training process: 0.9536057710647583
# The best SSIM epoch:  91
# Testing sample:  10
# The best SSIM through training process: 0.9579150676727295
# The best SSIM epoch:  74
# Testing sample:  11
# The best SSIM through training process: 0.9582236409187317
# The best SSIM epoch:  108
# Testing sample:  12
# The best SSIM through training process: 0.9614010453224182
# The best SSIM epoch:  109
# Testing sample:  13
# The best SSIM through training process: 0.9673792123794556
# The best SSIM epoch:  91
# Testing sample:  14
# The best SSIM through training process: 0.9671947360038757
# The best SSIM epoch:  110
# Testing sample:  15
# The best SSIM through training process: 0.9456895589828491
# The best SSIM epoch:  90
# Testing sample:  16
# The best SSIM through training process: 0.9665433168411255
# The best SSIM epoch:  109
# Testing sample:  17
# The best SSIM through training process: 0.960149884223938
# The best SSIM epoch:  60
# Testing sample:  18
# The best SSIM through training process: 0.9464079141616821
# The best SSIM epoch:  59
# Testing sample:  19
# The best SSIM through training process: 0.957299530506134
# The best SSIM epoch:  87
# Testing sample:  20
# The best SSIM through training process: 0.9728171229362488
# The best SSIM epoch:  90
# Testing sample:  21
# The best SSIM through training process: 0.9694543480873108
# The best SSIM epoch:  86
# Testing sample:  22
# The best SSIM through training process: 0.9568310379981995
# The best SSIM epoch:  61
# Testing sample:  23
# The best SSIM through training process: 0.9637761116027832
# The best SSIM epoch:  94
# Testing sample:  24
# The best SSIM through training process: 0.9688311815261841
# The best SSIM epoch:  105
# Testing sample:  25
# The best SSIM through training process: 0.9593566656112671
# The best SSIM epoch:  75
# Testing sample:  26
# The best SSIM through training process: 0.9623343348503113
# The best SSIM epoch:  82
# Testing sample:  27
# The best SSIM through training process: 0.9557770490646362
# The best SSIM epoch:  84
# Testing sample:  28
# The best SSIM through training process: 0.9533506035804749
# The best SSIM epoch:  91
# Testing sample:  29
# The best SSIM through training process: 0.965490996837616
# The best SSIM epoch:  106
# Testing sample:  30
# The best SSIM through training process: 0.9385992288589478
# The best SSIM epoch:  60
# Testing sample:  31
# The best SSIM through training process: 0.9465095400810242
# The best SSIM epoch:  90
# Testing sample:  32
# The best SSIM through training process: 0.9495784044265747
# The best SSIM epoch:  84
# Testing sample:  33
# The best SSIM through training process: 0.9614784717559814
# The best SSIM epoch:  112
# Testing sample:  34
# The best SSIM through training process: 0.9584140181541443
# The best SSIM epoch:  96
# Testing sample:  35
# The best SSIM through training process: 0.9571266174316406
# The best SSIM epoch:  92
# Testing sample:  36
# The best SSIM through training process: 0.957973062992096
# The best SSIM epoch:  56
# Testing sample:  37
# The best SSIM through training process: 0.951653242111206
# The best SSIM epoch:  52
# Testing sample:  38
# The best SSIM through training process: 0.9558262825012207
# The best SSIM epoch:  91
# Testing sample:  39
# The best SSIM through training process: 0.9677107334136963
# The best SSIM epoch:  181
# Testing sample:  40
# The best SSIM through training process: 0.9654250144958496
# The best SSIM epoch:  103
# Testing sample:  41
# The best SSIM through training process: 0.957805335521698
# The best SSIM epoch:  85
# Testing sample:  42
# The best SSIM through training process: 0.9547147750854492
# The best SSIM epoch:  86
# Testing sample:  43
# The best SSIM through training process: 0.9547231793403625
# The best SSIM epoch:  56
# Testing sample:  44
# The best SSIM through training process: 0.9606544375419617
# The best SSIM epoch:  87
# Testing sample:  45
# The best SSIM through training process: 0.9674333333969116
# The best SSIM epoch:  99
# Testing sample:  46
# The best SSIM through training process: 0.9304361939430237
# The best SSIM epoch:  66
# Testing sample:  47
# The best SSIM through training process: 0.9686661958694458
# The best SSIM epoch:  105
# Testing sample:  48
# The best SSIM through training process: 0.9427096843719482
# The best SSIM epoch:  53
# Testing sample:  49
# The best SSIM through training process: 0.8938780426979065
# The best SSIM epoch:  52
# Testing sample:  50
# The best SSIM through training process: 0.9522301554679871
# The best SSIM epoch:  58
# Testing sample:  51
# The best SSIM through training process: 0.9600528478622437
# The best SSIM epoch:  100
# Testing sample:  52
# The best SSIM through training process: 0.9507158398628235
# The best SSIM epoch:  85
# Testing sample:  53
# The best SSIM through training process: 0.9579216241836548
# The best SSIM epoch:  106
# Testing sample:  54
# The best SSIM through training process: 0.9789596199989319
# The best SSIM epoch:  125
# Testing sample:  55
# The best SSIM through training process: 0.9632388353347778
# The best SSIM epoch:  86
# Testing sample:  56
# The best SSIM through training process: 0.9604842662811279
# The best SSIM epoch:  99
# Testing sample:  57
# The best SSIM through training process: 0.9673399925231934
# The best SSIM epoch:  98
# Testing sample:  58
# The best SSIM through training process: 0.9519135355949402
# The best SSIM epoch:  69
# Testing sample:  59
# The best SSIM through training process: 0.9710402488708496
# The best SSIM epoch:  105
# Testing sample:  60
# The best SSIM through training process: 0.9346112012863159
# The best SSIM epoch:  72
# Testing sample:  61
# The best SSIM through training process: 0.9663861393928528
# The best SSIM epoch:  96
# Testing sample:  62
# The best SSIM through training process: 0.9490927457809448
# The best SSIM epoch:  119
# Testing sample:  63
# The best SSIM through training process: 0.9498172998428345
# The best SSIM epoch:  57
# Testing sample:  64
# The best SSIM through training process: 0.9679241180419922
# The best SSIM epoch:  134
# Testing sample:  65
# The best SSIM through training process: 0.9607561230659485
# The best SSIM epoch:  99
# Testing sample:  66
# The best SSIM through training process: 0.9744648337364197
# The best SSIM epoch:  111
# Testing sample:  67
# The best SSIM through training process: 0.9439594745635986
# The best SSIM epoch:  71
# Testing sample:  68
# The best SSIM through training process: 0.9523054361343384
# The best SSIM epoch:  96
# Testing sample:  69
# The best SSIM through training process: 0.9640277028083801
# The best SSIM epoch:  109
# Testing sample:  70
# The best SSIM through training process: 0.9634844660758972
# The best SSIM epoch:  109
# Testing sample:  71
# The best SSIM through training process: 0.9442465305328369
# The best SSIM epoch:  57
# Testing sample:  72
# The best SSIM through training process: 0.9612465500831604
# The best SSIM epoch:  86
# Testing sample:  73
# The best SSIM through training process: 0.9396096467971802
# The best SSIM epoch:  75
# Testing sample:  74
# The best SSIM through training process: 0.9500806927680969
# The best SSIM epoch:  63
# Testing sample:  75
# The best SSIM through training process: 0.9487014412879944
# The best SSIM epoch:  60
# Testing sample:  76
# The best SSIM through training process: 0.9585011005401611
# The best SSIM epoch:  111
# Testing sample:  77
# The best SSIM through training process: 0.9647860527038574
# The best SSIM epoch:  95
# Testing sample:  78
# The best SSIM through training process: 0.9730538129806519
# The best SSIM epoch:  94
# Testing sample:  79
# The best SSIM through training process: 0.9597024321556091
# The best SSIM epoch:  72
# Testing sample:  80
# The best SSIM through training process: 0.945123016834259
# The best SSIM epoch:  89
# Testing sample:  81
# The best SSIM through training process: 0.9581916928291321
# The best SSIM epoch:  98
# Testing sample:  82
# The best SSIM through training process: 0.9533872008323669
# The best SSIM epoch:  115
# Testing sample:  83
# The best SSIM through training process: 0.9577432870864868
# The best SSIM epoch:  82
# Testing sample:  84
# The best SSIM through training process: 0.9615662097930908
# The best SSIM epoch:  68
# Testing sample:  85
# The best SSIM through training process: 0.9622207283973694
# The best SSIM epoch:  86
# Testing sample:  86
# The best SSIM through training process: 0.8972544074058533
# The best SSIM epoch:  56
# Testing sample:  87
# The best SSIM through training process: 0.9437230229377747
# The best SSIM epoch:  66
# Testing sample:  88
# The best SSIM through training process: 0.954193115234375
# The best SSIM epoch:  57
# Testing sample:  89
# The best SSIM through training process: 0.9631280303001404
# The best SSIM epoch:  76
# Testing sample:  90
# The best SSIM through training process: 0.9667997360229492
# The best SSIM epoch:  86
# Testing sample:  91
# The best SSIM through training process: 0.9477972388267517
# The best SSIM epoch:  114
# Testing sample:  92
# The best SSIM through training process: 0.9620507955551147
# The best SSIM epoch:  84
# Testing sample:  93
# The best SSIM through training process: 0.9364935159683228
# The best SSIM epoch:  73
# Testing sample:  94
# The best SSIM through training process: 0.9428545236587524
# The best SSIM epoch:  58
# Testing sample:  95
# The best SSIM through training process: 0.9415211081504822
# The best SSIM epoch:  106
# Testing sample:  96
# The best SSIM through training process: 0.9583241939544678
# The best SSIM epoch:  86
# Testing sample:  97
# The best SSIM through training process: 0.9469112157821655
# The best SSIM epoch:  85
# Testing sample:  98
# The best SSIM through training process: 0.9559882879257202
# The best SSIM epoch:  83
# Testing sample:  99
# The best SSIM through training process: 0.97712242603302
# The best SSIM epoch:  135
# Testing sample:  100
# The best SSIM through training process: 0.9588083624839783
# The best SSIM epoch:  93
# Testing average SSIM loss:  0.9556162464618683
# Testing average SSIM loss epoch:  87.42
