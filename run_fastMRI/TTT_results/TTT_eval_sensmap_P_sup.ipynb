# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttpaper_sensmap_sup(l1_1e-5)P_T300_300epoch/E_tttpaper_sensmap_sup(l1_1e-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 1500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9303208589553833
# The best SSIM epoch:  442
# Testing sample:  2
# The best SSIM through training process: 0.8681052923202515
# The best SSIM epoch:  1216
# Testing sample:  3
# The best SSIM through training process: 0.923443078994751
# The best SSIM epoch:  294
# Testing sample:  4
# The best SSIM through training process: 0.93692547082901
# The best SSIM epoch:  514
# Testing sample:  5
# The best SSIM through training process: 0.9029551148414612
# The best SSIM epoch:  1421
# Testing sample:  6
# The best SSIM through training process: 0.9158716797828674
# The best SSIM epoch:  499
# Testing sample:  7
# The best SSIM through training process: 0.908336341381073
# The best SSIM epoch:  1207
# Testing sample:  8
# The best SSIM through training process: 0.8900442719459534
# The best SSIM epoch:  117
# Testing sample:  9
# The best SSIM through training process: 0.9219884276390076
# The best SSIM epoch:  526
# Testing sample:  10
# The best SSIM through training process: 0.9188385605812073
# The best SSIM epoch:  293
# Testing sample:  11
# The best SSIM through training process: 0.9265176057815552
# The best SSIM epoch:  452
# Testing sample:  12
# The best SSIM through training process: 0.9238157868385315
# The best SSIM epoch:  423
# Testing sample:  13
# The best SSIM through training process: 0.9199628233909607
# The best SSIM epoch:  1031
# Testing sample:  14
# The best SSIM through training process: 0.9292114973068237
# The best SSIM epoch:  1259
# Testing sample:  15
# The best SSIM through training process: 0.9169588685035706
# The best SSIM epoch:  495
# Testing sample:  16
# The best SSIM through training process: 0.9115854501724243
# The best SSIM epoch:  1422
# Testing sample:  17
# The best SSIM through training process: 0.8804696798324585
# The best SSIM epoch:  1498
# Testing sample:  18
# The best SSIM through training process: 0.9124726057052612
# The best SSIM epoch:  226
# Testing sample:  19
# The best SSIM through training process: 0.915247917175293
# The best SSIM epoch:  1126
# Testing sample:  20
# The best SSIM through training process: 0.9329627156257629
# The best SSIM epoch:  818
# Testing sample:  21
# The best SSIM through training process: 0.9253741502761841
# The best SSIM epoch:  856
# Testing sample:  22
# The best SSIM through training process: 0.9218785166740417
# The best SSIM epoch:  310
# Testing sample:  23
# The best SSIM through training process: 0.881906270980835
# The best SSIM epoch:  1498
# Testing sample:  24
# The best SSIM through training process: 0.9347027540206909
# The best SSIM epoch:  304
# Testing sample:  25
# The best SSIM through training process: 0.9213730096817017
# The best SSIM epoch:  448
# Testing sample:  26
# The best SSIM through training process: 0.9180929660797119
# The best SSIM epoch:  450
# Testing sample:  27
# The best SSIM through training process: 0.9183547496795654
# The best SSIM epoch:  440
# Testing sample:  28
# The best SSIM through training process: 0.9142497181892395
# The best SSIM epoch:  279
# Testing sample:  29
# The best SSIM through training process: 0.9377492666244507
# The best SSIM epoch:  443
# Testing sample:  30
# The best SSIM through training process: 0.8976455926895142
# The best SSIM epoch:  878
# Testing sample:  31
# The best SSIM through training process: 0.9111577868461609
# The best SSIM epoch:  383
# Testing sample:  32
# The best SSIM through training process: 0.9152435064315796
# The best SSIM epoch:  564
# Testing sample:  33
# The best SSIM through training process: 0.9162852764129639
# The best SSIM epoch:  953
# Testing sample:  34
# The best SSIM through training process: 0.9092175364494324
# The best SSIM epoch:  1492
# Testing sample:  35
# The best SSIM through training process: 0.9200063943862915
# The best SSIM epoch:  379
# Testing sample:  36
# The best SSIM through training process: 0.9162434339523315
# The best SSIM epoch:  313
# Testing sample:  37
# The best SSIM through training process: 0.9187532067298889
# The best SSIM epoch:  338
# Testing sample:  38
# The best SSIM through training process: 0.9117680788040161
# The best SSIM epoch:  429
# Testing sample:  39
# The best SSIM through training process: 0.9457392692565918
# The best SSIM epoch:  398
# Testing sample:  40
# The best SSIM through training process: 0.9324330687522888
# The best SSIM epoch:  491
# Testing sample:  41
# The best SSIM through training process: 0.9191284775733948
# The best SSIM epoch:  420
# Testing sample:  42
# The best SSIM through training process: 0.9133052229881287
# The best SSIM epoch:  1035
# Testing sample:  43
# The best SSIM through training process: 0.9013646841049194
# The best SSIM epoch:  426
# Testing sample:  44
# The best SSIM through training process: 0.929659366607666
# The best SSIM epoch:  316
# Testing sample:  45
# The best SSIM through training process: 0.9231778383255005
# The best SSIM epoch:  958
# Testing sample:  46
# The best SSIM through training process: 0.8827601075172424
# The best SSIM epoch:  1499
# Testing sample:  47
# The best SSIM through training process: 0.9265514612197876
# The best SSIM epoch:  1454
# Testing sample:  48
# The best SSIM through training process: 0.8889966011047363
# The best SSIM epoch:  519
# Testing sample:  49
# The best SSIM through training process: 0.8443982601165771
# The best SSIM epoch:  1498
# Testing sample:  50
# The best SSIM through training process: 0.9084015488624573
# The best SSIM epoch:  269
# Testing sample:  51
# The best SSIM through training process: 0.9008106589317322
# The best SSIM epoch:  1163
# Testing sample:  52
# The best SSIM through training process: 0.8979383707046509
# The best SSIM epoch:  1496
# Testing sample:  53
# The best SSIM through training process: 0.9226614236831665
# The best SSIM epoch:  359
# Testing sample:  54
# The best SSIM through training process: 0.9582353830337524
# The best SSIM epoch:  526
# Testing sample:  55
# The best SSIM through training process: 0.9275505542755127
# The best SSIM epoch:  482
# Testing sample:  56
# The best SSIM through training process: 0.9227521419525146
# The best SSIM epoch:  1122
# Testing sample:  57
# The best SSIM through training process: 0.9327189326286316
# The best SSIM epoch:  486
# Testing sample:  58
# The best SSIM through training process: 0.8700748085975647
# The best SSIM epoch:  1496
# Testing sample:  59
# The best SSIM through training process: 0.9416964054107666
# The best SSIM epoch:  434
# Testing sample:  60
# The best SSIM through training process: 0.9076052308082581
# The best SSIM epoch:  388
# Testing sample:  61
# The best SSIM through training process: 0.9305946230888367
# The best SSIM epoch:  379
# Testing sample:  62
# The best SSIM through training process: 0.9160947799682617
# The best SSIM epoch:  313
# Testing sample:  63
# The best SSIM through training process: 0.8970005512237549
# The best SSIM epoch:  599
# Testing sample:  64
# The best SSIM through training process: 0.9227584004402161
# The best SSIM epoch:  614
# Testing sample:  65
# The best SSIM through training process: 0.9243255257606506
# The best SSIM epoch:  343
# Testing sample:  66
# The best SSIM through training process: 0.9391945600509644
# The best SSIM epoch:  587
# Testing sample:  67
# The best SSIM through training process: 0.9074795842170715
# The best SSIM epoch:  427
# Testing sample:  68
# The best SSIM through training process: 0.9221335053443909
# The best SSIM epoch:  437
# Testing sample:  69
# The best SSIM through training process: 0.9231708645820618
# The best SSIM epoch:  663
# Testing sample:  70
# The best SSIM through training process: 0.925344705581665
# The best SSIM epoch:  448
# Testing sample:  71
# The best SSIM through training process: 0.8998677134513855
# The best SSIM epoch:  251
# Testing sample:  72
# The best SSIM through training process: 0.9298732876777649
# The best SSIM epoch:  511
# Testing sample:  73
# The best SSIM through training process: 0.9055972695350647
# The best SSIM epoch:  1117
# Testing sample:  74
# The best SSIM through training process: 0.9072993993759155
# The best SSIM epoch:  460
# Testing sample:  75
# The best SSIM through training process: 0.9072946906089783
# The best SSIM epoch:  217
# Testing sample:  76
# The best SSIM through training process: 0.9148144125938416
# The best SSIM epoch:  476
# Testing sample:  77
# The best SSIM through training process: 0.9170843958854675
# The best SSIM epoch:  1441
# Testing sample:  78
# The best SSIM through training process: 0.9445689916610718
# The best SSIM epoch:  655
# Testing sample:  79
# The best SSIM through training process: 0.9212217926979065
# The best SSIM epoch:  162
# Testing sample:  80
# The best SSIM through training process: 0.8967852592468262
# The best SSIM epoch:  1410
# Testing sample:  81
# The best SSIM through training process: 0.9203529953956604
# The best SSIM epoch:  720
# Testing sample:  82
# The best SSIM through training process: 0.9217703342437744
# The best SSIM epoch:  464
# Testing sample:  83
# The best SSIM through training process: 0.9346871376037598
# The best SSIM epoch:  495
# Testing sample:  84
# The best SSIM through training process: 0.9264551997184753
# The best SSIM epoch:  153
# Testing sample:  85
# The best SSIM through training process: 0.9265293478965759
# The best SSIM epoch:  314
# Testing sample:  86
# The best SSIM through training process: 0.8715835809707642
# The best SSIM epoch:  948
# Testing sample:  87
# The best SSIM through training process: 0.9036193490028381
# The best SSIM epoch:  224
# Testing sample:  88
# The best SSIM through training process: 0.9168292880058289
# The best SSIM epoch:  231
# Testing sample:  89
# The best SSIM through training process: 0.9265938401222229
# The best SSIM epoch:  503
# Testing sample:  90
# The best SSIM through training process: 0.9312395453453064
# The best SSIM epoch:  711
# Testing sample:  91
# The best SSIM through training process: 0.9120743274688721
# The best SSIM epoch:  226
# Testing sample:  92
# The best SSIM through training process: 0.9245553016662598
# The best SSIM epoch:  387
# Testing sample:  93
# The best SSIM through training process: 0.8885191679000854
# The best SSIM epoch:  283
# Testing sample:  94
# The best SSIM through training process: 0.9123139977455139
# The best SSIM epoch:  182
# Testing sample:  95
# The best SSIM through training process: 0.9062904715538025
# The best SSIM epoch:  500
# Testing sample:  96
# The best SSIM through training process: 0.9272645711898804
# The best SSIM epoch:  287
# Testing sample:  97
# The best SSIM through training process: 0.9177703857421875
# The best SSIM epoch:  1489
# Testing sample:  98
# The best SSIM through training process: 0.9067094326019287
# The best SSIM epoch:  815
# Testing sample:  99
# The best SSIM through training process: 0.9415493607521057
# The best SSIM epoch:  536
# Testing sample:  100
# The best SSIM through training process: 0.9161545634269714
# The best SSIM epoch:  325
# Testing average SSIM loss:  0.9155936259031295
# Testing average SSIM loss epoch:  645.74

# %% [markdown]
# without TTT

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    if COIL == 'rss':
        scale_factor = scale_rss(input_kspace, model)
    elif COIL == 'sensmap': 
        scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 0it [00:00, ?it/s]
# 100it [15:53,  9.53s/it]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.7120982152223587
