# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_rss, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttpaper_sensmap_joint(l1_1e-5)P_T300_300epoch/E_tttpaper_sensmap_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E_12.5_W_joint(l1_1e-5)P_T300_300epoch/E_12.5_W_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E12.1_maml(l1_out-3-5_in-5)P_T300_300epoch/E12.1_maml(l1_out-3-5_in-5)P_T300_300epoch_E300.pth'
# '/cheng/metaMRI/metaMRI/save/E11/E11.12_joint(l1_1e-5)P_T300_300epoch/E11.12_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
#'/cheng/metaMRI/metaMRI/save/E12.1_joint(l1_1e-5)P_T300_300epoch/E_12.1_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_rss(input_kspace, model)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk * scale_factor), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.937773585319519
# The best SSIM epoch:  204
# Testing sample:  2
# The best SSIM through training process: 0.9123409986495972
# The best SSIM epoch:  192
# Testing sample:  3
# The best SSIM through training process: 0.9305213689804077
# The best SSIM epoch:  179
# Testing sample:  4
# The best SSIM through training process: 0.9267326593399048
# The best SSIM epoch:  194
# Testing sample:  5
# The best SSIM through training process: 0.9393990635871887
# The best SSIM epoch:  199
# Testing sample:  6
# The best SSIM through training process: 0.9300352334976196
# The best SSIM epoch:  176
# Testing sample:  7
# The best SSIM through training process: 0.9325835704803467
# The best SSIM epoch:  201
# Testing sample:  8
# The best SSIM through training process: 0.9210186004638672
# The best SSIM epoch:  123
# Testing sample:  9
# The best SSIM through training process: 0.9309628009796143
# The best SSIM epoch:  159
# Testing sample:  10
# The best SSIM through training process: 0.9324734210968018
# The best SSIM epoch:  118
# Testing sample:  11
# The best SSIM through training process: 0.9243857264518738
# The best SSIM epoch:  187
# Testing sample:  12
# The best SSIM through training process: 0.9261910319328308
# The best SSIM epoch:  190
# Testing sample:  13
# The best SSIM through training process: 0.942047119140625
# The best SSIM epoch:  241
# Testing sample:  14
# The best SSIM through training process: 0.9452002644538879
# The best SSIM epoch:  321
# Testing sample:  15
# The best SSIM through training process: 0.9319594502449036
# The best SSIM epoch:  105
# Testing sample:  16
# The best SSIM through training process: 0.9402303695678711
# The best SSIM epoch:  369
# Testing sample:  17
# The best SSIM through training process: 0.9443497657775879
# The best SSIM epoch:  162
# Testing sample:  18
# The best SSIM through training process: 0.932968258857727
# The best SSIM epoch:  106
# Testing sample:  19
# The best SSIM through training process: 0.940838098526001
# The best SSIM epoch:  220
# Testing sample:  20
# The best SSIM through training process: 0.9502691626548767
# The best SSIM epoch:  337
# Testing sample:  21
# The best SSIM through training process: 0.9449228048324585
# The best SSIM epoch:  251
# Testing sample:  22
# The best SSIM through training process: 0.9388668537139893
# The best SSIM epoch:  90
# Testing sample:  23
# The best SSIM through training process: 0.9450528025627136
# The best SSIM epoch:  235
# Testing sample:  24
# The best SSIM through training process: 0.9309844970703125
# The best SSIM epoch:  210
# Testing sample:  25
# The best SSIM through training process: 0.9339255094528198
# The best SSIM epoch:  116
# Testing sample:  26
# The best SSIM through training process: 0.9352390766143799
# The best SSIM epoch:  162
# Testing sample:  27
# The best SSIM through training process: 0.9153895974159241
# The best SSIM epoch:  210
# Testing sample:  28
# The best SSIM through training process: 0.9238554239273071
# The best SSIM epoch:  194
# Testing sample:  29
# The best SSIM through training process: 0.9354258179664612
# The best SSIM epoch:  176
# Testing sample:  30
# The best SSIM through training process: 0.9269348382949829
# The best SSIM epoch:  109
# Testing sample:  31
# The best SSIM through training process: 0.9106383919715881
# The best SSIM epoch:  157
# Testing sample:  32
# The best SSIM through training process: 0.9348064064979553
# The best SSIM epoch:  124
# Testing sample:  33
# The best SSIM through training process: 0.9279415607452393
# The best SSIM epoch:  289
# Testing sample:  34
# The best SSIM through training process: 0.9407150149345398
# The best SSIM epoch:  222
# Testing sample:  35
# The best SSIM through training process: 0.941842257976532
# The best SSIM epoch:  161
# Testing sample:  36
# The best SSIM through training process: 0.9319206476211548
# The best SSIM epoch:  109
# Testing sample:  37
# The best SSIM through training process: 0.9384052753448486
# The best SSIM epoch:  94
# Testing sample:  38
# The best SSIM through training process: 0.9251502156257629
# The best SSIM epoch:  205
# Testing sample:  39
# The best SSIM through training process: 0.9464381337165833
# The best SSIM epoch:  259
# Testing sample:  40
# The best SSIM through training process: 0.9315946698188782
# The best SSIM epoch:  245
# Testing sample:  41
# The best SSIM through training process: 0.9221364855766296
# The best SSIM epoch:  140
# Testing sample:  42
# The best SSIM through training process: 0.9370198845863342
# The best SSIM epoch:  167
# Testing sample:  43
# The best SSIM through training process: 0.933221161365509
# The best SSIM epoch:  121
# Testing sample:  44
# The best SSIM through training process: 0.9367641806602478
# The best SSIM epoch:  125
# Testing sample:  45
# The best SSIM through training process: 0.9428175687789917
# The best SSIM epoch:  267
# Testing sample:  46
# The best SSIM through training process: 0.9256850481033325
# The best SSIM epoch:  123
# Testing sample:  47
# The best SSIM through training process: 0.945426344871521
# The best SSIM epoch:  332
# Testing sample:  48
# The best SSIM through training process: 0.9293200373649597
# The best SSIM epoch:  119
# Testing sample:  49
# The best SSIM through training process: 0.8927683234214783
# The best SSIM epoch:  79
# Testing sample:  50
# The best SSIM through training process: 0.9344621300697327
# The best SSIM epoch:  135
# Testing sample:  51
# The best SSIM through training process: 0.9291806817054749
# The best SSIM epoch:  302
# Testing sample:  52
# The best SSIM through training process: 0.9385405778884888
# The best SSIM epoch:  189
# Testing sample:  53
# The best SSIM through training process: 0.9307129383087158
# The best SSIM epoch:  193
# Testing sample:  54
# The best SSIM through training process: 0.9510279297828674
# The best SSIM epoch:  238
# Testing sample:  55
# The best SSIM through training process: 0.9368665814399719
# The best SSIM epoch:  140
# Testing sample:  56
# The best SSIM through training process: 0.9375884532928467
# The best SSIM epoch:  198
# Testing sample:  57
# The best SSIM through training process: 0.9401642084121704
# The best SSIM epoch:  152
# Testing sample:  58
# The best SSIM through training process: 0.9357160329818726
# The best SSIM epoch:  201
# Testing sample:  59
# The best SSIM through training process: 0.9483771324157715
# The best SSIM epoch:  195
# Testing sample:  60
# The best SSIM through training process: 0.9236854314804077
# The best SSIM epoch:  116
# Testing sample:  61
# The best SSIM through training process: 0.925963819026947
# The best SSIM epoch:  169
# Testing sample:  62
# The best SSIM through training process: 0.9201709628105164
# The best SSIM epoch:  184
# Testing sample:  63
# The best SSIM through training process: 0.9318638443946838
# The best SSIM epoch:  147
# Testing sample:  64
# The best SSIM through training process: 0.9353681802749634
# The best SSIM epoch:  267
# Testing sample:  65
# The best SSIM through training process: 0.9395183324813843
# The best SSIM epoch:  167
# Testing sample:  66
# The best SSIM through training process: 0.9492741227149963
# The best SSIM epoch:  184
# Testing sample:  67
# The best SSIM through training process: 0.934332013130188
# The best SSIM epoch:  126
# Testing sample:  68
# The best SSIM through training process: 0.9393438100814819
# The best SSIM epoch:  149
# Testing sample:  69
# The best SSIM through training process: 0.9217180609703064
# The best SSIM epoch:  223
# Testing sample:  70
# The best SSIM through training process: 0.924153745174408
# The best SSIM epoch:  197
# Testing sample:  71
# The best SSIM through training process: 0.9217526912689209
# The best SSIM epoch:  87
# Testing sample:  72
# The best SSIM through training process: 0.9364261031150818
# The best SSIM epoch:  128
# Testing sample:  73
# The best SSIM through training process: 0.9308440685272217
# The best SSIM epoch:  147
# Testing sample:  74
# The best SSIM through training process: 0.920852541923523
# The best SSIM epoch:  143
# Testing sample:  75
# The best SSIM through training process: 0.9331336617469788
# The best SSIM epoch:  132
# Testing sample:  76
# The best SSIM through training process: 0.9267075061798096
# The best SSIM epoch:  214
# Testing sample:  77
# The best SSIM through training process: 0.946568489074707
# The best SSIM epoch:  178
# Testing sample:  78
# The best SSIM through training process: 0.9550632238388062
# The best SSIM epoch:  181
# Testing sample:  79
# The best SSIM through training process: 0.9347307682037354
# The best SSIM epoch:  153
# Testing sample:  80
# The best SSIM through training process: 0.920378565788269
# The best SSIM epoch:  271
# Testing sample:  81
# The best SSIM through training process: 0.9356866478919983
# The best SSIM epoch:  299
# Testing sample:  82
# The best SSIM through training process: 0.9255452156066895
# The best SSIM epoch:  195
# Testing sample:  83
# The best SSIM through training process: 0.938124418258667
# The best SSIM epoch:  191
# Testing sample:  84
# The best SSIM through training process: 0.9392799139022827
# The best SSIM epoch:  155
# Testing sample:  85
# The best SSIM through training process: 0.9443855285644531
# The best SSIM epoch:  153
# Testing sample:  86
# The best SSIM through training process: 0.9026183485984802
# The best SSIM epoch:  99
# Testing sample:  87
# The best SSIM through training process: 0.9201369881629944
# The best SSIM epoch:  154
# Testing sample:  88
# The best SSIM through training process: 0.9295892119407654
# The best SSIM epoch:  126
# Testing sample:  89
# The best SSIM through training process: 0.9350282549858093
# The best SSIM epoch:  154
# Testing sample:  90
# The best SSIM through training process: 0.9440442323684692
# The best SSIM epoch:  207
# Testing sample:  91
# The best SSIM through training process: 0.9199398159980774
# The best SSIM epoch:  190
# Testing sample:  92
# The best SSIM through training process: 0.9234811067581177
# The best SSIM epoch:  200
# Testing sample:  93
# The best SSIM through training process: 0.9113082885742188
# The best SSIM epoch:  115
# Testing sample:  94
# The best SSIM through training process: 0.9314897060394287
# The best SSIM epoch:  84
# Testing sample:  95
# The best SSIM through training process: 0.918817400932312
# The best SSIM epoch:  183
# Testing sample:  96
# The best SSIM through training process: 0.9378891587257385
# The best SSIM epoch:  127
# Testing sample:  97
# The best SSIM through training process: 0.9359822273254395
# The best SSIM epoch:  143
# Testing sample:  98
# The best SSIM through training process: 0.9288044571876526
# The best SSIM epoch:  204
# Testing sample:  99
# The best SSIM through training process: 0.9450864195823669
# The best SSIM epoch:  275
# Testing sample:  100
# The best SSIM through training process: 0.9390130043029785
# The best SSIM epoch:  147
# Testing average SSIM loss:  0.9325822633504868
# Testing average SSIM loss epoch:  179.81

# %%
fig, axes = plt.subplots(1, 2, dpi= 300)

axes[0].imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[0].axis('off')

axes[1].imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[1].set_title('Ground Truth')
axes[1].axis('off')

plt.subplots_adjust(wspace=0.1)
plt.show()

# %% [markdown]
# RSS

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 1500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_rss(input_kspace, model)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = rss_torch(complex_abs(ifft2c(origk))).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = torch.moveaxis(rss_torch(ifft2c(scale_input_kspace)), -1, 0)   # [2, height, width]

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9428324699401855
# The best SSIM epoch:  702
# Testing sample:  2
# The best SSIM through training process: 0.9080637097358704
# The best SSIM epoch:  306
# Testing sample:  3
# The best SSIM through training process: 0.9224241971969604
# The best SSIM epoch:  520
# Testing sample:  4
# The best SSIM through training process: 0.9399042725563049
# The best SSIM epoch:  847
# Testing sample:  5
# The best SSIM through training process: 0.9307398796081543
# The best SSIM epoch:  579
# Testing sample:  6
# The best SSIM through training process: 0.9231774210929871
# The best SSIM epoch:  777
# Testing sample:  7
# The best SSIM through training process: 0.919636070728302
# The best SSIM epoch:  504
# Testing sample:  8
# The best SSIM through training process: 0.8984377384185791
# The best SSIM epoch:  381
# Testing sample:  9
# The best SSIM through training process: 0.9164419174194336
# The best SSIM epoch:  796
# Testing sample:  10
# The best SSIM through training process: 0.9225330948829651
# The best SSIM epoch:  584
# Testing sample:  11
# The best SSIM through training process: 0.9284236431121826
# The best SSIM epoch:  496
# Testing sample:  12
# The best SSIM through training process: 0.9327806830406189
# The best SSIM epoch:  692
# Testing sample:  13
# The best SSIM through training process: 0.9408532977104187
# The best SSIM epoch:  851
# Testing sample:  14
# The best SSIM through training process: 0.9438704252243042
# The best SSIM epoch:  711
# Testing sample:  15
# The best SSIM through training process: 0.9174503087997437
# The best SSIM epoch:  337
# Testing sample:  16
# The best SSIM through training process: 0.9460596442222595
# The best SSIM epoch:  1357
# Testing sample:  17
# The best SSIM through training process: 0.9260098338127136
# The best SSIM epoch:  411
# Testing sample:  18
# The best SSIM through training process: 0.9080161452293396
# The best SSIM epoch:  418
# Testing sample:  19
# The best SSIM through training process: 0.932308554649353
# The best SSIM epoch:  572
# Testing sample:  20
# The best SSIM through training process: 0.9472417831420898
# The best SSIM epoch:  817
# Testing sample:  21
# Epoch 37/1500, SSIM: 0.8812
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 51
#      49 # S fθ(A†y) [coils, height, width, channel]
#      50 if background_flip == True:
# ---> 51     output_sens_image = torch.zeros(sens_maps.shape).to(device)
#      52     for j,s in enumerate(sens_maps):
#      53         ss = s.clone()
#
# KeyboardInterrupt:

# %%
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing average SSIM loss:  0.9273602545261384
# Testing average SSIM loss epoch:  632.9

# %%
plt.figure(dpi=400)
plt.imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
plt.axis('off')
plt.show()

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E11/E11.11_sup(l1_1e-5)Q_T300_300epoch/E11.11_sup(l1_1e-5)Q_T300_300epoch_E300_best.pth'
# '/cheng/metaMRI/metaMRI/save/E12.1_maml(l1_out-3-5_in-5)P_T300_300epoch/E12.1_maml(l1_out-3-5_in-5)P_T300_300epoch_E300.pth'
# '/cheng/metaMRI/metaMRI/save/E11/E11.12_joint(l1_1e-5)P_T300_300epoch/E11.12_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'
#'/cheng/metaMRI/metaMRI/save/E12.1_joint(l1_1e-5)P_T300_300epoch/E_12.1_joint(l1_1e-5)P_T300_300epoch_E300_best.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
sup_model_output = model(train_inputs.unsqueeze(0)).squeeze(0)      
sup_output_image = complex_abs(torch.moveaxis(sup_model_output, 0, -1 )).unsqueeze(0)
crop_sup_output_image = center_crop( sup_output_image, crop_size )
crop_sup_output_image = (crop_sup_output_image - crop_sup_output_image.mean()) / crop_sup_output_image.std()
crop_sup_output_image *= std_crop_target_image
crop_sup_output_image += mean_crop_target_image

# %%
loss_ssim = 1 - ssim_fct(crop_sup_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
loss_ssim
# Out:
# 0.9398258924484253

# %%
fig, axes = plt.subplots(1, 3, dpi= 300)

axes[0].imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[0].set_title('Joint train on knee + TTT')
axes[0].axis('off')

axes[1].imshow(crop_sup_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[1].set_title('Sup train on Brain')
axes[1].axis('off')

axes[2].imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[2].set_title('Ground Truth')
axes[2].axis('off')

plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
plt.figure(dpi=400)
plt.imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
plt.axis('off')
plt.show()
