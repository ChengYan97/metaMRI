# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E14.2_maml_out_k-sup(l1_out-5_in-5)P_T300_300epoch/E14.2_maml_out_k-sup(l1_out-5_in-5)P_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9509630799293518
# The best SSIM epoch:  136
# Testing sample:  2
# The best SSIM through training process: 0.9178811311721802
# The best SSIM epoch:  132
# Testing sample:  3
# The best SSIM through training process: 0.9423545598983765
# The best SSIM epoch:  99
# Testing sample:  4
# The best SSIM through training process: 0.9484837651252747
# The best SSIM epoch:  161
# Testing sample:  5
# The best SSIM through training process: 0.9451767206192017
# The best SSIM epoch:  144
# Testing sample:  6
# The best SSIM through training process: 0.9397752285003662
# The best SSIM epoch:  146
# Testing sample:  7
# The best SSIM through training process: 0.9372713565826416
# The best SSIM epoch:  145
# Testing sample:  8
# The best SSIM through training process: 0.9264711141586304
# The best SSIM epoch:  68
# Testing sample:  9
# The best SSIM through training process: 0.9386266469955444
# The best SSIM epoch:  144
# Testing sample:  10
# The best SSIM through training process: 0.9406336545944214
# The best SSIM epoch:  117
# Testing sample:  11
# The best SSIM through training process: 0.939995527267456
# The best SSIM epoch:  139
# Testing sample:  12
# The best SSIM through training process: 0.9422247409820557
# The best SSIM epoch:  128
# Testing sample:  13
# The best SSIM through training process: 0.9532922506332397
# The best SSIM epoch:  131
# Testing sample:  14
# The best SSIM through training process: 0.9544167518615723
# The best SSIM epoch:  164
# Testing sample:  15
# The best SSIM through training process: 0.9352993965148926
# The best SSIM epoch:  137
# Testing sample:  16
# The best SSIM through training process: 0.9494758248329163
# The best SSIM epoch:  164
# Testing sample:  17
# The best SSIM through training process: 0.9487738609313965
# The best SSIM epoch:  150
# Testing sample:  18
# The best SSIM through training process: 0.9347651600837708
# The best SSIM epoch:  125
# Testing sample:  19
# The best SSIM through training process: 0.9468692541122437
# The best SSIM epoch:  156
# Testing sample:  20
# The best SSIM through training process: 0.9569333791732788
# The best SSIM epoch:  251
# Testing sample:  21
# The best SSIM through training process: 0.9531053304672241
# The best SSIM epoch:  217
# Testing sample:  22
# The best SSIM through training process: 0.9454696774482727
# The best SSIM epoch:  98
# Testing sample:  23
# The best SSIM through training process: 0.9539094567298889
# The best SSIM epoch:  169
# Testing sample:  24
# The best SSIM through training process: 0.9489919543266296
# The best SSIM epoch:  138
# Testing sample:  25
# The best SSIM through training process: 0.9462786912918091
# The best SSIM epoch:  136
# Testing sample:  26
# The best SSIM through training process: 0.9460352063179016
# The best SSIM epoch:  144
# Testing sample:  27
# The best SSIM through training process: 0.9328922629356384
# The best SSIM epoch:  147
# Testing sample:  28
# The best SSIM through training process: 0.9386606812477112
# The best SSIM epoch:  114
# Testing sample:  29
# The best SSIM through training process: 0.9502360224723816
# The best SSIM epoch:  147
# Testing sample:  30
# The best SSIM through training process: 0.9289122223854065
# The best SSIM epoch:  152
# Testing sample:  31
# The best SSIM through training process: 0.9249863624572754
# The best SSIM epoch:  119
# Testing sample:  32
# The best SSIM through training process: 0.9390252232551575
# The best SSIM epoch:  129
# Testing sample:  33
# The best SSIM through training process: 0.943595290184021
# The best SSIM epoch:  159
# Testing sample:  34
# The best SSIM through training process: 0.9486047625541687
# The best SSIM epoch:  171
# Testing sample:  35
# The best SSIM through training process: 0.9506983757019043
# The best SSIM epoch:  111
# Testing sample:  36
# The best SSIM through training process: 0.9401695132255554
# The best SSIM epoch:  105
# Testing sample:  37
# The best SSIM through training process: 0.9446303248405457
# The best SSIM epoch:  80
# Testing sample:  38
# The best SSIM through training process: 0.9378156065940857
# The best SSIM epoch:  129
# Testing sample:  39
# The best SSIM through training process: 0.9536131024360657
# The best SSIM epoch:  235
# Testing sample:  40
# The best SSIM through training process: 0.9473598003387451
# The best SSIM epoch:  149
# Testing sample:  41
# The best SSIM through training process: 0.9391838312149048
# The best SSIM epoch:  138
# Testing sample:  42
# The best SSIM through training process: 0.9425382614135742
# The best SSIM epoch:  133
# Testing sample:  43
# The best SSIM through training process: 0.9415366649627686
# The best SSIM epoch:  148
# Testing sample:  44
# The best SSIM through training process: 0.9484269618988037
# The best SSIM epoch:  102
# Testing sample:  45
# The best SSIM through training process: 0.9507922530174255
# The best SSIM epoch:  240
# Testing sample:  46
# The best SSIM through training process: 0.9262845516204834
# The best SSIM epoch:  105
# Testing sample:  47
# The best SSIM through training process: 0.9568845629692078
# The best SSIM epoch:  160
# Testing sample:  48
# The best SSIM through training process: 0.9329888224601746
# The best SSIM epoch:  139
# Testing sample:  49
# The best SSIM through training process: 0.8916108012199402
# The best SSIM epoch:  89
# Testing sample:  50
# The best SSIM through training process: 0.9397457838058472
# The best SSIM epoch:  88
# Testing sample:  51
# The best SSIM through training process: 0.9400094747543335
# The best SSIM epoch:  206
# Testing sample:  52
# The best SSIM through training process: 0.9422239065170288
# The best SSIM epoch:  143
# Testing sample:  53
# The best SSIM through training process: 0.9448807835578918
# The best SSIM epoch:  143
# Testing sample:  54
# The best SSIM through training process: 0.9654569625854492
# The best SSIM epoch:  157
# Testing sample:  55
# The best SSIM through training process: 0.9485077857971191
# The best SSIM epoch:  162
# Testing sample:  56
# The best SSIM through training process: 0.9481550455093384
# The best SSIM epoch:  182
# Testing sample:  57
# The best SSIM through training process: 0.955097496509552
# The best SSIM epoch:  124
# Testing sample:  58
# The best SSIM through training process: 0.9411649703979492
# The best SSIM epoch:  130
# Testing sample:  59
# The best SSIM through training process: 0.9569807648658752
# The best SSIM epoch:  134
# Testing sample:  60
# The best SSIM through training process: 0.9289702773094177
# The best SSIM epoch:  104
# Testing sample:  61
# The best SSIM through training process: 0.9474380612373352
# The best SSIM epoch:  157
# Testing sample:  62
# The best SSIM through training process: 0.9340556263923645
# The best SSIM epoch:  139
# Testing sample:  63
# The best SSIM through training process: 0.936331570148468
# The best SSIM epoch:  168
# Testing sample:  64
# The best SSIM through training process: 0.9487812519073486
# The best SSIM epoch:  187
# Testing sample:  65
# The best SSIM through training process: 0.9497554302215576
# The best SSIM epoch:  136
# Testing sample:  66
# The best SSIM through training process: 0.9604383707046509
# The best SSIM epoch:  174
# Testing sample:  67
# The best SSIM through training process: 0.9368460774421692
# The best SSIM epoch:  129
# Testing sample:  68
# The best SSIM through training process: 0.9410384893417358
# The best SSIM epoch:  126
# Testing sample:  69
# The best SSIM through training process: 0.9401564002037048
# The best SSIM epoch:  156
# Testing sample:  70
# The best SSIM through training process: 0.94423508644104
# The best SSIM epoch:  157
# Testing sample:  71
# The best SSIM through training process: 0.9293292164802551
# The best SSIM epoch:  108
# Testing sample:  72
# The best SSIM through training process: 0.9446538090705872
# The best SSIM epoch:  171
# Testing sample:  73
# The best SSIM through training process: 0.9320302605628967
# The best SSIM epoch:  146
# Testing sample:  74
# The best SSIM through training process: 0.9318854212760925
# The best SSIM epoch:  118
# Testing sample:  75
# The best SSIM through training process: 0.9385080933570862
# The best SSIM epoch:  102
# Testing sample:  76
# The best SSIM through training process: 0.9400397539138794
# The best SSIM epoch:  126
# Testing sample:  77
# The best SSIM through training process: 0.9542483687400818
# The best SSIM epoch:  139
# Testing sample:  78
# The best SSIM through training process: 0.9603288769721985
# The best SSIM epoch:  182
# Testing sample:  79
# The best SSIM through training process: 0.9471036195755005
# The best SSIM epoch:  95
# Testing sample:  80
# The best SSIM through training process: 0.9305458068847656
# The best SSIM epoch:  155
# Testing sample:  81
# The best SSIM through training process: 0.9438952803611755
# The best SSIM epoch:  238
# Testing sample:  82
# The best SSIM through training process: 0.9374147653579712
# The best SSIM epoch:  129
# Testing sample:  83
# The best SSIM through training process: 0.9428694248199463
# The best SSIM epoch:  169
# Testing sample:  84
# The best SSIM through training process: 0.9483292698860168
# The best SSIM epoch:  76
# Testing sample:  85
# The best SSIM through training process: 0.9531972408294678
# The best SSIM epoch:  133
# Testing sample:  86
# The best SSIM through training process: 0.8970280885696411
# The best SSIM epoch:  91
# Testing sample:  87
# The best SSIM through training process: 0.9299482703208923
# The best SSIM epoch:  112
# Testing sample:  88
# The best SSIM through training process: 0.9396671056747437
# The best SSIM epoch:  117
# Testing sample:  89
# The best SSIM through training process: 0.9474178552627563
# The best SSIM epoch:  141
# Testing sample:  90
# The best SSIM through training process: 0.9525375962257385
# The best SSIM epoch:  173
# Testing sample:  91
# The best SSIM through training process: 0.9329773187637329
# The best SSIM epoch:  154
# Testing sample:  92
# The best SSIM through training process: 0.9420257210731506
# The best SSIM epoch:  131
# Testing sample:  93
# The best SSIM through training process: 0.9220165610313416
# The best SSIM epoch:  100
# Testing sample:  94
# The best SSIM through training process: 0.9357279539108276
# The best SSIM epoch:  114
# Testing sample:  95
# The best SSIM through training process: 0.9294911026954651
# The best SSIM epoch:  135
# Testing sample:  96
# The best SSIM through training process: 0.9448778629302979
# The best SSIM epoch:  177
# Testing sample:  97
# The best SSIM through training process: 0.9385561943054199
# The best SSIM epoch:  137
# Testing sample:  98
# The best SSIM through training process: 0.9417052268981934
# The best SSIM epoch:  207
# Testing sample:  99
# The best SSIM through training process: 0.9602594375610352
# The best SSIM epoch:  248
# Testing sample:  100
# The best SSIM through training process: 0.9447334408760071
# The best SSIM epoch:  134
# Testing average SSIM loss:  0.9419853854179382
# Testing average SSIM loss epoch:  143.0

# %% [markdown]
# without TTT

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 0it [00:00, ?it/s]
# 100it [00:44,  2.27it/s]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.745689389705658
