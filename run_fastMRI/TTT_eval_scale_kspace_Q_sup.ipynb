# %%
import time
import random
import numpy as np
import pandas as pd
import sys
import pickle
import h5py
import copy
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import learn2learn as l2l
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from functions.fftc import fft2c_new as fft2c
from functions.fftc import ifft2c_new as ifft2c
from functions.math import complex_abs, complex_mul, complex_conj
# The corase reconstruction is the rss of the zerofilled multi-coil kspaces
# after inverse FT.
from functions.data.transforms import UnetDataTransform_TTTpaper_fixMask, center_crop,scale_rss, scale_sensmap, normalize_separate_over_ch, rss_torch
# Import a torch.utils.data.Dataset class that takes a list of data examples, a path to those examples
# a data transform and outputs a torch dataset.
from functions.data.mri_dataset import SliceDataset
# Unet architecture as nn.Module
from functions.models.unet import Unet
# Function that returns a MaskFunc object either for generatig random or equispaced masks
from functions.data.subsample import create_mask_for_mask_type
# Implementation of SSIMLoss
from functions.training.losses import SSIMLoss
from functions.helper import evaluate2c_imagepair
### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart


plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Computer Modern Roman"]})

colors = ['b','r','k','g','m','c','tab:brown','tab:orange','tab:pink','tab:gray','tab:olive','tab:purple']

markers = ["v","o","^","1","*",">","d","<","s","P","X"]
FONTSIZE = 22

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# seed
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ### Load the data

# %%
# data path
path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_val.yaml'
path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_val/'

# path_test = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/TTT_brain_test_100.yaml'
# path_test_sensmaps = '/cheng/metaMRI/metaMRI/data_dict/TTT_paper/sensmap_brain_test/'

# data transform
data_transform = UnetDataTransform_TTTpaper_fixMask('multicoil')

# training dataset and data loader
testset = SliceDataset(dataset = path_test, path_to_dataset='', 
                path_to_sensmaps = path_test_sensmaps, provide_senmaps=True, 
                challenge="multicoil", transform = data_transform, use_dataset_cache=True)

# shuffle = False !!!!!!!
test_dataloader = torch.utils.data.DataLoader(dataset = testset, batch_size = 1, 
                shuffle = False, generator = torch.Generator().manual_seed(1), pin_memory = False)

# %%
checkpoint_path = '/cheng/metaMRI/metaMRI/save/E_tttkspace_sensmap_sup(l1_1e-5)Q_T300_300epoch/E_tttkspace_sensmap_sup(l1_1e-5)Q_T300_300epoch_E300.pth'

model = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
model.load_state_dict(torch.load(checkpoint_path))
model = model.to(device)

# %%
path_mask = '/cheng/metaMRI/ttt_for_deep_learning_cs/unet/test_data/anatomy_shift/mask2d'
with open(path_mask,'rb') as fn:
    mask2d = pickle.load(fn)
mask = torch.tensor(mask2d[0]).unsqueeze(0).unsqueeze(0).unsqueeze(-1)
mask = mask.to(device)

# %% [markdown]
# ### Test-time training

# %%
background_flip = True
eval_with_binary_mask = False

# %% [markdown]
# Sensmap

# %%
# best_loss_l1_history=[]
# best_loss_l1_index_history=[]
best_loss_ssim_history=[]
best_loss_ssim_index_history=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')
adapt_lr = 0.00001
TTT_epoch = 500
# each data point TTT

for iter, batch in enumerate(test_dataloader): 
    print('Testing sample: ', iter+1)
    origk, sens_maps, sens_maps_conj, binary_background_mask, fname, slice_num = batch
    origk = origk.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)
    binary_background_mask = binary_background_mask.to(device)

    # input k space
    input_kspace = origk * mask + 0.0
    # scale factor
    scale_factor = scale_sensmap(input_kspace, model,sens_maps_conj)
    scale_input_kspace = scale_factor * input_kspace # [coils,height,width,2]

    # gt image by normalized kspace: x
    target_image_1c = complex_abs(complex_mul(ifft2c(origk), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # sensmap combine
    # target_image = complex_mul(target_image, sens_maps_conj).sum(dim=0, keepdim=False)
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    std_crop_target_image = crop_target_image.std()
    mean_crop_target_image = crop_target_image.mean()

    # A†y
    # train_inputs = complex_mul(train_inputs, sens_maps_conj).sum(dim=0, keepdim=False) #shape: height,width,2
    train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    train_inputs = torch.moveaxis( train_inputs , -1, 0 )

    loss_l1_history = []
    loss_ssim_history = []
    self_loss_history = []
    model_ttt = copy.deepcopy(model)
    optimizer = torch.optim.Adam(model_ttt.parameters(),lr=adapt_lr)

    for iteration in range(TTT_epoch): 
        ###### training ######
        # fθ(A†y)
        model_output = model_ttt(train_inputs.unsqueeze(0))    # [1, 2, height, width]       
        model_output = torch.moveaxis(model_output, 1, -1 )    #[1, height, width, 2]
        # S fθ(A†y) [coils, height, width, channel]
        if background_flip == True: 
            output_sens_image = torch.zeros(sens_maps.shape).to(device) 
            for j,s in enumerate(sens_maps):
                ss = s.clone()
                ss[torch.abs(ss)==0.0] = torch.abs(ss).max()
                output_sens_image[j,:,:,0] = model_output[0,:,:,0] * ss[:,:,0] - model_output[0,:,:,1] * ss[:,:,1]
                output_sens_image[j,:,:,1] = model_output[0,:,:,0] * ss[:,:,1] + model_output[0,:,:,1] * ss[:,:,0]

        else: 
            output_sens_image = complex_mul(model_output, sens_maps)
        # FS fθ(A†y)
        Fimg = fft2c(output_sens_image)
        # MFS fθ(A†y) = A fθ(A†y)
        Fimg_forward = Fimg * mask
        # consistency loss [y, Afθ(A†y)]
        loss_self = l1_loss(Fimg_forward, scale_input_kspace) / torch.sum(torch.abs(scale_input_kspace))

        optimizer.zero_grad()
        loss_self.backward()
        optimizer.step()
        #train_loss += loss.item()
        #print('TTT loss: ',loss_self.item())
        self_loss_history.append(loss_self.item())

        ###### evaluation ######
        output_image_1c = complex_abs(model_output).unsqueeze(0)    # [2, height, width] -> [1, height, width]
        if eval_with_binary_mask == True: 
            binary_mask_output_image_1c = (output_image_1c.unsqueeze(0) * binary_background_mask).squeeze(0)
            # center crop for SSIM
            crop_output_image = center_crop( binary_mask_output_image_1c, crop_size )
        else: 
            # center crop for SSIM
            crop_output_image = center_crop( output_image_1c, crop_size )
        # normalization
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image
        # SSIM = 1 - loss
        loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
        print(f"Epoch {iteration+1}/{TTT_epoch}, Loss: {loss_self.item():.4f}", end='\r')
        print(f"Epoch {iteration+1}/{TTT_epoch}, SSIM: {loss_ssim:.4f}", end='\r')

        #loss_l1_history.append(loss_l1)
        loss_ssim_history.append(loss_ssim)

    # best results for an example
    # best_loss_l1 = min(loss_l1_history)
    # print('The best L1: ', best_loss_l1)
    # best_loss_l1_epoch = np.argmin(loss_l1_history)
    # print('The best L1 epoch: ', best_loss_l1_epoch)
    best_loss_ssim = max(loss_ssim_history)
    print('The best SSIM through training process:', best_loss_ssim)
    best_loss_ssim_epoch = np.argmax(loss_ssim_history)
    print('The best SSIM epoch: ', best_loss_ssim_epoch)

    # best_loss_l1_index_history.append(best_loss_l1_epoch)
    best_loss_ssim_index_history.append(best_loss_ssim_epoch)
    # best_loss_l1_history.append(best_loss_l1)
    best_loss_ssim_history.append(best_loss_ssim)


# print("Testing average L1 loss: ", sum(best_loss_l1_history) / len(best_loss_l1_history))
# print("Testing average L1 loss epoch: ", sum(best_loss_l1_index_history) / len(best_loss_l1_index_history))
print("Testing average SSIM loss: ", sum(best_loss_ssim_history) / len(best_loss_ssim_history))
print("Testing average SSIM loss epoch: ", sum(best_loss_ssim_index_history) / len(best_loss_ssim_index_history))
# Out:
# Testing sample:  1
# The best SSIM through training process: 0.9671842455863953
# The best SSIM epoch:  89
# Testing sample:  2
# The best SSIM through training process: 0.928203284740448
# The best SSIM epoch:  58
# Testing sample:  3
# The best SSIM through training process: 0.9600125551223755
# The best SSIM epoch:  83
# Testing sample:  4
# The best SSIM through training process: 0.9662400484085083
# The best SSIM epoch:  129
# Testing sample:  5
# The best SSIM through training process: 0.9550971984863281
# The best SSIM epoch:  71
# Testing sample:  6
# The best SSIM through training process: 0.9575912356376648
# The best SSIM epoch:  91
# Testing sample:  7
# The best SSIM through training process: 0.9496556520462036
# The best SSIM epoch:  75
# Testing sample:  8
# The best SSIM through training process: 0.9370705485343933
# The best SSIM epoch:  46
# Testing sample:  9
# The best SSIM through training process: 0.9530986547470093
# The best SSIM epoch:  91
# Testing sample:  10
# The best SSIM through training process: 0.9576781392097473
# The best SSIM epoch:  72
# Testing sample:  11
# The best SSIM through training process: 0.9590315222740173
# The best SSIM epoch:  94
# Testing sample:  12
# The best SSIM through training process: 0.9617201089859009
# The best SSIM epoch:  99
# Testing sample:  13
# The best SSIM through training process: 0.9667855501174927
# The best SSIM epoch:  88
# Testing sample:  14
# The best SSIM through training process: 0.9659412503242493
# The best SSIM epoch:  114
# Testing sample:  15
# The best SSIM through training process: 0.9453790783882141
# The best SSIM epoch:  94
# Testing sample:  16
# The best SSIM through training process: 0.9662300944328308
# The best SSIM epoch:  102
# Testing sample:  17
# The best SSIM through training process: 0.9599960446357727
# The best SSIM epoch:  61
# Testing sample:  18
# The best SSIM through training process: 0.9454419612884521
# The best SSIM epoch:  61
# Testing sample:  19
# The best SSIM through training process: 0.9569023251533508
# The best SSIM epoch:  71
# Testing sample:  20
# The best SSIM through training process: 0.9727563261985779
# The best SSIM epoch:  94
# Testing sample:  21
# The best SSIM through training process: 0.9695926904678345
# The best SSIM epoch:  89
# Testing sample:  22
# The best SSIM through training process: 0.9566894769668579
# The best SSIM epoch:  60
# Testing sample:  23
# The best SSIM through training process: 0.9633983969688416
# The best SSIM epoch:  88
# Testing sample:  24
# The best SSIM through training process: 0.9687454104423523
# The best SSIM epoch:  103
# Testing sample:  25
# The best SSIM through training process: 0.9593682289123535
# The best SSIM epoch:  77
# Testing sample:  26
# The best SSIM through training process: 0.9620457887649536
# The best SSIM epoch:  80
# Testing sample:  27
# The best SSIM through training process: 0.9556241035461426
# The best SSIM epoch:  75
# Testing sample:  28
# The best SSIM through training process: 0.954125702381134
# The best SSIM epoch:  81
# Testing sample:  29
# The best SSIM through training process: 0.9655923843383789
# The best SSIM epoch:  89
# Testing sample:  30
# The best SSIM through training process: 0.9387130737304688
# The best SSIM epoch:  58
# Testing sample:  31
# The best SSIM through training process: 0.9471302032470703
# The best SSIM epoch:  82
# Testing sample:  32
# The best SSIM through training process: 0.9491955637931824
# The best SSIM epoch:  85
# Testing sample:  33
# The best SSIM through training process: 0.9606044888496399
# The best SSIM epoch:  112
# Testing sample:  34
# The best SSIM through training process: 0.9580597877502441
# The best SSIM epoch:  96
# Testing sample:  35
# The best SSIM through training process: 0.9575499296188354
# The best SSIM epoch:  85
# Testing sample:  36
# The best SSIM through training process: 0.9580926895141602
# The best SSIM epoch:  56
# Testing sample:  37
# The best SSIM through training process: 0.9514672756195068
# The best SSIM epoch:  51
# Testing sample:  38
# The best SSIM through training process: 0.9557124376296997
# The best SSIM epoch:  88
# Testing sample:  39
# The best SSIM through training process: 0.967604398727417
# The best SSIM epoch:  149
# Testing sample:  40
# The best SSIM through training process: 0.9665430188179016
# The best SSIM epoch:  88
# Testing sample:  41
# The best SSIM through training process: 0.9580419063568115
# The best SSIM epoch:  75
# Testing sample:  42
# The best SSIM through training process: 0.9533544182777405
# The best SSIM epoch:  82
# Testing sample:  43
# The best SSIM through training process: 0.9547525644302368
# The best SSIM epoch:  56
# Testing sample:  44
# The best SSIM through training process: 0.9615921974182129
# The best SSIM epoch:  81
# Testing sample:  45
# The best SSIM through training process: 0.9682581424713135
# The best SSIM epoch:  103
# Testing sample:  46
# The best SSIM through training process: 0.9298988580703735
# The best SSIM epoch:  60
# Testing sample:  47
# The best SSIM through training process: 0.9683475494384766
# The best SSIM epoch:  99
# Testing sample:  48
# The best SSIM through training process: 0.9433282017707825
# The best SSIM epoch:  50
# Testing sample:  49
# The best SSIM through training process: 0.8938905596733093
# The best SSIM epoch:  37
# Testing sample:  50
# The best SSIM through training process: 0.9520977139472961
# The best SSIM epoch:  52
# Testing sample:  51
# The best SSIM through training process: 0.9603026509284973
# The best SSIM epoch:  96
# Testing sample:  52
# The best SSIM through training process: 0.9507277607917786
# The best SSIM epoch:  83
# Testing sample:  53
# The best SSIM through training process: 0.9589281678199768
# The best SSIM epoch:  101
# Testing sample:  54
# The best SSIM through training process: 0.9790469408035278
# The best SSIM epoch:  110
# Testing sample:  55
# The best SSIM through training process: 0.9628466367721558
# The best SSIM epoch:  82
# Testing sample:  56
# The best SSIM through training process: 0.9596772789955139
# The best SSIM epoch:  104
# Testing sample:  57
# The best SSIM through training process: 0.9679046869277954
# The best SSIM epoch:  96
# Testing sample:  58
# The best SSIM through training process: 0.9521698355674744
# The best SSIM epoch:  73
# Testing sample:  59
# The best SSIM through training process: 0.970977783203125
# The best SSIM epoch:  101
# Testing sample:  60
# The best SSIM through training process: 0.9354842901229858
# The best SSIM epoch:  56
# Testing sample:  61
# The best SSIM through training process: 0.9671251773834229
# The best SSIM epoch:  84
# Testing sample:  62
# The best SSIM through training process: 0.9494464993476868
# The best SSIM epoch:  125
# Testing sample:  63
# The best SSIM through training process: 0.9501890540122986
# The best SSIM epoch:  53
# Testing sample:  64
# The best SSIM through training process: 0.9674353003501892
# The best SSIM epoch:  131
# Testing sample:  65
# The best SSIM through training process: 0.9619780778884888
# The best SSIM epoch:  88
# Testing sample:  66
# The best SSIM through training process: 0.9744712114334106
# The best SSIM epoch:  115
# Testing sample:  67
# The best SSIM through training process: 0.9444637894630432
# The best SSIM epoch:  75
# Testing sample:  68
# The best SSIM through training process: 0.9527249932289124
# The best SSIM epoch:  84
# Testing sample:  69
# The best SSIM through training process: 0.9635311961174011
# The best SSIM epoch:  118
# Testing sample:  70
# The best SSIM through training process: 0.9641364812850952
# The best SSIM epoch:  96
# Testing sample:  71
# The best SSIM through training process: 0.9435709714889526
# The best SSIM epoch:  56
# Testing sample:  72
# The best SSIM through training process: 0.9607931971549988
# The best SSIM epoch:  83
# Testing sample:  73
# The best SSIM through training process: 0.9402309656143188
# The best SSIM epoch:  75
# Testing sample:  74
# The best SSIM through training process: 0.950593888759613
# The best SSIM epoch:  68
# Testing sample:  75
# The best SSIM through training process: 0.948771595954895
# The best SSIM epoch:  50
# Testing sample:  76
# The best SSIM through training process: 0.958242654800415
# The best SSIM epoch:  115
# Testing sample:  77
# The best SSIM through training process: 0.9650641083717346
# The best SSIM epoch:  100
# Testing sample:  78
# The best SSIM through training process: 0.9722486734390259
# The best SSIM epoch:  98
# Testing sample:  79
# The best SSIM through training process: 0.9597311019897461
# The best SSIM epoch:  69
# Testing sample:  80
# The best SSIM through training process: 0.9446026682853699
# The best SSIM epoch:  96
# Testing sample:  81
# The best SSIM through training process: 0.9584996700286865
# The best SSIM epoch:  105
# Testing sample:  82
# The best SSIM through training process: 0.954416811466217
# The best SSIM epoch:  88
# Testing sample:  83
# The best SSIM through training process: 0.957377552986145
# The best SSIM epoch:  73
# Testing sample:  84
# The best SSIM through training process: 0.9616391658782959
# The best SSIM epoch:  60
# Testing sample:  85
# The best SSIM through training process: 0.9634097814559937
# The best SSIM epoch:  65
# Testing sample:  86
# The best SSIM through training process: 0.8970993757247925
# The best SSIM epoch:  70
# Testing sample:  87
# The best SSIM through training process: 0.9435532093048096
# The best SSIM epoch:  64
# Testing sample:  88
# The best SSIM through training process: 0.9552786350250244
# The best SSIM epoch:  58
# Testing sample:  89
# The best SSIM through training process: 0.9633897542953491
# The best SSIM epoch:  80
# Testing sample:  90
# The best SSIM through training process: 0.966989278793335
# The best SSIM epoch:  90
# Testing sample:  91
# The best SSIM through training process: 0.9487826824188232
# The best SSIM epoch:  104
# Testing sample:  92
# The best SSIM through training process: 0.9618298411369324
# The best SSIM epoch:  71
# Testing sample:  93
# The best SSIM through training process: 0.9375590085983276
# The best SSIM epoch:  58
# Testing sample:  94
# The best SSIM through training process: 0.9430818557739258
# The best SSIM epoch:  55
# Testing sample:  95
# The best SSIM through training process: 0.942961573600769
# The best SSIM epoch:  83
# Testing sample:  96
# The best SSIM through training process: 0.9581829905509949
# The best SSIM epoch:  94
# Testing sample:  97
# The best SSIM through training process: 0.9476780295372009
# The best SSIM epoch:  87
# Testing sample:  98
# The best SSIM through training process: 0.9557861089706421
# The best SSIM epoch:  77
# Testing sample:  99
# The best SSIM through training process: 0.9764068126678467
# The best SSIM epoch:  123
# Testing sample:  100
# The best SSIM through training process: 0.9596264958381653
# The best SSIM epoch:  96
# Testing average SSIM loss:  0.9557239925861358
# Testing average SSIM loss epoch:  83.52

# %%
fig, axes = plt.subplots(1, 2, dpi= 300)

axes[0].imshow(crop_output_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[0].axis('off')

axes[1].imshow(crop_target_image.squeeze(0).squeeze(0).cpu().detach().numpy(),cmap='gray')
axes[1].set_title('Ground Truth')
axes[1].axis('off')

plt.subplots_adjust(wspace=0.1)
plt.show()

# %% [markdown]
# without TTT

# %%
# model_blank = Unet(in_chans=2, out_chans=2, chans=64, num_pool_layers=4, drop_prob=0.0)
# model_blank = model_blank.to(device)

# %%
COIL = 'sensmap'
gt_norm = True

loss_ssim_history_=[]
ssim_fct = SSIMLoss()
l1_loss = torch.nn.L1Loss(reduction='sum')

for iter, batch in tqdm(enumerate(test_dataloader)): 
    kspace, sens_maps, sens_maps_conj, _, fname, slice_num = batch
    kspace = kspace.squeeze(0).to(device)
    sens_maps = sens_maps.squeeze(0).to(device)
    sens_maps_conj = sens_maps_conj.squeeze(0).to(device)

    # input k space
    input_kspace = kspace * mask + 0.0

    # scale factor
    if COIL == 'rss':
        scale_factor = scale_rss(input_kspace, model)
    elif COIL == 'sensmap': 
        scale_factor = scale_sensmap(input_kspace, model, sens_maps_conj)

    # gt image: x
    if COIL == 'rss':
        target_image_1c = rss_torch(complex_abs(ifft2c(kspace))).unsqueeze(0)
    elif COIL == 'sensmap':
        target_image_1c = complex_abs(complex_mul(ifft2c(kspace), sens_maps_conj).sum(dim=0, keepdim=False)).unsqueeze(0)
    # center crop for SSIM
    crop_size = torch.Size([min(target_image_1c.shape[-2:]), min(target_image_1c.shape[-2:])])
    crop_target_image = center_crop( target_image_1c, crop_size )
    if gt_norm: 
        std_crop_target_image = crop_target_image.std()
        mean_crop_target_image = crop_target_image.mean()

    # A†y
    scale_input_kspace = scale_factor* input_kspace
    if COIL == 'rss':
        train_inputs = rss_torch(ifft2c(scale_input_kspace))
    elif COIL == 'sensmap':    
        train_inputs = complex_mul(ifft2c(scale_input_kspace), sens_maps_conj).sum(dim=0, keepdim=False)
    # [height, width, 2]
    train_inputs = torch.moveaxis( train_inputs , -1, 0 ) # move complex channels to channel dimension
    # [2, height, width]

    # fθ(A†y)
    train_outputs = model(train_inputs.unsqueeze(0)) # [1, 2, height, width]
    train_outputs_1c = complex_abs(torch.moveaxis(train_outputs.squeeze(0), 0, -1 )).unsqueeze(0) # [1, height, width]

    # center crop for SSIM
    crop_output_image = center_crop( train_outputs_1c, crop_size )
    # normalization
    if gt_norm: 
        crop_output_image = (crop_output_image - crop_output_image.mean()) / crop_output_image.std()
        crop_output_image *= std_crop_target_image
        crop_output_image += mean_crop_target_image


    # loss_ssim = 1 - ssim_fct(binary_mask_output_image_1c, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()
    loss_ssim = 1 - ssim_fct(crop_output_image, crop_target_image, data_range = crop_target_image.max().unsqueeze(0)).item()

    # loss_l1_history_.append(loss_l1)
    loss_ssim_history_.append(loss_ssim)
# Out:
# 0it [00:00, ?it/s]
# 100it [02:16,  1.36s/it]

# %%
# print("Testing average L1 loss: ", sum(loss_l1_history_) / len(loss_l1_history_))
print("Testing average SSIM loss: ", sum(loss_ssim_history_) / len(loss_ssim_history_))
# Out:
# Testing average SSIM loss:  0.8951449304819107
