# %%
import yaml
import os
import numpy as np
import sys
import h5py
import matplotlib.pyplot as plt

### after you install bart 0.7.00 from https://mrirecon.github.io/bart/, import it as follows
sys.path.insert(0,'/cheng/bart-0.7.00/python/')
os.environ['TOOLBOX_PATH'] = "/cheng/bart-0.7.00/"
import bart

# %%
bart.bart
# Out:
# <function bart.bart(nargout, cmd, *args)>

# %%
## Saves sens maps as a single .h5 file per slice

with open('/cheng/metaMRI/metaMRI/data_dict_temp/stanford_knee_train.yaml', 'r') as stream:
    filenames = yaml.safe_load(stream)

# %%
filenames
# Out:
# [{'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge11',
#   'path': '/media/hdd1/stanford_fastmri_format/ge11.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge13',
#   'path': '/media/hdd1/stanford_fastmri_format/ge13.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 117},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 93},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 129},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 165},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge5',
#   'path': '/media/hdd1/stanford_fastmri_format/ge5.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 123},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 135},
#  {'filename': 'ge15',
#   'path': '/media/hdd1/stanford_fastmri_format/ge15.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 183},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 63},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 141},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 171},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge7',
#   'path': '/media/hdd1/stanford_fastmri_format/ge7.h5',
#   'predefined_mask': None,
#   'slice': 69},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 99},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 105},
#  {'filename': 'ge17',
#   'path': '/media/hdd1/stanford_fastmri_format/ge17.h5',
#   'predefined_mask': None,
#   'slice': 189},
#  {'filename': 'ge16',
#   'path': '/media/hdd1/stanford_fastmri_format/ge16.h5',
#   'predefined_mask': None,
#   'slice': 159},
#  {'filename': 'ge18',
#   'path': '/media/hdd1/stanford_fastmri_format/ge18.h5',
#   'predefined_mask': None,
#   'slice': 153},
#  {'filename': 'ge3',
#   'path': '/media/hdd1/stanford_fastmri_format/ge3.h5',
#   'predefined_mask': None,
#   'slice': 81},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 75},
#  {'filename': 'ge4',
#   'path': '/media/hdd1/stanford_fastmri_format/ge4.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge9',
#   'path': '/media/hdd1/stanford_fastmri_format/ge9.h5',
#   'predefined_mask': None,
#   'slice': 87},
#  {'filename': 'ge2',
#   'path': '/media/hdd1/stanford_fastmri_format/ge2.h5',
#   'predefined_mask': None,
#   'slice': 147},
#  {'filename': 'ge10',
#   'path': '/media/hdd1/stanford_fastmri_format/ge10.h5',
#   'predefined_mask': None,
#   'slice': 177},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 111},
#  {'filename': 'ge14',
#   'path': '/media/hdd1/stanford_fastmri_format/ge14.h5',
#   'predefined_mask': None,
#   'slice': 165}]

# %%
def apply_center_mask(kspace,center_fraction):
    num_cols = kspace.shape[-1]

    #center_fraction = 0.08
    acceleration = 4

    # create the mask
    num_low_freqs = int(round(num_cols * center_fraction))
    #print(num_low_freqs)
    num_high_freqs = round(num_cols / acceleration) - num_low_freqs
    pad = (num_cols - num_low_freqs + 1) // 2

    all_freqs_indices = np.arange(num_cols)
    all_high_freqs_indices = np.hstack((all_freqs_indices[: pad],all_freqs_indices[pad + num_low_freqs :]))

    chosen_high_freqs_indices = np.random.choice(all_high_freqs_indices, size=num_high_freqs, replace=False, p=None)

    mask = np.zeros(num_cols)
    
    mask[pad : pad + num_low_freqs] = 1.0
    #mask[chosen_high_freqs_indices] = 1.0
    #print(mask)
    
    mask_shape = [1 for _ in kspace.shape]
    mask_shape[-1] = num_cols
    mask = mask.reshape(*mask_shape)

    masked_kspace = kspace*mask + 0.0
    return masked_kspace, num_low_freqs

# %%
save_path = '/cheng/metaMRI/metaMRI/data_dict_temp/stanford_sensmap/'

counter = 0
for file in filenames:
    
    ## Load kspace
    with h5py.File(file["path"], "r") as hf:
        kspace_slice = hf["kspace"][file["slice"]]
    
    center_fraction = 0.08

    counter+=1
    print(counter)

    ## Apply mask only on the 0.08 center fraction
    masked_kspace, num_low_freqs = apply_center_mask(kspace_slice,center_fraction)

    ## Compute sens map
    sens_maps = bart.bart(1, f'ecalib -d0 -m1', np.array([np.moveaxis(masked_kspace,0,2)]))
    sens_maps = np.moveaxis(sens_maps[0],2,0)   

    ## Save sens map
    sensmap_fname = file["filename"] + '_smaps_slice' + str(file["slice"]) + '.h5'
    with h5py.File(save_path + sensmap_fname, "w") as hf:
        hf.create_dataset('sens_maps', data=sens_maps)
# Out:
# 1
# Done.
# 2
# Done.
# 3
# Done.
# 4
# Done.
# 5
# Done.
# 6
# Done.
# 7
# Done.
# 8
# Done.
# 9
# Done.
# 10
# Done.
# 11
# Done.
# 12
# Done.
# 13
# Done.
# 14
# Done.
# 15
# Done.
# 16
# Done.
# 17
# Done.
# 18
# Done.
# 19
# Done.
# 20
# Done.
# 21
# Done.
# 22
# Done.
# 23
# Done.
# 24
# Done.
# 25
# Done.
# 26
# Done.
# 27
# Done.
# 28
# Done.
# 29
# Done.
# 30
# Done.
# 31
# Done.
# 32
# Done.
# 33
# Done.
# 34
# Done.
# 35
# Done.
# 36
# Done.
# 37
# Done.
# 38
# Done.
# 39
# Done.
# 40
# Done.
# 41
# Done.
# 42
# Done.
# 43
# Done.
# 44
# Done.
# 45
# Done.
# 46
# Done.
# 47
# Done.
# 48
# Done.
# 49
# Done.
# 50
# Done.
# 51
# Done.
# 52
# Done.
# 53
# Done.
# 54
# Done.
# 55
# Done.
# 56
# Done.
# 57
# Done.
# 58
# Done.
# 59
# Done.
# 60
# Done.
# 61
# Done.
# 62
# Done.
# 63
# Done.
# 64
# Done.
# 65
# Done.
# 66
# Done.
# 67
# Done.
# 68
# Done.
# 69
# Done.
# 70
# Done.
# 71
# Done.
# 72
# Done.
# 73
# Done.
# 74
# Done.
# 75
# Done.
# 76
# Done.
# 77
# Done.
# 78
# Done.
# 79
# Done.
# 80
# Done.
# 81
# Done.
# 82
# Done.
# 83
# Done.
# 84
# Done.
# 85
# Done.
# 86
# Done.
# 87
# Done.
# 88
# Done.
# 89
# Done.
# 90
# Done.
# 91
# Done.
# 92
# Done.
# 93
# Done.
# 94
# Done.
# 95
# Done.
# 96
# Done.
# 97
# Done.
# 98
# Done.
# 99
# Done.
# 100
# Done.
# 101
# Done.
# 102
# Done.
# 103
# Done.
# 104
# Done.
# 105
# Done.
# 106
# Done.
# 107
# Done.
# 108
# Done.
# 109
# Done.
# 110
# Done.
# 111
# Done.
# 112
# Done.
# 113
# Done.
# 114
# Done.
# 115
# Done.
# 116
# Done.
# 117
# Done.
# 118
# Done.
# 119
# Done.
# 120
# Done.
# 121
# Done.
# 122
# Done.
# 123
# Done.
# 124
# Done.
# 125
# Done.
# 126
# Done.
# 127
# Done.
# 128
# Done.
# 129
# Done.
# 130
# Done.
# 131
# Done.
# 132
# Done.
# 133
# Done.
# 134
# Done.
# 135
# Done.
# 136
# Done.
# 137
# Done.
# 138
# Done.
# 139
# Done.
# 140
# Done.
# 141
# Done.
# 142
# Done.
# 143
# Done.
# 144
# Done.
# 145
# Done.
# 146
# Done.
# 147
# Done.
# 148
# Done.
# 149
# Done.
# 150
# Done.
# 151
# Done.
# 152
# Done.
# 153
# Done.
# 154
# Done.
# 155
# Done.
# 156
# Done.
# 157
# Done.
# 158
# Done.
# 159
# Done.
# 160
# Done.
# 161
# Done.
# 162
# Done.
# 163
# Done.
# 164
# Done.
# 165
# Done.
# 166
# Done.
# 167
# Done.
# 168
# Done.
# 169
# Done.
# 170
# Done.
# 171
# Done.
# 172
# Done.
# 173
# Done.
# 174
# Done.
# 175
# Done.
# 176
# Done.
# 177
# Done.
# 178
# Done.
# 179
# Done.
# 180
# Done.
# 181
# Done.
# 182
# Done.
# 183
# Done.
# 184
# Done.
# 185
# Done.
# 186
# Done.
# 187
# Done.
# 188
# Done.
# 189
# Done.
# 190
# Done.
# 191
# Done.
# 192
# Done.
# 193
# Done.
# 194
# Done.
# 195
# Done.
# 196
# Done.
# 197
# Done.
# 198
# Done.
# 199
# Done.
# 200
# Done.
# 201
# Done.
# 202
# Done.
# 203
# Done.
# 204
# Done.
# 205
# Done.
# 206
# Done.
# 207
# Done.
# 208
# Done.
# 209
# Done.
# 210
# Done.
# 211
# Done.
# 212
# Done.
# 213
# Done.
# 214
# Done.
# 215
# Done.
# 216
# Done.
# 217
# Done.
# 218
# Done.
# 219
# Done.
# 220
# Done.
# 221
# Done.
# 222
# Done.
# 223
# Done.
# 224
# Done.
# 225
# Done.
# 226
# Done.
# 227
# Done.
# 228
# Done.
# 229
# Done.
# 230
# Done.
# 231
# Done.
# 232
# Done.
# 233
# Done.
# 234
# Done.
# 235
# Done.
# 236
# Done.
# 237
# Done.
# 238
# Done.
# 239
# Done.
# 240
# Done.
# 241
# Done.
# 242
# Done.
# 243
# Done.
# 244
# Done.
# 245
# Done.
# 246
# Done.
# 247
# Done.
# 248
# Done.
# 249
# Done.
# 250
# Done.
# 251
# Done.
# 252
# Done.
# 253
# Done.
# 254
# Done.
# 255
# Done.
# 256
# Done.
# 257
# Done.
# 258
# Done.
# 259
# Done.
# 260
# Done.
# 261
# Done.
# 262
# Done.
# 263
# Done.
# 264
# Done.
# 265
# Done.
# 266
# Done.
# 267
# Done.
# 268
# Done.
# 269
# Done.
# 270
# Done.
# 271
# Done.
# 272
# Done.
# 273
# Done.
# 274
# Done.
# 275
# Done.
# 276
# Done.
# 277
# Done.
# 278
# Done.
# 279
# Done.
# 280
# Done.
# 281
# Done.
# 282
# Done.
# 283
# Done.
# 284
# Done.
# 285
# Done.
# 286
# Done.
# 287
# Done.
# 288
# Done.
# 289
# Done.
# 290
# Done.
# 291
# Done.
# 292
# Done.
# 293
# Done.
# 294
# Done.
# 295
# Done.
# 296
# Done.
# 297
# Done.
# 298
# Done.
# 299
# Done.
# 300
# Done.
# 301
# Done.
# 302
# Done.
# 303
# Done.
# 304
# Done.
# 305
# Done.
# 306
# Done.
# 307
# Done.
# 308
# Done.

# %%
print(sens_maps.shape)
# Out:
# (8, 320, 320)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(np.abs(sens_maps[0]),'gray')
ax.axis('off')
# Out:
# (-0.5, 319.5, 319.5, -0.5)
