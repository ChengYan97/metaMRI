# %% [markdown]
# ### dataset dir

# %%
import pandas as pd
import h5py
import xmltodict
import glob
import yaml
import tqdm
import pickle
import random
from os import listdir
from os.path import isfile, join, splitext

# %%
hf = h5py.File('/media/hdd1/fastMRIdata/brain/multicoil_train/file_brain_AXFLAIR_200_6002429.h5')
dic = xmltodict.parse(hf['ismrmrd_header'][()])['ismrmrdHeader']
dic['acquisitionSystemInformation']['systemModel']
# Out:
# 'Skyra'

# %%
target_protocol = 'CORPDFS_FBK'    # AXT1, AXT2, AXFLAIR, AXT1POST, CORPD_FBK
target_system = 'Prisma_fit'      # Aera, Skyra

dataset_name = 'knee_val_' + target_protocol + '_' + target_system

mypath = '/media/hdd1/fastMRIdata/knee/multicoil_val/'
# '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_val/'
# '/srv/knee/multicoil_train/'
# '/media/hdd1/fastMRIdata/knee/multicoil_val/'

# read file name in "mypath" into list
filenames = [splitext(filename)[0] for filename in listdir(mypath)]
slice_list = []

for filename in filenames:
    file_name = mypath + filename + '.h5'
    hf = h5py.File(file_name)
    dic = xmltodict.parse(hf['ismrmrd_header'][()])['ismrmrdHeader']
    reconX = int(dic['encoding']['reconSpace']['matrixSize']['x'])
    reconY = int(dic['encoding']['reconSpace']['matrixSize']['y'])
    kspace_shape = hf['kspace'].shape
    protocolName = dict(hf.attrs)['acquisition']
    systemModel = dic['acquisitionSystemInformation']['systemModel']
    #if reconX == 320 and reconY == 320 and protocolName == target_protocol \
        #and kspace_shape[2:4] == (640,320) and systemModel == target_system: 
    if protocolName == target_protocol and systemModel == target_system: 
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': None, 
            'filename': filename, 
            'predefined_mask': None})

    with open("/cheng/metaMRI/metaMRI/data_dict_narrowSlices/" + dataset_name + ".yaml", "w") as fp:
        yaml.dump(slice_list,fp)

# %%
target_protocol = 'CORPDFS_FBK'    # AXT1, AXT2, AXFLAIR, AXT1POST, CORPD_FBK
target_system = 'Biograph_mMR'      # Aera, Skyra, Biograph_mMR

dataset_name = 'knee_val_' + target_protocol + '_' + target_system + '_15-22'

mypath = '/media/hdd1/fastMRIdata/knee/multicoil_val/'
# '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_val/'
# '/srv/knee/multicoil_train/'
# '/media/hdd1/fastMRIdata/knee/multicoil_val/'

# read file name in "mypath" into list
filenames = [splitext(filename)[0] for filename in listdir(mypath)]
slice_list = []

for filename in filenames:
    file_name = mypath + filename + '.h5'
    hf = h5py.File(file_name)
    dic = xmltodict.parse(hf['ismrmrd_header'][()])['ismrmrdHeader']
    reconX = int(dic['encoding']['reconSpace']['matrixSize']['x'])
    reconY = int(dic['encoding']['reconSpace']['matrixSize']['y'])
    kspace_shape = hf['kspace'].shape
    protocolName = dict(hf.attrs)['acquisition']
    systemModel = dic['acquisitionSystemInformation']['systemModel']
    #if reconX == 320 and reconY == 320 and protocolName == target_protocol \
        #and kspace_shape[2:4] == (640,320) and systemModel == target_system: 
    if protocolName == target_protocol and systemModel == target_system: 
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 14, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 15, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 16, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 17, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 18, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 19, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 20, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 21, 
            'filename': filename, 
            'predefined_mask': None})  

    with open("/cheng/metaMRI/metaMRI/data_dict_narrowSlices/" + dataset_name + ".yaml", "w") as fp:
        yaml.dump(slice_list,fp)

# %%
target_protocol = 'CORPD_FBK'    # AXT1, AXT2, AXFLAIR, AXT1POST, CORPD_FBK
target_system = 'Aera'      # Aera, Skyra, Biograph_mMR

dataset_name = 'knee_val_' + target_protocol + '_' + target_system + '_2-9'

mypath = '/media/hdd1/fastMRIdata/knee/multicoil_val/'
# '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_val/'
# '/srv/knee/multicoil_train/'
# '/media/hdd1/fastMRIdata/knee/multicoil_val/'

# read file name in "mypath" into list
filenames = [splitext(filename)[0] for filename in listdir(mypath)]
slice_list = []

for filename in filenames:
    file_name = mypath + filename + '.h5'
    hf = h5py.File(file_name)
    dic = xmltodict.parse(hf['ismrmrd_header'][()])['ismrmrdHeader']
    reconX = int(dic['encoding']['reconSpace']['matrixSize']['x'])
    reconY = int(dic['encoding']['reconSpace']['matrixSize']['y'])
    kspace_shape = hf['kspace'].shape
    protocolName = dict(hf.attrs)['acquisition']
    systemModel = dic['acquisitionSystemInformation']['systemModel']
    #if reconX == 320 and reconY == 320 and protocolName == target_protocol \
        #and kspace_shape[2:4] == (640,320) and systemModel == target_system: 
    if protocolName == target_protocol and systemModel == target_system: 
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 1, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 2, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 3, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 4, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 5, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 6, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 7, 
            'filename': filename, 
            'predefined_mask': None})  
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 8, 
            'filename': filename, 
            'predefined_mask': None})  

    with open("/cheng/metaMRI/metaMRI/data_dict_narrowSlices/" + dataset_name + ".yaml", "w") as fp:
        yaml.dump(slice_list,fp)

# %%
target_protocol = 'AXT2'    # AXT1, AXT2, AXFLAIR, AXT1POST, CORPD_FBK
target_system = 'Aera'      # Aera, Skyra

dataset_name = 'brain_train_' + target_protocol + '_' + target_system + '_5-8'

mypath = '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_val/'
# '/srv/knee/multicoil_train/'
# '/media/hdd1/fastMRIdata/knee/multicoil_val/'

# read file name in "mypath" into list
filenames = [splitext(filename)[0] for filename in listdir(mypath)]
slice_list = []

for filename in filenames:
    file_name = mypath + filename + '.h5'
    hf = h5py.File(file_name)
    dic = xmltodict.parse(hf['ismrmrd_header'][()])['ismrmrdHeader']
    reconX = int(dic['encoding']['reconSpace']['matrixSize']['x'])
    reconY = int(dic['encoding']['reconSpace']['matrixSize']['y'])
    kspace_shape = hf['kspace'].shape
    protocolName = dict(hf.attrs)['acquisition']
    systemModel = dic['acquisitionSystemInformation']['systemModel']
    if  protocolName == target_protocol and systemModel == target_system\
        and kspace_shape[2:4] == (640,320) and kspace_shape[0] == 16 \
        and reconX == 320 and reconY == 320: 
    #if protocolName == target_protocol and systemModel == target_system: 
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 4, 
            'filename': filename, 
            'predefined_mask': None})
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 5, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 6, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 7, 
            'filename': filename, 
            'predefined_mask': None})
    
    with open("/cheng/metaMRI/metaMRI/data_dict_temp/" + dataset_name + ".yaml", "w") as fp:
        yaml.dump(slice_list,fp)

# %%
target_protocol = 'AXT1POST'    # AXT1, AXT2, AXFLAIR, AXT1POST, CORPD_FBK
target_system = 'Skyra'      # Aera, Skyra

dataset_name = 'brain_train_' + target_protocol + '_' + target_system + '_5-8'

mypath = '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_val/'
# '/srv/knee/multicoil_train/'
# '/media/hdd1/fastMRIdata/knee/multicoil_val/'

# read file name in "mypath" into list
filenames = [splitext(filename)[0] for filename in listdir(mypath)]
slice_list = []

for filename in filenames:
    file_name = mypath + filename + '.h5'
    hf = h5py.File(file_name)
    dic = xmltodict.parse(hf['ismrmrd_header'][()])['ismrmrdHeader']
    reconX = int(dic['encoding']['reconSpace']['matrixSize']['x'])
    reconY = int(dic['encoding']['reconSpace']['matrixSize']['y'])
    kspace_shape = hf['kspace'].shape
    protocolName = dict(hf.attrs)['acquisition']
    systemModel = dic['acquisitionSystemInformation']['systemModel']
    if  protocolName == target_protocol and systemModel == target_system\
        and kspace_shape[2:4] == (640,320) and kspace_shape[0] == 16 \
        and reconX == 320 and reconY == 320: 
    #if protocolName == target_protocol and systemModel == target_system: 
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 4, 
            'filename': filename, 
            'predefined_mask': None})
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 5, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 6, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 7, 
            'filename': filename, 
            'predefined_mask': None})
    
    with open("/cheng/metaMRI/metaMRI/data_dict_temp/" + dataset_name + ".yaml", "w") as fp:
        yaml.dump(slice_list,fp)

# %%
target_protocol = 'CORPD_FBK'    # AXT1, AXT2, AXFLAIR, AXT1POST, CORPD_FBK
target_system = 'Aera'      # Aera, Skyra

dataset_name = 'knee_train_' + target_protocol + '_' + target_system + '_15-19'

mypath = '/srv/knee/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_train/'
# '/media/hdd1/fastMRIdata/brain/multicoil_val/'
# '/srv/knee/multicoil_train/'
# '/media/hdd1/fastMRIdata/knee/multicoil_val/'

# read file name in "mypath" into list
filenames = [splitext(filename)[0] for filename in listdir(mypath)]
slice_list = []

for filename in filenames:
    file_name = mypath + filename + '.h5'
    hf = h5py.File(file_name)
    dic = xmltodict.parse(hf['ismrmrd_header'][()])['ismrmrdHeader']
    reconX = int(dic['encoding']['reconSpace']['matrixSize']['x'])
    reconY = int(dic['encoding']['reconSpace']['matrixSize']['y'])
    kspace_shape = hf['kspace'].shape
    protocolName = dict(hf.attrs)['acquisition']
    systemModel = dic['acquisitionSystemInformation']['systemModel']
    if  protocolName == target_protocol and systemModel == target_system: 
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 14, 
            'filename': filename, 
            'predefined_mask': None})      
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 15, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 16, 
            'filename': filename, 
            'predefined_mask': None})        
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 17, 
            'filename': filename, 
            'predefined_mask': None})
        slice_list.append({
            'path': mypath + filename+'.h5', 
            'slice': 18, 
            'filename': filename, 
            'predefined_mask': None})
    
    with open("/cheng/metaMRI/metaMRI/data_dict_temp/" + dataset_name + ".yaml", "w") as fp:
        yaml.dump(slice_list,fp)
